# %% [markdown]
# ## step 1 define data reader

# %%
import torchaudio
import os
from tqdm.auto import tqdm
import torch
from torch.utils.data import DataLoader
from transformers import Wav2Vec2FeatureExtractor
import random
import soundfile
#import palimpzest as pz
import chromadb
import pandas as pd

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import pdb

# %%
import palimpzest as pz
# Out:
# /home/opalinav/palimpzest/audio_pz2/lib/python3.12/site-packages/torch/cuda/__init__.py:129: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 101: invalid device ordinal (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
from palimpzest.core.lib.fields import (
    BooleanField,
    BytesField,
    Field,
    FloatField,
    IntField,
    ListField,
    NumericField,
    StringField,
    AudioField
)

# %%
audio2text_cols=[
    {"name":"song_id", 'type':str, 'desc': 'Uniquu track ID of the song'},
    {"name": "audio_10", 'type': AudioField, 'desc':'path to audio file'},
    {"name": "audio_30", 'type': AudioField, 'desc':'path to audio file'},
    {"name": "audio_60", 'type': AudioField, 'desc':'path to audio file'},

]

# %%
def load_audio(
    file_path,
    target_sr,
    is_mono=True,
    is_normalize=False,
    crop=True,
    crop_to_length_in_sec=None,
    crop_to_length_in_sample_points=None,
    crop_randomly=False,
    pad=False,
    return_start=False,
    device=torch.device('cpu')
):
    """Load audio file and convert to target sample rate.
    Supports cropping and padding.

    Args:
        file_path (str): path to audio file
        target_sr (int): target sample rate, if not equal to sample rate of audio file, resample to target_sr
        is_mono (bool, optional): convert to mono. Defaults to True.
        is_normalize (bool, optional): normalize to [-1, 1]. Defaults to False.
        crop_to_length_in_sec (float, optional): crop to specified length in seconds. Defaults to None.
        crop_to_length_in_sample_points (int, optional): crop to specified length in sample points. Defaults to None. Note that the crop length in sample points is calculated before resampling.
        crop_randomly (bool, optional): crop randomly. Defaults to False.
        pad (bool, optional): pad to specified length if waveform is shorter than specified length. Defaults to False.
        device (torch.device, optional): device to use for resampling. Defaults to torch.device('cpu').

    Returns:
        torch.Tensor: waveform of shape (1, n_sample)
    """
    # TODO: deal with target_depth
    try:
        waveform, sample_rate = torchaudio.load(file_path)
    except Exception as e:
        waveform, sample_rate = torchaudio.backend.soundfile_backend.load(file_path)
    if waveform.shape[0] > 1:
        if is_mono:
            waveform = torch.mean(waveform, dim=0, keepdim=True)

    if is_normalize:
        waveform = waveform / waveform.abs().max()

    if crop:

        waveform, start = crop_audio(
            waveform,
            sample_rate,
            crop_to_length_in_sec=crop_to_length_in_sec,
            crop_to_length_in_sample_points=crop_to_length_in_sample_points,
            crop_randomly=crop_randomly,
            pad=pad,
        )

    if sample_rate != target_sr:
        resampler = torchaudio.transforms.Resample(sample_rate, target_sr)
        waveform = waveform.to(device)
        resampler = resampler.to(device)
        waveform = resampler(waveform)

    if return_start:
        return waveform, start
    return waveform


def crop_audio(
    waveform,
    sample_rate,
    crop_to_length_in_sec=None,
    crop_to_length_in_sample_points=None,
    crop_randomly=False,
    pad=False,
):
    """Crop waveform to specified length in seconds or sample points.
    Supports random cropping and padding.

    Args:
        waveform (torch.Tensor): waveform of shape (1, n_sample)
        sample_rate (int): sample rate of waveform
        crop_to_length_in_sec (float, optional): crop to specified length in seconds. Defaults to None.
        crop_to_length_in_sample_points (int, optional): crop to specified length in sample points. Defaults to None.
        crop_randomly (bool, optional): crop randomly. Defaults to False.
        pad (bool, optional): pad to specified length if waveform is shorter than specified length. Defaults to False.

    Returns:
        torch.Tensor: cropped waveform
        int: start index of cropped waveform in original waveform
    """
    assert crop_to_length_in_sec is None or crop_to_length_in_sample_points is None, \
    "Only one of crop_to_length_in_sec and crop_to_length_in_sample_points can be specified"

    # convert crop length to sample points
    crop_duration_in_sample = None
    if crop_to_length_in_sec:
        crop_duration_in_sample = int(sample_rate * crop_to_length_in_sec)
    elif crop_to_length_in_sample_points:
        crop_duration_in_sample = crop_to_length_in_sample_points

    # crop
    start = 0
    if crop_duration_in_sample:
        if waveform.shape[-1] > crop_duration_in_sample:
            if crop_randomly:
                start = random.randint(0, waveform.shape[-1] - crop_duration_in_sample)
            waveform = waveform[..., start:start + crop_duration_in_sample]

        elif waveform.shape[-1] < crop_duration_in_sample:
            if pad:
                waveform = torch.nn.functional.pad(waveform, (0, crop_duration_in_sample - waveform.shape[-1]))

    return waveform, start

# %%
class MusicDataReader2(pz.DataReader):
    def __init__(self, songs_dir,labels_dir=None,device=None,processor=None,split: str = "test"):
        super().__init__(audio2text_cols)
        self.split=split
        self.songs_dir =songs_dir
        self.songs = sorted(os.listdir(self.songs_dir))
        if self.split=='test':
            self.songs=self.songs[-10:]
        else:
            self.songs=self.songs[:15]
            self.labels=pd.read_csv(labels_dir,index_col=1)
        
        if device is None:
            self.device='cpu'
        
        if processor is None:
            processor=Wav2Vec2FeatureExtractor.from_pretrained("m-a-p/MERT-v1-330M",trust_remote_code=True)
        self.processor=processor
       
        #process all audio in here first
        self.processed_songs={}
        self.crops=[10,30,60]
        for idx,song_filename in enumerate(self.songs):
            
            audio_path=os.path.join(self.songs_dir,song_filename)
            song_id=song_filename[:-8] #ex. song_filename=7400.low.mp3, song_id=7400
            song_dict={'song_id':song_id}
            for crop in self.crops:
                waveform = load_audio(audio_path, target_sr=24000,
                            is_mono=True,
                            is_normalize=False,
                            crop_to_length_in_sample_points=int(crop*16000)+1,
                            crop_randomly=True,
                            pad=False).to(self.device)
                
                
                processed_audio = self.processor(waveform,
                            sampling_rate=24000,
                            return_tensors="pt")['input_values'][0].to(self.device)
                
                song_dict[f'audio_{crop}']=processed_audio
            self.processed_songs[idx]=song_dict
            
            
           
           
    def compute_label(self, song_id) -> dict:
        """Compute the genre label for a song given its entry in the dataset."""
       
        genres=eval(self.labels.at[int(song_id),'genre'])
        instruments=eval(self.labels.at[int(song_id),'instrument'])
        moods=eval(self.labels.at[int(song_id),'mood/theme'])        
        label_dict = {
            'genre': genres,
            'instruments': instruments,
            'moods': moods
        }
        return label_dict
    
    @staticmethod
    def precision(preds: list | None, target: list, labels_dir=r'/home/opalinav/musi_long120_parsed_results.csv'):
        'preds is list of song ids returned in query, target is query song id'
        
        labels=pd.read_csv(labels_dir, index_col=1)
        #compute labels
        genres=eval(labels.at[int(target),'genre'])
        instruments=eval(labels.at[int(target),'instrument'])
        moods=eval(labels.at[int(target),'mood/theme'])        
        label_dict = {
            'genre': genres,
            'instrument': instruments,
            'mood/theme': moods
        }
        
        scores=[]
        for category in label_dict:
            targ=set(label_dict[category])
            correct=0
            for pred_id in preds:
                pred_labels=set(eval(labels.at[int(pred_id),category]))
                #if query song has at least one shared  tag as target song, then count as correct
                if len(targ&pred_labels)>0:
                    correct+=1
            scores.append(correct/len(preds))
        avg=sum(scores)/len(scores)
        print(f'avg_score:{avg}')
        return avg

    def __len__(self):
        return len(self.songs)

    def __getitem__(self, idx: int):
        entry=self.processed_songs[idx]

        item = {"fields": {}, "labels": {},'score_fn':{}}
        item["fields"]["song_id"] = entry['song_id']
        for crop in self.crops:
            item["fields"][f"audio_{crop}"] =entry[f'audio_{crop}']

        if self.split == "train":
            # add label info
            #item['labels']['song_description']=entry['song_id']
            #items['score_fn']['track_id']=MusicDataReader2.
            item["labels"]['track_id'] = entry['song_id']  #self.compute_label(entry['song_id'])
            # add scoring functions for list fields
            item['score_fn']['track_id']=MusicDataReader2.precision
            
        return item

# %%
songs_dir=r'/home/opalinav/intersect120'
labels_dir=r'/home/opalinav/musi_long120_parsed_results.csv'
datareader=MusicDataReader2(songs_dir,labels_dir)
datareader_val=MusicDataReader2(songs_dir,labels_dir,split='train')

# %%
def run_plan(optimized=False):
    songs_dir=r'/home/opalinav/intersect120'
    labels_dir=r'/home/opalinav/musi_long120_parsed_results.csv'
    datareader=MusicDataReader2(songs_dir,labels_dir)
    datareader_val=MusicDataReader2(songs_dir,labels_dir,split='train')
    song_desc_cols=[
        {"name":"song_description", 'type':str, 'desc': 'text description of the song'}
    ]

    def search_func(index: chromadb.Collection, query: list[list[float]], k: int) -> list[str]:
        results = index.query(query, n_results=k)
        #pdb.set_trace()
        #print(f'resultsssss: {results['ids']}')
        return {'track_id': results['ids'][0]}
    
    import chromadb.utils.embedding_functions as embedding_functions
    openai_ef = embedding_functions.OpenAIEmbeddingFunction(
                    api_key=os.environ["OPENAI_API_KEY"],
                    model_name="text-embedding-3-small"
                )
    
    client = chromadb.PersistentClient(path=r'/home/opalinav/chroma120_v3')
    index = client.get_collection(name="Songs120_v3",embedding_function=openai_ef)
    track_labels = [
        {"name": "track_id", "type": list[str], "desc": "track id of songs most similar to query"},
    ]
    
    plan=pz.Dataset(datareader)
    plan=plan.sem_add_columns(song_desc_cols)
    plan=plan.retrieve(index=index,search_attr='song_description',output_attrs=track_labels,search_func=search_func)

    if optimized:
        config = pz.QueryProcessorConfig(
            policy=pz.MaxQuality(),
            val_datasource=datareader_val,
            execution_strategy="parallel",
            max_workers=20,
            allow_audio_crop=True
        )
        output=plan.run(config=config, k=2, j=3, sample_budget=20)
        return output
    else:
        output=plan.run()
        return output

# %%
def precision_outside(preds: list | None, target: list, labels_dir=r'/home/opalinav/musi_long120_parsed_results.csv'):
        'preds is list of song ids returned in query, target is query song id'
        print(f'precision called!')
        print(f'target: {target}')
        print(f'preds:{preds}')
        labels=pd.read_csv(labels_dir, index_col=1)
        #compute labels
        genres=eval(labels.at[int(target),'genre'])
        instruments=eval(labels.at[int(target),'instrument'])
        moods=eval(labels.at[int(target),'mood/theme'])        
        label_dict = {
            'genre': genres,
            'instrument': instruments,
            'mood/theme': moods
        }
        
        scores=[]
        for category in label_dict:
            targ=set(label_dict[category])
            correct=0
            for pred_id in preds:
                pred_labels=set(eval(labels.at[int(pred_id),category]))
                #if query song has at least one shared  tag as target song, then count as correct
                if len(targ&pred_labels)>0:
                    correct+=1
            scores.append(correct/len(preds))
        avg=sum(scores)/len(scores)
        print(f'avg_score:{avg}')
        return avg

# %%
import json
def save_things(output,df_path,stats_path):
    df=output.to_df()
    df['precision'] = df.apply(
        lambda row: precision_outside(row['track_id'], row['song_id']),
        axis=1
    )
    df.to_csv(df_path)

    execution_stats_dict=output.execution_stats.to_json()
    
    with open(stats_path, "w") as f:
        json.dump(execution_stats_dict, f)

# %%
out8.to_df()
# Out:
#                                             audio_10  \
# 0  [[tensor(-0.0220, dtype=torch.float32), tensor...
# 1  [[tensor(-0.0459, dtype=torch.float32), tensor...
# 2  [[tensor(-0.1358, dtype=torch.float32), tensor...
# 3  [[tensor(0.0021, dtype=torch.float32), tensor(...
# 4  [[tensor(-0.0483, dtype=torch.float32), tensor...
# 5  [[tensor(0.0059, dtype=torch.float32), tensor(...
# 6  [[tensor(-0.0765, dtype=torch.float32), tensor...
# 7  [[tensor(0.0479, dtype=torch.float32), tensor(...
# 8  [[tensor(0.0978, dtype=torch.float32), tensor(...
# 9  [[tensor(-0.0382, dtype=torch.float32), tensor...
#
#                                             audio_30  \
# 0  [[tensor(0.1609, dtype=torch.float32), tensor(...
# 1  [[tensor(-0.0544, dtype=torch.float32), tensor...
# 2  [[tensor(0.1044, dtype=torch.float32), tensor(...
# 3  [[tensor(-0.0109, dtype=torch.float32), tensor...
# 4  [[tensor(-0.0161, dtype=torch.float32), tensor...
# 5  [[tensor(0.0095, dtype=torch.float32), tensor(...
# 6  [[tensor(-0.4930, dtype=torch.float32), tensor...
# 7  [[tensor(-0.1044, dtype=torch.float32), tensor...
# 8  [[tensor(-0.2834, dtype=torch.float32), tensor...
# 9  [[tensor(-0.0946, dtype=torch.float32), tensor...
#
#                                             audio_60 song_id  \
# 0  [[tensor(0.0223, dtype=torch.float32), tensor(...   86200
# 1  [[tensor(0.0003, dtype=torch.float32), tensor(...  872000
# 2  [[tensor(-0.0877, dtype=torch.float32), tensor...  847200
# 3  [[tensor(0.0188, dtype=torch.float32), tensor(...  920000
# 4  [[tensor(0.0763, dtype=torch.float32), tensor(...  903600
# 5  [[tensor(0.0340, dtype=torch.float32), tensor(...  893400
# 6  [[tensor(-0.1569, dtype=torch.float32), tensor...  913700
# 7  [[tensor(-0.0305, dtype=torch.float32), tensor...   95400
# 8  [[tensor(-0.1872, dtype=torch.float32), tensor...  950100
# 9  [[tensor(-0.0533, dtype=torch.float32), tensor...  945200
#
#                                     song_description   track_id
# 0  The song is a blues song. It is played on a gu...  [1330500]
# 1  The song is a slow, melancholic, and emotional...  [1366700]
# 2  ​The song is a jazz song, with a medium tempo ...  [1357400]
# 3  ​The song is a slow, mellow, bluesy jazz song....  [1357400]
# 4  ​The song is a classical piece, likely written...  [1105300]
# 5  The song is a slow, mellow, and emotional inst...   [661300]
# 6  The song is a funky house song with a medium t...   [945200]
# 7  The song is a jazz song with a swinging rhythm...  [1357400]
# 8  The song is a funky house track with a fast te...   [945200]
# 9  The song is a dance track with a fast tempo of...   [945200]

# %%
out8=run_plan(optimized=True)
# Out:
# Output()
# FIELDS[("Schema[['audio_10', 'audio_30', 'audio_60', 'song_id']].23b79bde5a.audio_10", True), ("Schema[['audio_10', 'audio_30', 'audio_60', 'song_id']].23b79bde5a.audio_30", True), ("Schema[['audio_10', 'audio_30', 'audio_60', 'song_id']].23b79bde5a.audio_60", True), ("Schema[['audio_10', 'audio_30', 'audio_60', 'song_id']].23b79bde5a.song_id", False)]
# FIELDS2
# [True, True, True, False]
# available_models:[GPT_4o, GPT_4o_MINI, GPT_4o, GPT_4o_MINI, MUSILINGO_LONG, MUSILINGO_SHORT]
# did not pass:Model.GPT_4o
# did not pass:Model.GPT_4o_MINI
# did not pass:Model.GPT_4o
# did not pass:Model.GPT_4o_MINI
# passed:Model.MUSILINGO_LONG
# passed:Model.MUSILINGO_SHORT
# /home/opalinav/palimpzest/audio_pz2/lib/python3.12/site-packages/timm/models/hub.py:4: FutureWarning: Importing
# from timm.models.hub is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# Loading Audio Encoder
# Loading Audio Encoder
# Loading Audio Encoder
# Loading Audio Encoder
# Loading Audio Encoder
# Loading Audio Encoder
# WARNING: feature_extractor_cqt requires the libray 'nnAudio'
# Loading Audio Encoder Done
# Loading LLAMA
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565 - if you loaded a llama tokenizer from a GGUF file you can ignore this message
# Loading Audio Encoder Done
# Loading LLAMA
# LlamaForCausalLM has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# Loading Audio Encoder Done
# Loading LLAMA
# Loading Audio Encoder Done
# Loading LLAMA
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# key: audio_30
# Loading Audio Encoder Done
# Loading LLAMA
# Loading Audio Encoder Done
# Loading LLAMA
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# key: audio_30
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# key: audio_30
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# key: audio_30
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# key: audio_30
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# key: audio_30
# avg_score:0.0
# avg_score:0.06666666666666667
# avg_score:0.39999999999999997
# avg_score:0.4666666666666666
# avg_score:0.3666666666666667
# avg_score:0.20000000000000004
# Loading Audio Encoder
# Loading Audio Encoder
# Loading Audio Encoder
# Loading Audio Encoder
# Loading Audio Encoder Done
# Loading LLAMA
# Loading Audio Encoder Done
# Loading LLAMA
# Loading Audio Encoder Done
# Loading LLAMA
# Loading Audio Encoder Done
# Loading LLAMA
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# key: audio_10
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# key: audio_10
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# key: audio_30
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# key: audio_10
# avg_score:0.31666666666666665
# avg_score:0.0
# avg_score:0.6666666666666666
# avg_score:0.6666666666666666
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Total opt. time: 960.94s
# Total opt. cost: $0.0000
# FIELDS[("Schema[['audio_10', 'audio_30', 'audio_60', 'song_id']].23b79bde5a.audio_10", True), ("Schema[['audio_10', 'audio_30', 'audio_60', 'song_id']].23b79bde5a.audio_30", True), ("Schema[['audio_10', 'audio_30', 'audio_60', 'song_id']].23b79bde5a.audio_60", True), ("Schema[['audio_10', 'audio_30', 'audio_60', 'song_id']].23b79bde5a.song_id", False)]
# FIELDS2
# [True, True, True, False]
# available_models:[GPT_4o, GPT_4o_MINI, GPT_4o, GPT_4o_MINI, MUSILINGO_LONG, MUSILINGO_SHORT]
# did not pass:Model.GPT_4o
# did not pass:Model.GPT_4o_MINI
# did not pass:Model.GPT_4o
# did not pass:Model.GPT_4o_MINI
# passed:Model.MUSILINGO_LONG
# passed:Model.MUSILINGO_SHORT
# Loading Audio Encoder
# Loading Audio Encoder
# Loading Audio Encoder
# Loading Audio Encoder Done
# Loading LLAMA
# Loading Audio Encoder
# Loading Audio Encoder Done
# Loading LLAMA
# Loading Audio Encoder
# Loading Audio Encoder
# Loading Audio Encoder
# Loading Audio Encoder
# Loading Audio Encoder Done
# Loading LLAMA
# Loading Audio Encoder
# Loading Audio Encoder Done
# Loading LLAMA
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# Loading Audio Encoder Done
# Loading LLAMA
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# key: audio_30
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# key: audio_30
# Loading Audio Encoder Done
# Loading LLAMA
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# key: audio_30
# Loading Audio Encoder Done
# Loading LLAMA
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# key: audio_30
# Loading Audio Encoder Done
# Loading LLAMA
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# key: audio_30
# Loading Audio Encoder Done
# Loading LLAMA
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# key: audio_30
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# key: audio_30
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# key: audio_30
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading Audio Encoder Done
# Loading LLAMA
# key: audio_30
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# key: audio_30
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Total time: 359.94s
# Total cost: $0.0000

# %%
out7.to_df()
# Out:
#                                             audio_10  \
# 0  [[tensor(0.1118, dtype=torch.float32), tensor(...
# 1  [[tensor(0.0016, dtype=torch.float32), tensor(...
# 2  [[tensor(-0.0182, dtype=torch.float32), tensor...
# 3  [[tensor(0.1009, dtype=torch.float32), tensor(...
# 4  [[tensor(0.1241, dtype=torch.float32), tensor(...
# 5  [[tensor(0.0708, dtype=torch.float32), tensor(...
# 6  [[tensor(-0.1115, dtype=torch.float32), tensor...
# 7  [[tensor(0.0064, dtype=torch.float32), tensor(...
# 8  [[tensor(-0.0569, dtype=torch.float32), tensor...
# 9  [[tensor(-0.0079, dtype=torch.float32), tensor...
#
#                                             audio_30  \
# 0  [[tensor(0.2059, dtype=torch.float32), tensor(...
# 1  [[tensor(-0.0279, dtype=torch.float32), tensor...
# 2  [[tensor(0.0146, dtype=torch.float32), tensor(...
# 3  [[tensor(-0.0965, dtype=torch.float32), tensor...
# 4  [[tensor(-0.2311, dtype=torch.float32), tensor...
# 5  [[tensor(-0.0653, dtype=torch.float32), tensor...
# 6  [[tensor(0.0581, dtype=torch.float32), tensor(...
# 7  [[tensor(0.1023, dtype=torch.float32), tensor(...
# 8  [[tensor(0.0292, dtype=torch.float32), tensor(...
# 9  [[tensor(0.0018, dtype=torch.float32), tensor(...
#
#                                             audio_60 song_id  \
# 0  [[tensor(-0.2693, dtype=torch.float32), tensor...  847200
# 1  [[tensor(0.0489, dtype=torch.float32), tensor(...  893400
# 2  [[tensor(-0.0282, dtype=torch.float32), tensor...  903600
# 3  [[tensor(0.0019, dtype=torch.float32), tensor(...  872000
# 4  [[tensor(-0.0009, dtype=torch.float32), tensor...   86200
# 5  [[tensor(0.0345, dtype=torch.float32), tensor(...  945200
# 6  [[tensor(0.0236, dtype=torch.float32), tensor(...  913700
# 7  [[tensor(-0.0591, dtype=torch.float32), tensor...  950100
# 8  [[tensor(-0.0126, dtype=torch.float32), tensor...   95400
# 9  [[tensor(0.0024, dtype=torch.float32), tensor(...  920000
#
#                                     song_description  \
# 0  The song is a jazz song, with a medium tempo o...
# 1  The song is a traditional Irish folk song. It ...
# 2  The song is a classical piano piece. The instr...
# 3  The song is a pop song with a fast tempo of 12...
# 4  The song is a blues song. It is played on a gu...
# 5  The song is a dance track with a fast tempo of...
# 6  The song is a funky house song with a medium t...
# 7  The song is a funky house track with a fast te...
# 8  The song is a jazz song with a swinging rhythm...
# 9  The song is a jazz song. It is played on a pia...
#
#                                       track_id
# 0  [1357400, 1087100, 1041500, 718300, 903600]
# 1  [1170400, 86200, 1385300, 1105300, 1037900]
# 2  [1009600, 633200, 757500, 1339700, 1266500]
# 3  [950100, 1155000, 1383900, 945200, 1420700]
# 4   [86200, 1330500, 816200, 1086300, 1395500]
# 5  [945200, 950100, 1420700, 1121400, 1383900]
# 6  [945200, 950100, 1121400, 1420500, 1420700]
# 7  [945200, 1420500, 1121400, 501200, 1420700]
# 8  [1357400, 1087100, 1041500, 718300, 903600]
# 9  [1357400, 847200, 1041500, 903600, 1087100]

# %%
save_things(out7,'crop_opt3.csv', 'crop_opt3.json')
# Out:
# precision called!
# target: 847200
# preds:['1357400', '1087100', '1041500', '718300', '903600']
# avg_score:0.46666666666666673
# precision called!
# target: 893400
# preds:['1170400', '86200', '1385300', '1105300', '1037900']
# avg_score:0.3333333333333333
# precision called!
# target: 903600
# preds:['1009600', '633200', '757500', '1339700', '1266500']
# avg_score:0.39999999999999997
# precision called!
# target: 872000
# preds:['950100', '1155000', '1383900', '945200', '1420700']
# avg_score:0.39999999999999997
# precision called!
# target: 86200
# preds:['86200', '1330500', '816200', '1086300', '1395500']
# avg_score:0.3333333333333333
# precision called!
# target: 945200
# preds:['945200', '950100', '1420700', '1121400', '1383900']
# avg_score:0.7333333333333334
# precision called!
# target: 913700
# preds:['945200', '950100', '1121400', '1420500', '1420700']
# avg_score:0.6666666666666666
# precision called!
# target: 950100
# preds:['945200', '1420500', '1121400', '501200', '1420700']
# avg_score:0.6666666666666666
# precision called!
# target: 95400
# preds:['1357400', '1087100', '1041500', '718300', '903600']
# avg_score:0.3333333333333333
# precision called!
# target: 920000
# preds:['1357400', '847200', '1041500', '903600', '1087100']
# avg_score:0.39999999999999997

# %% [markdown]
# ### past runs

# %%
songs_dir=r'/home/opalinav/intersect120'
labels_dir=r'/home/opalinav/musi_long120_parsed_results.csv'
datareader=MusicDataReader(songs_dir,labels_dir)
datareader_val=MusicDataReader(songs_dir,labels_dir,split='train')

# %%
song_desc_cols=[
    {"name":"song_description", 'type':str, 'desc': 'text description of the song'}
]

# %%
def search_func(index: chromadb.Collection, query: list[list[float]], k: int) -> list[str]:
    results = index.query(query, n_results=k)
    #pdb.set_trace()
    print(f'resultsssss: {results['ids']}')
    return {'track_id': results['ids'][0]}

# %%
import chromadb.utils.embedding_functions as embedding_functions
openai_ef = embedding_functions.OpenAIEmbeddingFunction(
                api_key=os.environ["OPENAI_API_KEY"],
                model_name="text-embedding-3-small"
            )

# %%
#client = chromadb.PersistentClient(path=r'C:\Users\Opalina\Desktop\Meng\jamendo\chroma120_v1')
client = chromadb.PersistentClient(path=r'/home/opalinav/chroma120_v3')
index = client.get_collection(name="Songs120_v3",embedding_function=openai_ef)

# %%
index._embedding_function

# %%
track_labels = [
    {"name": "track_id", "type": list[str], "desc": "track id of songs most similar to query"},
]

# %%
plan=pz.Dataset(datareader)
plan=plan.sem_add_columns(song_desc_cols)
plan=plan.retrieve(index=index,search_attr='song_description',output_attrs=track_labels,search_func=search_func)#, output_attr_desc='')

# %%
config = pz.QueryProcessorConfig(
        policy=pz.MaxQuality(),
        val_datasource=datareader_val,
        execution_strategy="parallel",
        max_workers=20,
)

# %%
#output=plan.run()

# %%
#df=output.to_df()
#df

# %%
df=output.to_df()
df
# Out:
#                                        audio_content  song_id  \
# 0  [[tensor(0.0119, dtype=torch.float32), tensor(...  1028900
# 1  [[tensor(0.0778, dtype=torch.float32), tensor(...  1009600
# 2  [[tensor(-0.0571, dtype=torch.float32), tensor...  1014400
# 3  [[tensor(0.3735, dtype=torch.float32), tensor(...  1012000
# 4  [[tensor(-0.1565, dtype=torch.float32), tensor...  1037900
#
#                                     song_description   track_id
# 0  ​​The song is a slow, mellow, and emotional ba...  [1116400]
# 1  The song is a traditional Indian classical son...   [920000]
# 2  The song is a fast-paced rock song with a heav...  [1303000]
# 3  The song is a funky, groovy, upbeat, and energ...  [1087100]
# 4  The song is a traditional Indian classical rag...   [920000]

# %%
def precision2(preds: list | None, target_id: list, labels_dir=r'/home/opalinav/musi_long120_parsed_results.csv'):
    'preds is list of song ids returned in query, targets is list of true-value genre tags'
    labels=pd.read_csv(labels_dir, index_col=1)
    correct=0
    targets=set(eval(labels.at[int(target_id),'genre']))
    print(f'targets: {targets}')
    for pred_id in preds:
        pred_genres=set(eval(labels.at[int(pred_id),'genre']))
        print(f'preds: {pred_genres}')
        #if query song has at least onde shared genre tag as target song, then count as correct
        if len(targets&pred_genres)>0:
            correct+=1
    
    return correct/len(preds)

# %%
df['precision'] = df.apply(
    lambda row: precision2(row['track_id'], row['song_id']),
    axis=1
)
# Out:
# targets: {'classical'}
# preds: {'classical'}
# targets: {'soundtrack', 'classical'}
# preds: {'newage', 'soundtrack'}
# targets: {'metal', 'rock', 'alternative'}
# preds: {'rock', 'punkrock'}
# targets: {'ambient', 'soundtrack', 'classical'}
# preds: {'instrumentalpop', 'easylistening'}
# targets: {'newage', 'ambient', 'lounge'}
# preds: {'newage', 'soundtrack'}

# %%
df
# Out:
#                                        audio_content  song_id  \
# 0  [[tensor(0.0119, dtype=torch.float32), tensor(...  1028900
# 1  [[tensor(0.0778, dtype=torch.float32), tensor(...  1009600
# 2  [[tensor(-0.0571, dtype=torch.float32), tensor...  1014400
# 3  [[tensor(0.3735, dtype=torch.float32), tensor(...  1012000
# 4  [[tensor(-0.1565, dtype=torch.float32), tensor...  1037900
#
#                                     song_description   track_id  precision
# 0  ​​The song is a slow, mellow, and emotional ba...  [1116400]        1.0
# 1  The song is a traditional Indian classical son...   [920000]        1.0
# 2  The song is a fast-paced rock song with a heav...  [1303000]        1.0
# 3  The song is a funky, groovy, upbeat, and energ...  [1087100]        0.0
# 4  The song is a traditional Indian classical rag...   [920000]        1.0

# %%
df['precision']
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    0.0
# 4    1.0
# Name: precision, dtype: float64

# %%
df['precision']=df.apply()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 precision_pipeline(1028900,[1116400])
#
# Cell In[31], line 4, in precision_pipeline(song_id, tracks)
#       2 labels=pd.read_csv(labels_dir,index_col=1)
#       3 targets=set(eval(labels.at[int(song_id),'genre']))
# ----> 4 score=precision(tracks,targets)
#       5 return score
#
# NameError: name 'precision' is not defined

# %%
output.execution_stats.to_json()
# Out:
# {'execution_id': '43f75a37bd',
#  'sentinel_plan_stats': {'f20198bc0d': {'plan_id': 'f20198bc0d',
#    'plan_str': " 0. MarshalAndScanDataOp -> Schema[['audio_content', 'song_id']] \n\n 1.1. Schema[['audio_content', 'song_id']] -> LLMConvertBonded -> Schema[['audio_content', 'song_description', 'song_id']]\n    (audio_content, song_id) -> (audio_content, song_descriptio)\n    Model: Model.MUSILINGO_SHORT\n    Prompt Strategy: PromptStrategy.COT_QA\n\n 1.2. Schema[['audio_content', 'song_id']] -> LLMConvertBonded -> Schema[['audio_content', 'song_description', 'song_id']]\n    (audio_content, song_id) -> (audio_content, song_descriptio)\n    Model: Model.MUSILINGO_LONG\n    Prompt Strategy: PromptStrategy.COT_QA\n\n 2.1. Schema[['audio_content', 'song_description', 'song_id']] -> RetrieveOp -> Schema[['audio_content', 'song_description', 'song_id', 'track_id']]\n    (audio_content, song_descriptio) -> (audio_content, song_descriptio)\n    Retrieve: Collection with top 10\n\n 2.2. Schema[['audio_content', 'song_description', 'song_id']] -> RetrieveOp -> Schema[['audio_content', 'song_description', 'song_id', 'track_id']]\n    (audio_content, song_descriptio) -> (audio_content, song_descriptio)\n    Retrieve: Collection with top 3\n\n 2.3. Schema[['audio_content', 'song_description', 'song_id']] -> RetrieveOp -> Schema[['audio_content', 'song_description', 'song_id', 'track_id']]\n    (audio_content, song_descriptio) -> (audio_content, song_descriptio)\n    Retrieve: Collection with top 20\n\n 2.4. Schema[['audio_content', 'song_description', 'song_id']] -> RetrieveOp -> Schema[['audio_content', 'song_description', 'song_id', 'track_id']]\n    (audio_content, song_descriptio) -> (audio_content, song_descriptio)\n    Retrieve: Collection with top 5\n\n 2.5. Schema[['audio_content', 'song_description', 'song_id']] -> RetrieveOp -> Schema[['audio_content', 'song_description', 'song_id', 'track_id']]\n    (audio_content, song_descriptio) -> (audio_content, song_descriptio)\n    Retrieve: Collection with top 15\n\n 2.6. Schema[['audio_content', 'song_description', 'song_id']] -> RetrieveOp -> Schema[['audio_content', 'song_description', 'song_id', 'track_id']]\n    (audio_content, song_descriptio) -> (audio_content, song_descriptio)\n    Retrieve: Collection with top 25\n\n 2.7. Schema[['audio_content', 'song_description', 'song_id']] -> RetrieveOp -> Schema[['audio_content', 'song_description', 'song_id', 'track_id']]\n    (audio_content, song_descriptio) -> (audio_content, song_descriptio)\n    Retrieve: Collection with top 1\n\n",
#    'operator_stats': {'74683bdeae': {'39682ac35a': {'op_id': '39682ac35a',
#       'op_name': 'MarshalAndScanDataOp',
#       'total_op_time': 0.0021562576293945312,
#       'total_op_cost': 0.0,
#       'record_op_stats_lst': [{'record_id': 'd3224808cd',
#         'record_parent_id': None,
#         'record_source_idx': 0,
#         'record_state': {'audio_content': '<bytes>', 'song_id': '816200'},
#         'op_id': '39682ac35a',
#         'logical_op_id': '74683bdeae',
#         'op_name': 'MarshalAndScanDataOp',
#         'time_per_record': 0.0008714199066162109,
#         'cost_per_record': 0.0,
#         'source_op_id': None,
#         'plan_id': 'f20198bc0d',
#         'quality': 1.0,
#         'model_name': None,
#         'answer': None,
#         'input_fields': None,
#         'generated_fields': None,
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.0,
#         'fn_call_duration_secs': 0.0,
#         'total_llm_calls': 0,
#         'total_embedding_llm_calls': 0,
#         'failed_convert': None,
#         'image_operation': None,
#         'op_details': {'generated_fields': "['audio_content', 'song_id']"}},
#        {'record_id': '43ebe95a41',
#         'record_parent_id': None,
#         'record_source_idx': 7,
#         'record_state': {'audio_content': '<bytes>', 'song_id': '913700'},
#         'op_id': '39682ac35a',
#         'logical_op_id': '74683bdeae',
#         'op_name': 'MarshalAndScanDataOp',
#         'time_per_record': 0.00021147727966308594,
#         'cost_per_record': 0.0,
#         'source_op_id': None,
#         'plan_id': 'f20198bc0d',
#         'quality': 1.0,
#         'model_name': None,
#         'answer': None,
#         'input_fields': None,
#         'generated_fields': None,
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.0,
#         'fn_call_duration_secs': 0.0,
#         'total_llm_calls': 0,
#         'total_embedding_llm_calls': 0,
#         'failed_convert': None,
#         'image_operation': None,
#         'op_details': {'generated_fields': "['audio_content', 'song_id']"}},
#        {'record_id': 'ec52895d86',
#         'record_parent_id': None,
#         'record_source_idx': 6,
#         'record_state': {'audio_content': '<bytes>', 'song_id': '903600'},
#         'op_id': '39682ac35a',
#         'logical_op_id': '74683bdeae',
#         'op_name': 'MarshalAndScanDataOp',
#         'time_per_record': 0.0001971721649169922,
#         'cost_per_record': 0.0,
#         'source_op_id': None,
#         'plan_id': 'f20198bc0d',
#         'quality': 1.0,
#         'model_name': None,
#         'answer': None,
#         'input_fields': None,
#         'generated_fields': None,
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.0,
#         'fn_call_duration_secs': 0.0,
#         'total_llm_calls': 0,
#         'total_embedding_llm_calls': 0,
#         'failed_convert': None,
#         'image_operation': None,
#         'op_details': {'generated_fields': "['audio_content', 'song_id']"}},
#        {'record_id': '8447e70785',
#         'record_parent_id': None,
#         'record_source_idx': 9,
#         'record_state': {'audio_content': '<bytes>', 'song_id': '945200'},
#         'op_id': '39682ac35a',
#         'logical_op_id': '74683bdeae',
#         'op_name': 'MarshalAndScanDataOp',
#         'time_per_record': 0.0006203651428222656,
#         'cost_per_record': 0.0,
#         'source_op_id': None,
#         'plan_id': 'f20198bc0d',
#         'quality': 1.0,
#         'model_name': None,
#         'answer': None,
#         'input_fields': None,
#         'generated_fields': None,
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.0,
#         'fn_call_duration_secs': 0.0,
#         'total_llm_calls': 0,
#         'total_embedding_llm_calls': 0,
#         'failed_convert': None,
#         'image_operation': None,
#         'op_details': {'generated_fields': "['audio_content', 'song_id']"}},
#        {'record_id': '4e0a084dd8',
#         'record_parent_id': None,
#         'record_source_idx': 11,
#         'record_state': {'audio_content': '<bytes>', 'song_id': '95400'},
#         'op_id': '39682ac35a',
#         'logical_op_id': '74683bdeae',
#         'op_name': 'MarshalAndScanDataOp',
#         'time_per_record': 0.00025582313537597656,
#         'cost_per_record': 0.0,
#         'source_op_id': None,
#         'plan_id': 'f20198bc0d',
#         'quality': 1.0,
#         'model_name': None,
#         'answer': None,
#         'input_fields': None,
#         'generated_fields': None,
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.0,
#         'fn_call_duration_secs': 0.0,
#         'total_llm_calls': 0,
#         'total_embedding_llm_calls': 0,
#         'failed_convert': None,
#         'image_operation': None,
#         'op_details': {'generated_fields': "['audio_content', 'song_id']"}}],
#       'op_details': {'generated_fields': "['audio_content', 'song_id']"}}},
#     '1922e8cc39': {'ddf645ac78': {'op_id': 'ddf645ac78',
#       'op_name': 'LLMConvertBonded',
#       'total_op_time': 1701.459825515747,
#       'total_op_cost': 0.0,
#       'record_op_stats_lst': [{'record_id': 'aaa1f72fc9',
#         'record_parent_id': 'd3224808cd',
#         'record_source_idx': 0,
#         'record_state': {'audio_content': '<bytes>',
#          'song_id': '816200',
#          'song_description': '\u200bThe song is a slow, mellow, and emotional jazz song. The instruments used are a piano, a double bass, and a saxophone. The mood/theme of the song is melancholic and introspective. The bpm of the song is medium-fast. This song would be played at a romantic dinner or a quiet evening at home.'},
#         'op_id': 'ddf645ac78',
#         'logical_op_id': '1922e8cc39',
#         'op_name': 'LLMConvertBonded',
#         'time_per_record': 282.59136962890625,
#         'cost_per_record': 0.0,
#         'source_op_id': '74683bdeae',
#         'plan_id': 'f20198bc0d',
#         'quality': 1.0,
#         'model_name': 'm-a-p/MusiLingo-short-v1',
#         'answer': {'song_description': '\u200bThe song is a slow, mellow, and emotional jazz song. The instruments used are a piano, a double bass, and a saxophone. The mood/theme of the song is melancholic and introspective. The bpm of the song is medium-fast. This song would be played at a romantic dinner or a quiet evening at home.'},
#         'input_fields': ['audio_content', 'song_id'],
#         'generated_fields': ['song_description'],
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.0,
#         'fn_call_duration_secs': 0.0,
#         'total_llm_calls': 0.0,
#         'total_embedding_llm_calls': 0.0,
#         'failed_convert': False,
#         'image_operation': False,
#         'op_details': {'model': 'm-a-p/MusiLingo-short-v1',
#          'prompt_strategy': 'chain-of-thought-question',
#          'cardinality': 'one-to-one',
#          'udf': 'None',
#          'generated_fields': "['song_description']"}},
#        {'record_id': '63831d08e3',
#         'record_parent_id': '43ebe95a41',
#         'record_source_idx': 7,
#         'record_state': {'audio_content': '<bytes>',
#          'song_id': '913700',
#          'song_description': '\u200bThe song is a traditional Indian classical raga, which is a genre of Indian classical music. The instruments used in the song are the sitar, the tabla, and the harmonium. The mood/theme of the song is devotional and meditative. The song is played at a moderate tempo of around 120 bpm. This song is typically played during religious ceremonies and meditation sessions.'},
#         'op_id': 'ddf645ac78',
#         'logical_op_id': '1922e8cc39',
#         'op_name': 'LLMConvertBonded',
#         'time_per_record': 432.3871533870697,
#         'cost_per_record': 0.0,
#         'source_op_id': '74683bdeae',
#         'plan_id': 'f20198bc0d',
#         'quality': 1.0,
#         'model_name': 'm-a-p/MusiLingo-short-v1',
#         'answer': {'song_description': '\u200bThe song is a traditional Indian classical raga, which is a genre of Indian classical music. The instruments used in the song are the sitar, the tabla, and the harmonium. The mood/theme of the song is devotional and meditative. The song is played at a moderate tempo of around 120 bpm. This song is typically played during religious ceremonies and meditation sessions.'},
#         'input_fields': ['audio_content', 'song_id'],
#         'generated_fields': ['song_description'],
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.0,
#         'fn_call_duration_secs': 0.0,
#         'total_llm_calls': 0.0,
#         'total_embedding_llm_calls': 0.0,
#         'failed_convert': False,
#         'image_operation': False,
#         'op_details': {'model': 'm-a-p/MusiLingo-short-v1',
#          'prompt_strategy': 'chain-of-thought-question',
#          'cardinality': 'one-to-one',
#          'udf': 'None',
#          'generated_fields': "['song_description']"}},
#        {'record_id': '58cfd9f86c',
#         'record_parent_id': 'ec52895d86',
#         'record_source_idx': 6,
#         'record_state': {'audio_content': '<bytes>',
#          'song_id': '903600',
#          'song_description': 'The song is a classical piano piece. The instruments used are a piano and a cello. The mood/theme of the song is melancholic and emotional. The bpm of the song is moderate. This song would be played at a classical concert or a movie soundtrack.'},
#         'op_id': 'ddf645ac78',
#         'logical_op_id': '1922e8cc39',
#         'op_name': 'LLMConvertBonded',
#         'time_per_record': 892.4249522686005,
#         'cost_per_record': 0.0,
#         'source_op_id': '74683bdeae',
#         'plan_id': 'f20198bc0d',
#         'quality': 1.0,
#         'model_name': 'm-a-p/MusiLingo-short-v1',
#         'answer': {'song_description': 'The song is a classical piano piece. The instruments used are a piano and a cello. The mood/theme of the song is melancholic and emotional. The bpm of the song is moderate. This song would be played at a classical concert or a movie soundtrack.'},
#         'input_fields': ['audio_content', 'song_id'],
#         'generated_fields': ['song_description'],
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.0,
#         'fn_call_duration_secs': 0.0,
#         'total_llm_calls': 0.0,
#         'total_embedding_llm_calls': 0.0,
#         'failed_convert': False,
#         'image_operation': False,
#         'op_details': {'model': 'm-a-p/MusiLingo-short-v1',
#          'prompt_strategy': 'chain-of-thought-question',
#          'cardinality': 'one-to-one',
#          'udf': 'None',
#          'generated_fields': "['song_description']"}},
#        {'record_id': '1dc61e29b9',
#         'record_parent_id': '8447e70785',
#         'record_source_idx': 9,
#         'record_state': {'audio_content': '<bytes>',
#          'song_id': '945200',
#          'song_description': 'The song is a dance track with a fast tempo of 128 bpm. It is a happy and upbeat song with a catchy melody and a funky bassline. The song features a synthesizer, a drum machine, and a keyboard. The mood of the song is energetic and lively, perfect for dancing. This song would be played at a dance party or a nightclub.'},
#         'op_id': 'ddf645ac78',
#         'logical_op_id': '1922e8cc39',
#         'op_name': 'LLMConvertBonded',
#         'time_per_record': 49.08640146255493,
#         'cost_per_record': 0.0,
#         'source_op_id': '74683bdeae',
#         'plan_id': 'f20198bc0d',
#         'quality': 1.0,
#         'model_name': 'm-a-p/MusiLingo-short-v1',
#         'answer': {'song_description': 'The song is a dance track with a fast tempo of 128 bpm. It is a happy and upbeat song with a catchy melody and a funky bassline. The song features a synthesizer, a drum machine, and a keyboard. The mood of the song is energetic and lively, perfect for dancing. This song would be played at a dance party or a nightclub.'},
#         'input_fields': ['audio_content', 'song_id'],
#         'generated_fields': ['song_description'],
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.0,
#         'fn_call_duration_secs': 0.0,
#         'total_llm_calls': 0.0,
#         'total_embedding_llm_calls': 0.0,
#         'failed_convert': False,
#         'image_operation': False,
#         'op_details': {'model': 'm-a-p/MusiLingo-short-v1',
#          'prompt_strategy': 'chain-of-thought-question',
#          'cardinality': 'one-to-one',
#          'udf': 'None',
#          'generated_fields': "['song_description']"}},
#        {'record_id': '0d8edf0582',
#         'record_parent_id': '4e0a084dd8',
#         'record_source_idx': 11,
#         'record_state': {'audio_content': '<bytes>',
#          'song_id': '95400',
#          'song_description': 'The song is a slow, mellow, and romantic instrumental piece. It features a saxophone playing a melodic and emotional solo, accompanied by a soft and gentle piano melody. The song has a relaxing and calming mood, perfect for a romantic evening or a chill out session. The tempo is medium-slow, around 80-90 bpm.'},
#         'op_id': 'ddf645ac78',
#         'logical_op_id': '1922e8cc39',
#         'op_name': 'LLMConvertBonded',
#         'time_per_record': 44.96994876861572,
#         'cost_per_record': 0.0,
#         'source_op_id': '74683bdeae',
#         'plan_id': 'f20198bc0d',
#         'quality': 1.0,
#         'model_name': 'm-a-p/MusiLingo-short-v1',
#         'answer': {'song_description': 'The song is a slow, mellow, and romantic instrumental piece. It features a saxophone playing a melodic and emotional solo, accompanied by a soft and gentle piano melody. The song has a relaxing and calming mood, perfect for a romantic evening or a chill out session. The tempo is medium-slow, around 80-90 bpm.'},
#         'input_fields': ['audio_content', 'song_id'],
#         'generated_fields': ['song_description'],
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.0,
#         'fn_call_duration_secs': 0.0,
#         'total_llm_calls': 0.0,
#         'total_embedding_llm_calls': 0.0,
#         'failed_convert': False,
#         'image_operation': False,
#         'op_details': {'model': 'm-a-p/MusiLingo-short-v1',
#          'prompt_strategy': 'chain-of-thought-question',
#          'cardinality': 'one-to-one',
#          'udf': 'None',
#          'generated_fields': "['song_description']"}}],
#       'op_details': {'model': 'm-a-p/MusiLingo-short-v1',
#        'prompt_strategy': 'chain-of-thought-question',
#        'cardinality': 'one-to-one',
#        'udf': 'None',
#        'generated_fields': "['song_description']"}},
#      'f53d9eb9af': {'op_id': 'f53d9eb9af',
#       'op_name': 'LLMConvertBonded',
#       'total_op_time': 2739.2068593502045,
#       'total_op_cost': 0.0,
#       'record_op_stats_lst': [{'record_id': 'aaa1f72fc9',
#         'record_parent_id': 'd3224808cd',
#         'record_source_idx': 0,
#         'record_state': {'audio_content': '<bytes>',
#          'song_id': '816200',
#          'song_description': "The song in question is a melodic piece that can be classified as a ballad. It is characterized by a slow tempo of 60 beats per minute, which creates a soothing and contemplative atmosphere. The song is played on a piano, which is the primary instrument in this composition. The melody is simple yet captivating, and the piano's gentle plucking of the strings creates a soft and soothing sound. The song is a perfect fit for a romantic setting, such as a candlelit dinner or a serene walk in the park. It can also be used as background music for a sentimental scene in a movie or TV show. The song's gentle and calming nature makes it an ideal choice for a relaxing and romantic atmosphere."},
#         'op_id': 'f53d9eb9af',
#         'logical_op_id': '1922e8cc39',
#         'op_name': 'LLMConvertBonded',
#         'time_per_record': 999.4386036396027,
#         'cost_per_record': 0.0,
#         'source_op_id': '74683bdeae',
#         'plan_id': 'f20198bc0d',
#         'quality': 0.0,
#         'model_name': 'm-a-p/MusiLingo-long-v1',
#         'answer': {'song_description': "The song in question is a melodic piece that can be classified as a ballad. It is characterized by a slow tempo of 60 beats per minute, which creates a soothing and contemplative atmosphere. The song is played on a piano, which is the primary instrument in this composition. The melody is simple yet captivating, and the piano's gentle plucking of the strings creates a soft and soothing sound. The song is a perfect fit for a romantic setting, such as a candlelit dinner or a serene walk in the park. It can also be used as background music for a sentimental scene in a movie or TV show. The song's gentle and calming nature makes it an ideal choice for a relaxing and romantic atmosphere."},
#         'input_fields': ['audio_content', 'song_id'],
#         'generated_fields': ['song_description'],
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.0,
#         'fn_call_duration_secs': 0.0,
#         'total_llm_calls': 0.0,
#         'total_embedding_llm_calls': 0.0,
#         'failed_convert': False,
#         'image_operation': False,
#         'op_details': {'model': 'm-a-p/MusiLingo-long-v1',
#          'prompt_strategy': 'chain-of-thought-question',
#          'cardinality': 'one-to-one',
#          'udf': 'None',
#          'generated_fields': "['song_description']"}},
#        {'record_id': '63831d08e3',
#         'record_parent_id': '43ebe95a41',
#         'record_source_idx': 7,
#         'record_state': {'audio_content': '<bytes>',
#          'song_id': '913700',
#          'song_description': "The song in question is a melodic piece that can be classified as a classical instrumental. It is characterized by the use of a piano, which is the primary instrument in this composition. The melody is a gentle, soothing tune that is played at a moderate tempo of 100 beats per minute. The song is best suited for a relaxing atmosphere, such as a peaceful retreat or a meditation session. The melody is simple and straightforward, making it easy to follow and enjoy. The song's gentle, calming nature is sure to create a tranquil and serene ambiance, perfect for unwinding and finding inner peace."},
#         'op_id': 'f53d9eb9af',
#         'logical_op_id': '1922e8cc39',
#         'op_name': 'LLMConvertBonded',
#         'time_per_record': 656.081770658493,
#         'cost_per_record': 0.0,
#         'source_op_id': '74683bdeae',
#         'plan_id': 'f20198bc0d',
#         'quality': 0.0,
#         'model_name': 'm-a-p/MusiLingo-long-v1',
#         'answer': {'song_description': "The song in question is a melodic piece that can be classified as a classical instrumental. It is characterized by the use of a piano, which is the primary instrument in this composition. The melody is a gentle, soothing tune that is played at a moderate tempo of 100 beats per minute. The song is best suited for a relaxing atmosphere, such as a peaceful retreat or a meditation session. The melody is simple and straightforward, making it easy to follow and enjoy. The song's gentle, calming nature is sure to create a tranquil and serene ambiance, perfect for unwinding and finding inner peace."},
#         'input_fields': ['audio_content', 'song_id'],
#         'generated_fields': ['song_description'],
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.0,
#         'fn_call_duration_secs': 0.0,
#         'total_llm_calls': 0.0,
#         'total_embedding_llm_calls': 0.0,
#         'failed_convert': False,
#         'image_operation': False,
#         'op_details': {'model': 'm-a-p/MusiLingo-long-v1',
#          'prompt_strategy': 'chain-of-thought-question',
#          'cardinality': 'one-to-one',
#          'udf': 'None',
#          'generated_fields': "['song_description']"}},
#        {'record_id': '58cfd9f86c',
#         'record_parent_id': 'ec52895d86',
#         'record_source_idx': 6,
#         'record_state': {'audio_content': '<bytes>',
#          'song_id': '903600',
#          'song_description': 'The song is a melodic piece that is characterized by a slow tempo of 60 beats per minute. It is a song that is primarily designed to evoke a sense of nostalgia, with a melancholic and sentimental tone. The song is performed by a male vocalist, who delivers the lyrics with a deep, emotive voice. The song is a ballad, which is a genre that typically focuses on telling a story or expressing a sentimental theme. The instrumentation of the song is primarily dominated by a piano, which provides the melody and harmony. The piano is accompanied by a string section, which adds depth and richness to the overall sound. The song is a perfect fit for a romantic dinner or a quiet evening at home, where the listener can sit back and enjoy the emotional depth of the music. The song is a beautiful representation of the power of music to evoke emotions and transport listeners to a different world.'},
#         'op_id': 'f53d9eb9af',
#         'logical_op_id': '1922e8cc39',
#         'op_name': 'LLMConvertBonded',
#         'time_per_record': 1083.6864850521088,
#         'cost_per_record': 0.0,
#         'source_op_id': '74683bdeae',
#         'plan_id': 'f20198bc0d',
#         'quality': 0.0,
#         'model_name': 'm-a-p/MusiLingo-long-v1',
#         'answer': {'song_description': 'The song is a melodic piece that is characterized by a slow tempo of 60 beats per minute. It is a song that is primarily designed to evoke a sense of nostalgia, with a melancholic and sentimental tone. The song is performed by a male vocalist, who delivers the lyrics with a deep, emotive voice. The song is a ballad, which is a genre that typically focuses on telling a story or expressing a sentimental theme. The instrumentation of the song is primarily dominated by a piano, which provides the melody and harmony. The piano is accompanied by a string section, which adds depth and richness to the overall sound. The song is a perfect fit for a romantic dinner or a quiet evening at home, where the listener can sit back and enjoy the emotional depth of the music. The song is a beautiful representation of the power of music to evoke emotions and transport listeners to a different world.'},
#         'input_fields': ['audio_content', 'song_id'],
#         'generated_fields': ['song_description'],
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.0,
#         'fn_call_duration_secs': 0.0,
#         'total_llm_calls': 0.0,
#         'total_embedding_llm_calls': 0.0,
#         'failed_convert': False,
#         'image_operation': False,
#         'op_details': {'model': 'm-a-p/MusiLingo-long-v1',
#          'prompt_strategy': 'chain-of-thought-question',
#          'cardinality': 'one-to-one',
#          'udf': 'None',
#          'generated_fields': "['song_description']"}}],
#       'op_details': {'model': 'm-a-p/MusiLingo-long-v1',
#        'prompt_strategy': 'chain-of-thought-question',
#        'cardinality': 'one-to-one',
#        'udf': 'None',
#        'generated_fields': "['song_description']"}}},
#     '8b9497b0e0': {'4db601e506': {'op_id': '4db601e506',
#       'op_name': 'RetrieveOp',
#       'total_op_time': 0.0,
#       'total_op_cost': 0.0,
#       'record_op_stats_lst': [],
#       'op_details': {'index': 'Collection',
#        'search_attr': 'song_description',
#        'output_attrs': "[{'name': 'track_id', 'type': list[str], 'desc': 'track id of songs most similar to query'}]",
#        'k': '10',
#        'generated_fields': "['track_id']"}},
#      '5be3c6e49d': {'op_id': '5be3c6e49d',
#       'op_name': 'RetrieveOp',
#       'total_op_time': 0.0,
#       'total_op_cost': 0.0,
#       'record_op_stats_lst': [],
#       'op_details': {'index': 'Collection',
#        'search_attr': 'song_description',
#        'output_attrs': "[{'name': 'track_id', 'type': list[str], 'desc': 'track id of songs most similar to query'}]",
#        'k': '3',
#        'generated_fields': "['track_id']"}},
#      'b30578e66d': {'op_id': 'b30578e66d',
#       'op_name': 'RetrieveOp',
#       'total_op_time': 3.964059352874756,
#       'total_op_cost': 6.880000000000001e-06,
#       'record_op_stats_lst': [{'record_id': '5e0ac040bf',
#         'record_parent_id': 'aaa1f72fc9',
#         'record_source_idx': 0,
#         'record_state': {'audio_content': '<bytes>',
#          'song_id': '816200',
#          'song_description': '\u200bThe song is a slow, mellow, and emotional jazz song. The instruments used are a piano, a double bass, and a saxophone. The mood/theme of the song is melancholic and introspective. The bpm of the song is medium-fast. This song would be played at a romantic dinner or a quiet evening at home.',
#          'track_id': ['1357400',
#           '847200',
#           '1170600',
#           '1041500',
#           '903600',
#           '86200',
#           '1082100',
#           '661300',
#           '816200',
#           '1374300',
#           '1173500',
#           '1081000',
#           '1366700',
#           '1330500',
#           '1116400',
#           '1037900',
#           '659900',
#           '1090700',
#           '752300',
#           '1062500']},
#         'op_id': 'b30578e66d',
#         'logical_op_id': '8b9497b0e0',
#         'op_name': 'RetrieveOp',
#         'time_per_record': 1.2619194984436035,
#         'cost_per_record': 1.3800000000000001e-06,
#         'source_op_id': '1922e8cc39',
#         'plan_id': 'f20198bc0d',
#         'quality': 0.0,
#         'model_name': None,
#         'answer': {'track_id': ['1357400',
#           '847200',
#           '1170600',
#           '1041500',
#           '903600',
#           '86200',
#           '1082100',
#           '661300',
#           '816200',
#           '1374300',
#           '1173500',
#           '1081000',
#           '1366700',
#           '1330500',
#           '1116400',
#           '1037900',
#           '659900',
#           '1090700',
#           '752300',
#           '1062500']},
#         'input_fields': ['audio_content', 'song_description', 'song_id'],
#         'generated_fields': ['track_id'],
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.8525099754333496,
#         'fn_call_duration_secs': 0.4094095230102539,
#         'total_llm_calls': 1,
#         'total_embedding_llm_calls': 1,
#         'failed_convert': None,
#         'image_operation': None,
#         'op_details': {'index': 'Collection',
#          'search_attr': 'song_description',
#          'output_attrs': "[{'name': 'track_id', 'type': list[str], 'desc': 'track id of songs most similar to query'}]",
#          'k': '20',
#          'generated_fields': "['track_id']"}},
#        {'record_id': 'd18a1f7625',
#         'record_parent_id': '63831d08e3',
#         'record_source_idx': 7,
#         'record_state': {'audio_content': '<bytes>',
#          'song_id': '913700',
#          'song_description': '\u200bThe song is a traditional Indian classical raga, which is a genre of Indian classical music. The instruments used in the song are the sitar, the tabla, and the harmonium. The mood/theme of the song is devotional and meditative. The song is played at a moderate tempo of around 120 bpm. This song is typically played during religious ceremonies and meditation sessions.',
#          'track_id': ['757500',
#           '920000',
#           '1129800',
#           '633200',
#           '1339700',
#           '1327700',
#           '635300',
#           '501300',
#           '816200',
#           '7400',
#           '116600',
#           '399500',
#           '86200',
#           '794600',
#           '1163000',
#           '1396500',
#           '661300',
#           '1082100',
#           '752300',
#           '1357400']},
#         'op_id': 'b30578e66d',
#         'logical_op_id': '8b9497b0e0',
#         'op_name': 'RetrieveOp',
#         'time_per_record': 0.866687536239624,
#         'cost_per_record': 1.56e-06,
#         'source_op_id': '1922e8cc39',
#         'plan_id': 'f20198bc0d',
#         'quality': 1.0,
#         'model_name': None,
#         'answer': {'track_id': ['757500',
#           '920000',
#           '1129800',
#           '633200',
#           '1339700',
#           '1327700',
#           '635300',
#           '501300',
#           '816200',
#           '7400',
#           '116600',
#           '399500',
#           '86200',
#           '794600',
#           '1163000',
#           '1396500',
#           '661300',
#           '1082100',
#           '752300',
#           '1357400']},
#         'input_fields': ['audio_content', 'song_description', 'song_id'],
#         'generated_fields': ['track_id'],
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.8354201316833496,
#         'fn_call_duration_secs': 0.031267404556274414,
#         'total_llm_calls': 1,
#         'total_embedding_llm_calls': 1,
#         'failed_convert': None,
#         'image_operation': None,
#         'op_details': {'index': 'Collection',
#          'search_attr': 'song_description',
#          'output_attrs': "[{'name': 'track_id', 'type': list[str], 'desc': 'track id of songs most similar to query'}]",
#          'k': '20',
#          'generated_fields': "['track_id']"}},
#        {'record_id': '3039f40050',
#         'record_parent_id': '58cfd9f86c',
#         'record_source_idx': 6,
#         'record_state': {'audio_content': '<bytes>',
#          'song_id': '903600',
#          'song_description': 'The song is a classical piano piece. The instruments used are a piano and a cello. The mood/theme of the song is melancholic and emotional. The bpm of the song is moderate. This song would be played at a classical concert or a movie soundtrack.',
#          'track_id': ['1009600',
#           '633200',
#           '757500',
#           '1339700',
#           '1266500',
#           '752300',
#           '202200',
#           '1105300',
#           '501300',
#           '1385300',
#           '816200',
#           '920000',
#           '661300',
#           '1082100',
#           '1116400',
#           '682600',
#           '1037900',
#           '1357400',
#           '1081000',
#           '1062500']},
#         'op_id': 'b30578e66d',
#         'logical_op_id': '8b9497b0e0',
#         'op_name': 'RetrieveOp',
#         'time_per_record': 0.7993016242980957,
#         'cost_per_record': 1.06e-06,
#         'source_op_id': '1922e8cc39',
#         'plan_id': 'f20198bc0d',
#         'quality': 1.0,
#         'model_name': None,
#         'answer': {'track_id': ['1009600',
#           '633200',
#           '757500',
#           '1339700',
#           '1266500',
#           '752300',
#           '202200',
#           '1105300',
#           '501300',
#           '1385300',
#           '816200',
#           '920000',
#           '661300',
#           '1082100',
#           '1116400',
#           '682600',
#           '1037900',
#           '1357400',
#           '1081000',
#           '1062500']},
#         'input_fields': ['audio_content', 'song_description', 'song_id'],
#         'generated_fields': ['track_id'],
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.5812809467315674,
#         'fn_call_duration_secs': 0.21802067756652832,
#         'total_llm_calls': 1,
#         'total_embedding_llm_calls': 1,
#         'failed_convert': None,
#         'image_operation': None,
#         'op_details': {'index': 'Collection',
#          'search_attr': 'song_description',
#          'output_attrs': "[{'name': 'track_id', 'type': list[str], 'desc': 'track id of songs most similar to query'}]",
#          'k': '20',
#          'generated_fields': "['track_id']"}},
#        {'record_id': '452012714a',
#         'record_parent_id': '1dc61e29b9',
#         'record_source_idx': 9,
#         'record_state': {'audio_content': '<bytes>',
#          'song_id': '945200',
#          'song_description': 'The song is a dance track with a fast tempo of 128 bpm. It is a happy and upbeat song with a catchy melody and a funky bassline. The song features a synthesizer, a drum machine, and a keyboard. The mood of the song is energetic and lively, perfect for dancing. This song would be played at a dance party or a nightclub.',
#          'track_id': ['945200',
#           '950100',
#           '1420700',
#           '1383900',
#           '1121400',
#           '1420500',
#           '1372200',
#           '872000',
#           '1155000',
#           '501200',
#           '1277700',
#           '1371800',
#           '1084200',
#           '1132200',
#           '1164200',
#           '1250200',
#           '1353300',
#           '206000',
#           '1076600',
#           '1088000']},
#         'op_id': 'b30578e66d',
#         'logical_op_id': '8b9497b0e0',
#         'op_name': 'RetrieveOp',
#         'time_per_record': 0.6016650199890137,
#         'cost_per_record': 1.48e-06,
#         'source_op_id': '1922e8cc39',
#         'plan_id': 'f20198bc0d',
#         'quality': 1.0,
#         'model_name': None,
#         'answer': {'track_id': ['945200',
#           '950100',
#           '1420700',
#           '1383900',
#           '1121400',
#           '1420500',
#           '1372200',
#           '872000',
#           '1155000',
#           '501200',
#           '1277700',
#           '1371800',
#           '1084200',
#           '1132200',
#           '1164200',
#           '1250200',
#           '1353300',
#           '206000',
#           '1076600',
#           '1088000']},
#         'input_fields': ['audio_content', 'song_description', 'song_id'],
#         'generated_fields': ['track_id'],
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.5941150188446045,
#         'fn_call_duration_secs': 0.00755000114440918,
#         'total_llm_calls': 1,
#         'total_embedding_llm_calls': 1,
#         'failed_convert': None,
#         'image_operation': None,
#         'op_details': {'index': 'Collection',
#          'search_attr': 'song_description',
#          'output_attrs': "[{'name': 'track_id', 'type': list[str], 'desc': 'track id of songs most similar to query'}]",
#          'k': '20',
#          'generated_fields': "['track_id']"}},
#        {'record_id': 'fcebeb52d7',
#         'record_parent_id': '0d8edf0582',
#         'record_source_idx': 11,
#         'record_state': {'audio_content': '<bytes>',
#          'song_id': '95400',
#          'song_description': 'The song is a slow, mellow, and romantic instrumental piece. It features a saxophone playing a melodic and emotional solo, accompanied by a soft and gentle piano melody. The song has a relaxing and calming mood, perfect for a romantic evening or a chill out session. The tempo is medium-slow, around 80-90 bpm.',
#          'track_id': ['1357400',
#           '1082100',
#           '1116400',
#           '1041500',
#           '659900',
#           '903600',
#           '1081000',
#           '1037900',
#           '752300',
#           '501300',
#           '847200',
#           '633200',
#           '661300',
#           '816200',
#           '1173500',
#           '1366700',
#           '635300',
#           '1170600',
#           '1129800',
#           '920000']},
#         'op_id': 'b30578e66d',
#         'logical_op_id': '8b9497b0e0',
#         'op_name': 'RetrieveOp',
#         'time_per_record': 0.43448567390441895,
#         'cost_per_record': 1.4e-06,
#         'source_op_id': '1922e8cc39',
#         'plan_id': 'f20198bc0d',
#         'quality': 1.0,
#         'model_name': None,
#         'answer': {'track_id': ['1357400',
#           '1082100',
#           '1116400',
#           '1041500',
#           '659900',
#           '903600',
#           '1081000',
#           '1037900',
#           '752300',
#           '501300',
#           '847200',
#           '633200',
#           '661300',
#           '816200',
#           '1173500',
#           '1366700',
#           '635300',
#           '1170600',
#           '1129800',
#           '920000']},
#         'input_fields': ['audio_content', 'song_description', 'song_id'],
#         'generated_fields': ['track_id'],
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.4160497188568115,
#         'fn_call_duration_secs': 0.018435955047607422,
#         'total_llm_calls': 1,
#         'total_embedding_llm_calls': 1,
#         'failed_convert': None,
#         'image_operation': None,
#         'op_details': {'index': 'Collection',
#          'search_attr': 'song_description',
#          'output_attrs': "[{'name': 'track_id', 'type': list[str], 'desc': 'track id of songs most similar to query'}]",
#          'k': '20',
#          'generated_fields': "['track_id']"}}],
#       'op_details': {'index': 'Collection',
#        'search_attr': 'song_description',
#        'output_attrs': "[{'name': 'track_id', 'type': list[str], 'desc': 'track id of songs most similar to query'}]",
#        'k': '20',
#        'generated_fields': "['track_id']"}},
#      'c1ee994356': {'op_id': 'c1ee994356',
#       'op_name': 'RetrieveOp',
#       'total_op_time': 3.231210231781006,
#       'total_op_cost': 4.000000000000001e-06,
#       'record_op_stats_lst': [{'record_id': '5e0ac040bf',
#         'record_parent_id': 'aaa1f72fc9',
#         'record_source_idx': 0,
#         'record_state': {'audio_content': '<bytes>',
#          'song_id': '816200',
#          'song_description': '\u200bThe song is a slow, mellow, and emotional jazz song. The instruments used are a piano, a double bass, and a saxophone. The mood/theme of the song is melancholic and introspective. The bpm of the song is medium-fast. This song would be played at a romantic dinner or a quiet evening at home.',
#          'track_id': ['1357400', '847200', '1170600', '1041500', '903600']},
#         'op_id': 'c1ee994356',
#         'logical_op_id': '8b9497b0e0',
#         'op_name': 'RetrieveOp',
#         'time_per_record': 0.7357637882232666,
#         'cost_per_record': 1.3800000000000001e-06,
#         'source_op_id': '1922e8cc39',
#         'plan_id': 'f20198bc0d',
#         'quality': 1.0,
#         'model_name': None,
#         'answer': {'track_id': ['1357400',
#           '847200',
#           '1170600',
#           '1041500',
#           '903600']},
#         'input_fields': ['audio_content', 'song_description', 'song_id'],
#         'generated_fields': ['track_id'],
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.5791473388671875,
#         'fn_call_duration_secs': 0.1566164493560791,
#         'total_llm_calls': 1,
#         'total_embedding_llm_calls': 1,
#         'failed_convert': None,
#         'image_operation': None,
#         'op_details': {'index': 'Collection',
#          'search_attr': 'song_description',
#          'output_attrs': "[{'name': 'track_id', 'type': list[str], 'desc': 'track id of songs most similar to query'}]",
#          'k': '5',
#          'generated_fields': "['track_id']"}},
#        {'record_id': 'd18a1f7625',
#         'record_parent_id': '63831d08e3',
#         'record_source_idx': 7,
#         'record_state': {'audio_content': '<bytes>',
#          'song_id': '913700',
#          'song_description': '\u200bThe song is a traditional Indian classical raga, which is a genre of Indian classical music. The instruments used in the song are the sitar, the tabla, and the harmonium. The mood/theme of the song is devotional and meditative. The song is played at a moderate tempo of around 120 bpm. This song is typically played during religious ceremonies and meditation sessions.',
#          'track_id': ['757500', '920000', '1129800', '633200', '1339700']},
#         'op_id': 'c1ee994356',
#         'logical_op_id': '8b9497b0e0',
#         'op_name': 'RetrieveOp',
#         'time_per_record': 1.2280752658843994,
#         'cost_per_record': 1.56e-06,
#         'source_op_id': '1922e8cc39',
#         'plan_id': 'f20198bc0d',
#         'quality': 0.0,
#         'model_name': None,
#         'answer': {'track_id': ['757500',
#           '920000',
#           '1129800',
#           '633200',
#           '1339700']},
#         'input_fields': ['audio_content', 'song_description', 'song_id'],
#         'generated_fields': ['track_id'],
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 0.9832038879394531,
#         'fn_call_duration_secs': 0.2448713779449463,
#         'total_llm_calls': 1,
#         'total_embedding_llm_calls': 1,
#         'failed_convert': None,
#         'image_operation': None,
#         'op_details': {'index': 'Collection',
#          'search_attr': 'song_description',
#          'output_attrs': "[{'name': 'track_id', 'type': list[str], 'desc': 'track id of songs most similar to query'}]",
#          'k': '5',
#          'generated_fields': "['track_id']"}},
#        {'record_id': '3039f40050',
#         'record_parent_id': '58cfd9f86c',
#         'record_source_idx': 6,
#         'record_state': {'audio_content': '<bytes>',
#          'song_id': '903600',
#          'song_description': 'The song is a classical piano piece. The instruments used are a piano and a cello. The mood/theme of the song is melancholic and emotional. The bpm of the song is moderate. This song would be played at a classical concert or a movie soundtrack.',
#          'track_id': ['1009600', '633200', '757500', '1339700', '1266500']},
#         'op_id': 'c1ee994356',
#         'logical_op_id': '8b9497b0e0',
#         'op_name': 'RetrieveOp',
#         'time_per_record': 1.2673711776733398,
#         'cost_per_record': 1.06e-06,
#         'source_op_id': '1922e8cc39',
#         'plan_id': 'f20198bc0d',
#         'quality': 0.0,
#         'model_name': None,
#         'answer': {'track_id': ['1009600',
#           '633200',
#           '757500',
#           '1339700',
#           '1266500']},
#         'input_fields': ['audio_content', 'song_description', 'song_id'],
#         'generated_fields': ['track_id'],
#         'total_input_tokens': 0.0,
#         'total_output_tokens': 0.0,
#         'total_input_cost': 0.0,
#         'total_output_cost': 0.0,
#         'filter_str': None,
#         'passed_operator': True,
#         'llm_call_duration_secs': 1.068857192993164,
#         'fn_call_duration_secs': 0.19851398468017578,
#         'total_llm_calls': 1,
#         'total_embedding_llm_calls': 1,
#         'failed_convert': None,
#         'image_operation': None,
#         'op_details': {'index': 'Collection',
#          'search_attr': 'song_description',
#          'output_attrs': "[{'name': 'track_id', 'type': list[str], 'desc': 'track id of songs most similar to query'}]",
#          'k': '5',
#          'generated_fields': "['track_id']"}}],
#       'op_details': {'index': 'Collection',
#        'search_attr': 'song_description',
#        'output_attrs': "[{'name': 'track_id', 'type': list[str], 'desc': 'track id of songs most similar to query'}]",
#        'k': '5',
#        'generated_fields': "['track_id']"}},
#      'ebae6b0194': {'op_id': 'ebae6b0194',
#       'op_name': 'RetrieveOp',
#       'total_op_time': 0.0,
#       'total_op_cost': 0.0,
#       'record_op_stats_lst': [],
#       'op_details': {'index': 'Collection',
#        'search_attr': 'song_description',
#        'output_attrs': "[{'name': 'track_id', 'type': list[str], 'desc': 'track id of songs most similar to query'}]",
#        'k': '15',
#        'generated_fields': "['track_id']"}},
#      'f0437126c7': {'op_id': 'f0437126c7',
#       'op_name': 'RetrieveOp',
#       'total_op_time': 0.0,
#       'total_op_cost': 0.0,
# ...
#        'op_name': 'LLMConvertBonded',
#        'time_per_record': 168.84549045562744,
#        'cost_per_record': 0.0,
#        'source_op_id': '39682ac35a',
#        'plan_id': '8205a7a3a0',
#        'quality': None,
#        'model_name': 'm-a-p/MusiLingo-short-v1',
#        'answer': {'song_description': 'The song is a funky, groovy, upbeat, and energetic instrumental song. It is played with a funky bassline, a groovy drum beat, and a catchy melody. The song has a fast tempo of 120 bpm. It is suitable for a party, a dance party, a nightclub, a concert, and a celebration.'},
#        'input_fields': ['audio_content', 'song_id'],
#        'generated_fields': ['song_description'],
#        'total_input_tokens': 0.0,
#        'total_output_tokens': 0.0,
#        'total_input_cost': 0.0,
#        'total_output_cost': 0.0,
#        'filter_str': None,
#        'passed_operator': True,
#        'llm_call_duration_secs': 0.0,
#        'fn_call_duration_secs': 0.0,
#        'total_llm_calls': 0.0,
#        'total_embedding_llm_calls': 0.0,
#        'failed_convert': False,
#        'image_operation': False,
#        'op_details': {'model': 'm-a-p/MusiLingo-short-v1',
#         'prompt_strategy': 'chain-of-thought-question',
#         'cardinality': 'one-to-one',
#         'udf': 'None',
#         'generated_fields': "['song_description']"}},
#       {'record_id': '78d88a52d0',
#        'record_parent_id': 'f90028dd49',
#        'record_source_idx': 4,
#        'record_state': {'audio_content': '<bytes>',
#         'song_id': '1037900',
#         'song_description': 'The song is a traditional Indian classical raga, which is a melody-based genre of music. The instruments used are the sitar, sarod, and tabla. The mood/theme of the song is devotional and meditative. The song is played at a moderate tempo of 120 bpm. This song would be played at a religious ceremony or during a meditation session.'},
#        'op_id': 'ddf645ac78',
#        'logical_op_id': '1922e8cc39',
#        'op_name': 'LLMConvertBonded',
#        'time_per_record': 197.13142848014832,
#        'cost_per_record': 0.0,
#        'source_op_id': '39682ac35a',
#        'plan_id': '8205a7a3a0',
#        'quality': None,
#        'model_name': 'm-a-p/MusiLingo-short-v1',
#        'answer': {'song_description': 'The song is a traditional Indian classical raga, which is a melody-based genre of music. The instruments used are the sitar, sarod, and tabla. The mood/theme of the song is devotional and meditative. The song is played at a moderate tempo of 120 bpm. This song would be played at a religious ceremony or during a meditation session.'},
#        'input_fields': ['audio_content', 'song_id'],
#        'generated_fields': ['song_description'],
#        'total_input_tokens': 0.0,
#        'total_output_tokens': 0.0,
#        'total_input_cost': 0.0,
#        'total_output_cost': 0.0,
#        'filter_str': None,
#        'passed_operator': True,
#        'llm_call_duration_secs': 0.0,
#        'fn_call_duration_secs': 0.0,
#        'total_llm_calls': 0.0,
#        'total_embedding_llm_calls': 0.0,
#        'failed_convert': False,
#        'image_operation': False,
#        'op_details': {'model': 'm-a-p/MusiLingo-short-v1',
#         'prompt_strategy': 'chain-of-thought-question',
#         'cardinality': 'one-to-one',
#         'udf': 'None',
#         'generated_fields': "['song_description']"}}],
#      'op_details': {'model': 'm-a-p/MusiLingo-short-v1',
#       'prompt_strategy': 'chain-of-thought-question',
#       'cardinality': 'one-to-one',
#       'udf': 'None',
#       'generated_fields': "['song_description']"}},
#     'fa76f907b4': {'op_id': 'fa76f907b4',
#      'op_name': 'RetrieveOp',
#      'total_op_time': 2.617938995361328,
#      'total_op_cost': 6.62e-06,
#      'record_op_stats_lst': [{'record_id': 'cb135c70fd',
#        'record_parent_id': 'f3038bbbba',
#        'record_source_idx': 3,
#        'record_state': {'audio_content': '<bytes>',
#         'song_id': '1028900',
#         'song_description': '\u200b\u200bThe song is a slow, mellow, and emotional ballad. It is played on a piano and features a male vocalist singing in a low and emotional tone. The song has a slow tempo of 60 bpm and is suitable for a romantic or emotional occasion.',
#         'track_id': ['1116400']},
#        'op_id': 'fa76f907b4',
#        'logical_op_id': '8b9497b0e0',
#        'op_name': 'RetrieveOp',
#        'time_per_record': 0.3096487522125244,
#        'cost_per_record': 1.08e-06,
#        'source_op_id': 'ddf645ac78',
#        'plan_id': '8205a7a3a0',
#        'quality': None,
#        'model_name': None,
#        'answer': {'track_id': ['1116400']},
#        'input_fields': ['audio_content', 'song_description', 'song_id'],
#        'generated_fields': ['track_id'],
#        'total_input_tokens': 0.0,
#        'total_output_tokens': 0.0,
#        'total_input_cost': 0.0,
#        'total_output_cost': 0.0,
#        'filter_str': None,
#        'passed_operator': True,
#        'llm_call_duration_secs': 0.293536901473999,
#        'fn_call_duration_secs': 0.01611185073852539,
#        'total_llm_calls': 1,
#        'total_embedding_llm_calls': 1,
#        'failed_convert': None,
#        'image_operation': None,
#        'op_details': {'index': 'Collection',
#         'search_attr': 'song_description',
#         'output_attrs': "[{'name': 'track_id', 'type': list[str], 'desc': 'track id of songs most similar to query'}]",
#         'k': '1',
#         'generated_fields': "['track_id']"}},
#       {'record_id': '5e0ac040bf',
#        'record_parent_id': 'aaa1f72fc9',
#        'record_source_idx': 0,
#        'record_state': {'audio_content': '<bytes>',
#         'song_id': '1009600',
#         'song_description': 'The song is a traditional Indian classical song in the Raga Bhimpalasi genre. The instruments used are the sitar, tabla, and harmonium. The mood/theme of the song is devotional and contemplative. The song has a medium tempo of 120 bpm. The song is typically played during religious ceremonies and festivals.',
#         'track_id': ['920000']},
#        'op_id': 'fa76f907b4',
#        'logical_op_id': '8b9497b0e0',
#        'op_name': 'RetrieveOp',
#        'time_per_record': 0.3157064914703369,
#        'cost_per_record': 1.34e-06,
#        'source_op_id': 'ddf645ac78',
#        'plan_id': '8205a7a3a0',
#        'quality': None,
#        'model_name': None,
#        'answer': {'track_id': ['920000']},
#        'input_fields': ['audio_content', 'song_description', 'song_id'],
#        'generated_fields': ['track_id'],
#        'total_input_tokens': 0.0,
#        'total_output_tokens': 0.0,
#        'total_input_cost': 0.0,
#        'total_output_cost': 0.0,
#        'filter_str': None,
#        'passed_operator': True,
#        'llm_call_duration_secs': 0.3003859519958496,
#        'fn_call_duration_secs': 0.015320539474487305,
#        'total_llm_calls': 1,
#        'total_embedding_llm_calls': 1,
#        'failed_convert': None,
#        'image_operation': None,
#        'op_details': {'index': 'Collection',
#         'search_attr': 'song_description',
#         'output_attrs': "[{'name': 'track_id', 'type': list[str], 'desc': 'track id of songs most similar to query'}]",
#         'k': '1',
#         'generated_fields': "['track_id']"}},
#       {'record_id': '501976f06f',
#        'record_parent_id': 'e9314ec8f9',
#        'record_source_idx': 2,
#        'record_state': {'audio_content': '<bytes>',
#         'song_id': '1014400',
#         'song_description': 'The song is a fast-paced rock song with a heavy guitar riff. The song features a distorted bass guitar, a fast drum beat, and a high-pitched guitar solo. The song has a fast tempo of around 120 bpm. The song is energetic and aggressive, making it suitable for playing at a rock concert or a sports event.',
#         'track_id': ['1303000']},
#        'op_id': 'fa76f907b4',
#        'logical_op_id': '8b9497b0e0',
#        'op_name': 'RetrieveOp',
#        'time_per_record': 0.6187806129455566,
#        'cost_per_record': 1.3600000000000001e-06,
#        'source_op_id': 'ddf645ac78',
#        'plan_id': '8205a7a3a0',
#        'quality': None,
#        'model_name': None,
#        'answer': {'track_id': ['1303000']},
#        'input_fields': ['audio_content', 'song_description', 'song_id'],
#        'generated_fields': ['track_id'],
#        'total_input_tokens': 0.0,
#        'total_output_tokens': 0.0,
#        'total_input_cost': 0.0,
#        'total_output_cost': 0.0,
#        'filter_str': None,
#        'passed_operator': True,
#        'llm_call_duration_secs': 0.60015869140625,
#        'fn_call_duration_secs': 0.01862192153930664,
#        'total_llm_calls': 1,
#        'total_embedding_llm_calls': 1,
#        'failed_convert': None,
#        'image_operation': None,
#        'op_details': {'index': 'Collection',
#         'search_attr': 'song_description',
#         'output_attrs': "[{'name': 'track_id', 'type': list[str], 'desc': 'track id of songs most similar to query'}]",
#         'k': '1',
#         'generated_fields': "['track_id']"}},
#       {'record_id': '3dea618429',
#        'record_parent_id': '3344fd8d3e',
#        'record_source_idx': 1,
#        'record_state': {'audio_content': '<bytes>',
#         'song_id': '1012000',
#         'song_description': 'The song is a funky, groovy, upbeat, and energetic instrumental song. It is played with a funky bassline, a groovy drum beat, and a catchy melody. The song has a fast tempo of 120 bpm. It is suitable for a party, a dance party, a nightclub, a concert, and a celebration.',
#         'track_id': ['1087100']},
#        'op_id': 'fa76f907b4',
#        'logical_op_id': '8b9497b0e0',
#        'op_name': 'RetrieveOp',
#        'time_per_record': 0.638704776763916,
#        'cost_per_record': 1.3600000000000001e-06,
#        'source_op_id': 'ddf645ac78',
#        'plan_id': '8205a7a3a0',
#        'quality': None,
#        'model_name': None,
#        'answer': {'track_id': ['1087100']},
#        'input_fields': ['audio_content', 'song_description', 'song_id'],
#        'generated_fields': ['track_id'],
#        'total_input_tokens': 0.0,
#        'total_output_tokens': 0.0,
#        'total_input_cost': 0.0,
#        'total_output_cost': 0.0,
#        'filter_str': None,
#        'passed_operator': True,
#        'llm_call_duration_secs': 0.622450590133667,
#        'fn_call_duration_secs': 0.016254186630249023,
#        'total_llm_calls': 1,
#        'total_embedding_llm_calls': 1,
#        'failed_convert': None,
#        'image_operation': None,
#        'op_details': {'index': 'Collection',
#         'search_attr': 'song_description',
#         'output_attrs': "[{'name': 'track_id', 'type': list[str], 'desc': 'track id of songs most similar to query'}]",
#         'k': '1',
#         'generated_fields': "['track_id']"}},
#       {'record_id': 'cdda988aaa',
#        'record_parent_id': '78d88a52d0',
#        'record_source_idx': 4,
#        'record_state': {'audio_content': '<bytes>',
#         'song_id': '1037900',
#         'song_description': 'The song is a traditional Indian classical raga, which is a melody-based genre of music. The instruments used are the sitar, sarod, and tabla. The mood/theme of the song is devotional and meditative. The song is played at a moderate tempo of 120 bpm. This song would be played at a religious ceremony or during a meditation session.',
#         'track_id': ['920000']},
#        'op_id': 'fa76f907b4',
#        'logical_op_id': '8b9497b0e0',
#        'op_name': 'RetrieveOp',
#        'time_per_record': 0.7350983619689941,
#        'cost_per_record': 1.48e-06,
#        'source_op_id': 'ddf645ac78',
#        'plan_id': '8205a7a3a0',
#        'quality': None,
#        'model_name': None,
#        'answer': {'track_id': ['920000']},
#        'input_fields': ['audio_content', 'song_description', 'song_id'],
#        'generated_fields': ['track_id'],
#        'total_input_tokens': 0.0,
#        'total_output_tokens': 0.0,
#        'total_input_cost': 0.0,
#        'total_output_cost': 0.0,
#        'filter_str': None,
#        'passed_operator': True,
#        'llm_call_duration_secs': 0.7194280624389648,
#        'fn_call_duration_secs': 0.015670299530029297,
#        'total_llm_calls': 1,
#        'total_embedding_llm_calls': 1,
#        'failed_convert': None,
#        'image_operation': None,
#        'op_details': {'index': 'Collection',
#         'search_attr': 'song_description',
#         'output_attrs': "[{'name': 'track_id', 'type': list[str], 'desc': 'track id of songs most similar to query'}]",
#         'k': '1',
#         'generated_fields': "['track_id']"}}],
#      'op_details': {'index': 'Collection',
#       'search_attr': 'song_description',
#       'output_attrs': "[{'name': 'track_id', 'type': list[str], 'desc': 'track id of songs most similar to query'}]",
#       'k': '1',
#       'generated_fields': "['track_id']"}}},
#    'total_plan_time': 199.58483219146729,
#    'total_plan_cost': 6.62e-06}},
#  'optimization_time': 1182.1364951133728,
#  'optimization_cost': 1.6360000000000003e-05,
#  'plan_execution_time': 199.6449830532074,
#  'plan_execution_cost': 6.62e-06,
#  'total_execution_time': 1381.7814781665802,
#  'total_execution_cost': 2.2980000000000004e-05,
#  'sentinel_plan_strs': {'f20198bc0d': " 0. MarshalAndScanDataOp -> Schema[['audio_content', 'song_id']] \n\n 1.1. Schema[['audio_content', 'song_id']] -> LLMConvertBonded -> Schema[['audio_content', 'song_description', 'song_id']]\n    (audio_content, song_id) -> (audio_content, song_descriptio)\n    Model: Model.MUSILINGO_SHORT\n    Prompt Strategy: PromptStrategy.COT_QA\n\n 1.2. Schema[['audio_content', 'song_id']] -> LLMConvertBonded -> Schema[['audio_content', 'song_description', 'song_id']]\n    (audio_content, song_id) -> (audio_content, song_descriptio)\n    Model: Model.MUSILINGO_LONG\n    Prompt Strategy: PromptStrategy.COT_QA\n\n 2.1. Schema[['audio_content', 'song_description', 'song_id']] -> RetrieveOp -> Schema[['audio_content', 'song_description', 'song_id', 'track_id']]\n    (audio_content, song_descriptio) -> (audio_content, song_descriptio)\n    Retrieve: Collection with top 10\n\n 2.2. Schema[['audio_content', 'song_description', 'song_id']] -> RetrieveOp -> Schema[['audio_content', 'song_description', 'song_id', 'track_id']]\n    (audio_content, song_descriptio) -> (audio_content, song_descriptio)\n    Retrieve: Collection with top 3\n\n 2.3. Schema[['audio_content', 'song_description', 'song_id']] -> RetrieveOp -> Schema[['audio_content', 'song_description', 'song_id', 'track_id']]\n    (audio_content, song_descriptio) -> (audio_content, song_descriptio)\n    Retrieve: Collection with top 20\n\n 2.4. Schema[['audio_content', 'song_description', 'song_id']] -> RetrieveOp -> Schema[['audio_content', 'song_description', 'song_id', 'track_id']]\n    (audio_content, song_descriptio) -> (audio_content, song_descriptio)\n    Retrieve: Collection with top 5\n\n 2.5. Schema[['audio_content', 'song_description', 'song_id']] -> RetrieveOp -> Schema[['audio_content', 'song_description', 'song_id', 'track_id']]\n    (audio_content, song_descriptio) -> (audio_content, song_descriptio)\n    Retrieve: Collection with top 15\n\n 2.6. Schema[['audio_content', 'song_description', 'song_id']] -> RetrieveOp -> Schema[['audio_content', 'song_description', 'song_id', 'track_id']]\n    (audio_content, song_descriptio) -> (audio_content, song_descriptio)\n    Retrieve: Collection with top 25\n\n 2.7. Schema[['audio_content', 'song_description', 'song_id']] -> RetrieveOp -> Schema[['audio_content', 'song_description', 'song_id', 'track_id']]\n    (audio_content, song_descriptio) -> (audio_content, song_descriptio)\n    Retrieve: Collection with top 1\n\n"},
#  'plan_strs': {'8205a7a3a0': " 0. MarshalAndScanDataOp -> Schema[['audio_content', 'song_id']] \n\n 1. Schema[['audio_content', 'song_id']] -> LLMConvertBonded -> Schema[['audio_content', 'song_description', 'song_id']]\n    (audio_content, song_id) -> (audio_content, song_descriptio)\n    Model: Model.MUSILINGO_SHORT\n    Prompt Strategy: PromptStrategy.COT_QA\n\n 2. Schema[['audio_content', 'song_description', 'song_id']] -> RetrieveOp -> Schema[['audio_content', 'song_description', 'song_id', 'track_id']]\n    (audio_content, song_descriptio) -> (audio_content, song_descriptio)\n    Retrieve: Collection with top 1\n\n"}}

# %%
df=output.to_df()
df
# Out:
#                                        audio_content  song_id  \
# 0  [[tensor(0.0141, dtype=torch.float32), tensor(...  1009600
# 1  [[tensor(-0.0986, dtype=torch.float32), tensor...  1012000
# 2  [[tensor(-0.0020, dtype=torch.float32), tensor...  1037900
# 3  [[tensor(-0.0616, dtype=torch.float32), tensor...  1014400
# 4  [[tensor(-0.0192, dtype=torch.float32), tensor...  1028900
#
#                                     song_description track_id
# 0  The song is a slow, mellow, and romantic instr...       []
# 1  The song is a funky instrumental with a groovy...       []
# 2  The song is a traditional Irish folk song. It ...       []
# 3  ​​The song is a slow and mellow instrumental p...       []
# 4  ​​The song is a slow, romantic ballad with a b...       []

# %%
df=output.to_df()
df
# Out:
#                                        audio_content  song_id  \
# 0  [[tensor(0.0967), tensor(0.1461), tensor(0.138...  1012000
# 1  [[tensor(0.0620), tensor(0.0968), tensor(0.095...  1028900
# 2  [[tensor(0.0039), tensor(-0.0004), tensor(-0.0...  1037900
# 3  [[tensor(0.0039), tensor(0.0049), tensor(-0.04...  1014400
# 4  [[tensor(-0.1304), tensor(-0.1827), tensor(-0....  1009600
#
#                                     song_description   track_id
# 0  The song is a melodic composition that can be ...  [1398100]
# 1  The song is a melodic piece that can be classi...  [1082100]
# 2  The song in question is a melodic piece that c...  [1082100]
# 3  The song in question is a melodic rock piece, ...  [1155900]
# 4  The song is a melodic piece that is characteri...  [1082100]

# %%
output=plan.run()
# Out:
# FIELDS[("Schema[['audio_content', 'song_id']].959fe542c9.audio_content", True), ("Schema[['audio_content', 'song_id']].959fe542c9.song_id", False)]
# FIELDS2
# [True, False]
# convert.py: m-a-p/MusiLingo-long-v1
# Loading Audio Encoder
# WARNING: feature_extractor_cqt requires the libray 'nnAudio'
# /home/opalinav/palimpzest/audio_pz2/lib/python3.12/site-packages/timm/models/hub.py:4: FutureWarning: Importing from timm.models.hub is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565 - if you loaded a llama tokenizer from a GGUF file you can ignore this message
# Loading Audio Encoder Done
# Loading LLAMA
# LlamaForCausalLM has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# convert.py: m-a-p/MusiLingo-short-v1
# Loading Audio Encoder
# Loading Audio Encoder Done
# Loading LLAMA
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# convert.py: m-a-p/MusiLingo-long-v1
# Loading Audio Encoder
# Loading Audio Encoder Done
# Loading LLAMA
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# convert.py: m-a-p/MusiLingo-long-v1
# Loading Audio Encoder
# Loading Audio Encoder Done
# Loading LLAMA
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Output()
# RIGHT CALL:generators.py
# convert.py:['audio_content', 'song_description', 'song_id']
# convert.py, field:audio_content
# convert.py, field:song_description
# convert.py, field:song_id
# RIGHT CALL:generators.py
# convert.py:['audio_content', 'song_description', 'song_id']
# convert.py, field:audio_content
# convert.py, field:song_description
# convert.py, field:song_id
# RIGHT CALL:generators.py
# convert.py:['audio_content', 'song_description', 'song_id']
# convert.py, field:audio_content
# convert.py, field:song_description
# convert.py, field:song_id
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Total time: 228.13s
# Total cost: $0.0000

# %%
output.data_records
# Out:
# [DataRecord(audio_content=tensor([[-0.0423, -0.0612, -0.0575,  ..., -0.1701, -0.2124, -0.0549]]), song_description='The song is a melodic piece that is characterized by a slow tempo of 60 beats per minute. It is a song that is primarily instrumental, with the main focus being on the piano. The melody is a simple one, with a repetitive pattern that is played on the piano. The song is a ballad, which is a genre that is known for its emotional and sentimental nature. The mood of the song is one of sadness, with the melody evoking feelings of melancholy and longing. The theme of the song is one of love, with the melody expressing the pain of a broken heart. The song is best suited for a romantic setting, such as a candlelit dinner or a quiet night out. It is a song that can evoke a range of emotions, from nostalgia to heartbreak, making it a perfect choice for a romantic setting.', song_id='1009600', track_id=['1037900']),
#  DataRecord(audio_content=tensor([[ 0.2288,  0.3258,  0.2984,  ..., -0.0567, -0.0922, -0.0820]]), song_description='The song is a melodic composition that can be classified as a pop song. It is characterized by a female vocalist who sings in a melodic and emotive manner, accompanied by a male vocalist who provides harmonies. The song is set to a moderate tempo of 100 bpm, which gives it a lively and upbeat feel. The musical arrangement is dominated by a synthesizer, which provides the main melody and bassline. The synthesizer is accompanied by a drum machine, which provides a steady beat and rhythm. The song is a perfect fit for a lively and energetic atmosphere, such as a nightclub or a dance party. It is a song that can be enjoyed by people of all ages, and is particularly suited for those who enjoy pop music.', song_id='1012000', track_id=['1420700']),
#  DataRecord(audio_content=tensor([[0.0174, 0.0248, 0.0225,  ..., 0.0447, 0.0384, 0.0078]]), song_description="The song in question is a melodic piece that can be classified as a light classical music. It is characterized by the use of a piano, which is the primary instrument in this composition. The melody is gentle, and the tempo is moderate, with a tempo range of 100-120 beats per minute. The song is designed to evoke a sense of calmness and serenity, making it an ideal choice for a relaxing atmosphere. It could be played at a variety of events, including a peaceful retreat, a yoga session, or even a romantic dinner. The song's gentle melody and moderate tempo make it a versatile piece that can be enjoyed by listeners of all ages and backgrounds.", song_id='1014400', track_id=['757500'])]

# %%
df=output.to_df()

# %%
df
# Out:
#                                        audio_content  song_id  \
# 0  [[tensor(4.6705e-05), tensor(-0.0018), tensor(...  1009600
# 1  [[tensor(-0.1634), tensor(-0.2427), tensor(-0....  1012000
# 2  [[tensor(0.0118), tensor(0.0190), tensor(0.028...  1014400
#
#                                     song_description   track_id
# 0  The song is a melodic piece that is characteri...  [1037900]
# 1  The song is a melodic piece that can be classi...  [1366700]
# 2  The song you're referring to is a melodic piec...   [702500]

# %%
output=plan.run()
#output.to_df().to_csv('results.csv')
# Out:
# FIELDS[("Schema[['audio_content', 'song_id']].959fe542c9.audio_content", True), ("Schema[['audio_content', 'song_id']].959fe542c9.song_id", False)]
# FIELDS2
# [True, False]
# convert.py: m-a-p/MusiLingo-long-v1
# /home/opalinav/palimpzest/audio_pz2/lib/python3.12/site-packages/timm/models/hub.py:4: FutureWarning: Importing from timm.models.hub is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# Loading Audio Encoder
# WARNING: feature_extractor_cqt requires the libray 'nnAudio'
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565 - if you loaded a llama tokenizer from a GGUF file you can ignore this message
# Loading Audio Encoder Done
# Loading LLAMA
# LlamaForCausalLM has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# convert.py: m-a-p/MusiLingo-short-v1
# Loading Audio Encoder
# Loading Audio Encoder Done
# Loading LLAMA
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# convert.py: m-a-p/MusiLingo-long-v1
# Loading Audio Encoder
# Loading Audio Encoder Done
# Loading LLAMA
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# convert.py: m-a-p/MusiLingo-long-v1
# Loading Audio Encoder
# Loading Audio Encoder Done
# Loading LLAMA
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LLAMA Done
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Output()
# RIGHT CALL:generators.py
# convert.py:['audio_content', 'song_description', 'song_id']
# convert.py, field:audio_content
# convert.py, field:song_description
# convert.py, field:song_id
# RIGHT CALL:generators.py
# convert.py:['audio_content', 'song_description', 'song_id']
# convert.py, field:audio_content
# convert.py, field:song_description
# convert.py, field:song_id
# RIGHT CALL:generators.py
# convert.py:['audio_content', 'song_description', 'song_id']
# convert.py, field:audio_content
# convert.py, field:song_description
# convert.py, field:song_id
# {'ids': [['633200']], 'embeddings': None, 'documents': [["This song is categorized as a classical music piece. It
# is characterized by its melodic harmony, which is primarily composed of a piano melody. The melody is played by a
# solo piano, which is accompanied by a string section. The strings are arranged in a manner that creates a
# harmonious and melodious texture, which is further enhanced by the piano's melody. The song is a beautiful
# composition that showcases the classical music genre's ability to create a rich and complex musical texture. The
# song is a melodic composition that features a piano as the primary instrument. The piano is played in a slow,
# melodic manner, creating a soothing and calming atmosphere. The melody is accompanied by a cello, which adds depth
# and richness to the overall sound. The combination of the piano and cello creates a harmonious and melodious tune
# that is perfect for a relaxing atmosphere. The song is not particularly fast-paced, and its tempo is moderate,
# making it an ideal choice for a peaceful and calming ambiance. It is a beautiful composition that is perfect for a
# romantic setting, a serene atmosphere, or simply as background music for a relaxing day. The song in question is a
# melancholic piece, with a distinctly sad and sorrowful tone. It is characterized by a slow tempo, which gives it a
# sense of heaviness and weight. The melody is played on a piano, which adds to the emotional depth of the song. The
# song is also accompanied by a male vocalist, whose voice is rich and resonant, adding to the overall emotional
# impact of the piece. The song is a perfect representation of the melancholic mood, and is often used in situations
# where one wants to evoke a sense of sadness or loss. 120. The song is a slow-paced, melodic piece that is
# characterized by its gentle, soothing rhythm. The tempo of the song is measured at 120 beats per minute, which is a
# relatively slow pace, making it ideal for relaxation and meditation. The song is a perfect example of the calming
# and peaceful nature of ambient music, which is often used to create a serene atmosphere. The song is a perfect
# example of the calming and peaceful nature of ambient music, which is often used to create a serene atmosphere. It
# is a perfect choice for those who want to unwind and relax, or for those who are looking for a peaceful background
# music to listen to."]], 'uris': None, 'data': None, 'metadatas': [[{'bpm': 109.977622986, 'genre': "['symphonic',
# 'classical', 'orchestral', 'soundtrack']", 'instrument': "['piano']", 'key': 'D minor', 'mood/theme': "['sad',
# 'love', 'dream']"}]], 'distances': [[0.25596386194229126]], 'included': [<IncludeEnum.distances: 'distances'>,
# <IncludeEnum.documents: 'documents'>, <IncludeEnum.metadatas: 'metadatas'>]}
# *** SyntaxError: unterminated string literal (detected at line 1)
# [['633200']]

# %%
from IPython.display import Audio

# %%
Audio(data=song_datareader[0]['audio_content'],rate=24000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Persistent Chroma Collection

# %%
import chromadb

# %%
#client = chromadb.PersistentClient(path=r'C:\Users\Opalina\Desktop\Meng\jamendo\chroma120_v1')
client = chromadb.PersistentClient(path=r'/home/opalinav/chroma120_v1')
collection = client.get_collection(name="Songs120_v2")

# %%
collection.get(ids)
# Out:
# {'ids': ['1088000',
#   '759300',
#   '1066500',
#   '1416200',
#   '1189900',
#   '1317900',
#   '1300500',
#   '1125400',
#   '604700',
#   '702500',
#   '1073700',
#   '1372200',
#   '1337900',
#   '945200',
#   '501300',
#   '1115700',
#   '1388600',
#   '1158200',
#   '872000',
#   '1320000',
#   '1080900',
#   '816200',
#   '1037900',
#   '1327700',
#   '1353300',
#   '1357400',
#   '1041500',
#   '1374300',
#   '1096800',
#   '1062500',
#   '682600',
#   '80500',
#   '1121400',
#   '1087100',
#   '1014400',
#   '1052800',
#   '399500',
#   '1090700',
#   '1056400',
#   '1371800',
#   '95400',
#   '1081000',
#   '1132200',
#   '1170600',
#   '752300',
#   '1366700',
#   '206000',
#   '86200',
#   '1062600',
#   '1284300',
#   '1211600',
#   '729300',
#   '1420500',
#   '1066200',
#   '1398500',
#   '7400',
#   '1227500',
#   '1116400',
#   '1082100',
#   '1163000',
#   '1393400',
#   '757500',
#   '1282300',
#   '1277700',
#   '1166100',
#   '1396500',
#   '1012000',
#   '913700',
#   '1028900',
#   '1084200',
#   '1395500',
#   '1173500',
#   '661300',
#   '1339700',
#   '1420600',
#   '1155900',
#   '1416000',
#   '1266500',
#   '1330500',
#   '1129800',
#   '950100',
#   '1385300',
#   '1398100',
#   '1248600',
#   '1086300',
#   '847200',
#   '1324900',
#   '633200',
#   '1222000',
#   '1076600',
#   '116600',
#   '1195900',
#   '1109900',
#   '1105300',
#   '840600',
#   '1250200',
#   '1420700',
#   '635300',
#   '1164200',
#   '903600',
#   '1202100',
#   '1155000',
#   '659900',
#   '920000',
#   '1009600',
#   '1162700',
#   '501200',
#   '202200',
#   '893400',
#   '1303000',
#   '718300',
#   '1102300',
#   '1383900',
#   '133600',
#   '1170400',
#   '1110500',
#   '794600',
#   '1101300',
#   '798200',
#   '1314300'],
#  'embeddings': None,
#  'documents': ['This song is a melodic techno piece, which is a sub-genre of electronic music. The song is characterized by its rhythmic patterns, which are created by the use of a kick drum and a snare drum. The melody is created by the use of synthesizers, which produce a distinctive and unique sound. The song is also notable for its use of a vocal sample, which is a pre-recorded voice that is used to create a melody. The song is a perfect example of how techno music can be used to create a unique and engaging sound. It is a perfect blend of electronic elements and human touch, which makes it a standout in the techno genre. The song is a melodic composition that features a prominent bassline, which is played on a synthesizer. The bassline is the primary melody of the song, and it is accompanied by a rhythmic beat that is generated by a drum machine. The drum machine produces a steady beat that is synchronized with the bassline, creating a harmonious rhythm that is the backbone of the song. The song also features a synthesized melody that is played on a keyboard, which adds a layer of depth to the overall sound. The melody is a simple sequence of notes that are played repeatedly, creating a hypnotic effect. The song is characterized by its minimalistic approach, with only a few instruments contributing to the overall sound. The result is a song that is both minimalist and engaging, with a unique blend of electronic and melodic elements. The song is a melancholic one, evoking a sense of sadness and melancholy. The melody is characterized by a slow, mournful melody played on a synthesizer, which creates a sense of depth and richness. The song also features a prominent bass line, which adds a sense of weight and solidity to the overall sound. The synthesizer also has a distinctive, pulsating quality that gives the song a rhythmic feel. The song is a perfect representation of the melancholic mood it evokes, and is ideal for use in a film or video that seeks to evoke a sense of sadness and melancholy. The song is a high-tempo, energetic piece of music, with a tempo of 120 beats per minute (BPM). This is a fast-paced, high-energy track that is perfect for a dance party or a high-energy workout. The song is characterized by a distinctive synthesizer sound that creates a driving, pulsating rhythm. The synthesizer is accompanied by a bassline that is both driving and energetic, adding to the overall high-energy feel of the song. The song is also characterized by a distinctive vocal melody that is sung in a high-pitched, energetic tone. The vocal melody is accompanied by a catchy, upbeat chorus that adds to the overall high-energy feel of the song. The song is a perfect example of a high-energy, fast-paced track that is perfect for a dance party or a workout. It is a great addition to any playlist that seeks to create an energetic and upbeat atmosphere.',
#   "This song is a hip-hop track, characterized by its rhythmic beats and rap vocals. The song is a fusion of two different genres, namely hip-hop and rap. The former is a genre that originated in the 1970s, characterized by its use of break-beats and sampling. The latter, on the other hand, is a style of rap that originated in the 1980s, characterized by its fast-paced delivery and rhythmic flow. The song is a unique blend of these two genres, making it a unique and interesting addition to the hip-hop genre. The song is a melodic composition that features a male vocalist singing over a synthesized background. The vocalist's voice is accompanied by a synthesized bassline, which is a synthesized sound that provides a low-pitched, rhythmic foundation to the song. The bassline is supported by a drum machine, which provides a steady beat to the song. The song also features a synthesized melody, which is a repeating sequence of notes that adds a harmonic layer to the song. The melody is played on a synthesizer, which is a digital instrument that can produce a wide range of sounds. The synthesizer is used to create a melodic texture that is both harmonious and engaging. The song is characterized by its catchy rhythm and the synthesized sounds that create a unique and distinctive atmosphere. It is a song that is perfect for a dance club setting, where the rhythm and the synthesized sounds can create an exciting and energetic atmosphere. The song is a melodic piece that evokes a sense of nostalgia, a sentimental longing for a past era. It is characterized by a slow tempo, a gentle melody, and a simple rhythm. The song is a perfect representation of the mellow, laid-back vibe of the 70s, a time of peace and love. The melody is a blend of a synthesized bass line and a piano melody, which creates a harmonious and soothing sound. The overall effect of the song is a relaxing, nostalgic atmosphere, perfect for unwinding and reflecting on the past. The song in question is a mid-tempo piece, with a tempo of 100 beats per minute (BPM). This tempo is a moderate pace, suitable for a range of activities, including running, yoga, or even dancing. The song is characterized by a distinctive bassline, which is a prominent feature of the composition. The bassline is a driving force, propelling the song forward and adding a sense of rhythm to the overall sound. The song is also notable for its use of a synthesizer, which provides a distinctive and futuristic sound. The synthesizer is used to create a sense of depth and complexity, adding a layer of depth to the overall sound. The song is a well-rounded, engaging piece, suitable for a range of audiences.",
#   "This song is a melodic piece that belongs to the genre of pop. It is characterized by its catchy melody, which is primarily driven by a synthesizer. The song also features a male vocalist who sings in a melodic and rhythmic manner, adding to the overall charm of the piece. The song is also notable for its use of a drum machine, which provides a steady beat and rhythm to the song. The song is a perfect example of the pop genre, which is known for its catchy and melodic tunes. It is a great addition to any playlist, especially those that are designed to set a mellow and relaxing atmosphere. The song is a melodic composition that features a range of instruments. The primary instrument is the electric guitar, which is played in a rhythmic pattern that is synchronized with the drum beat. The guitar is accompanied by a bass guitar, which provides a solid foundation for the melody. The melody itself is played by a synthesizer, which is a digital instrument that produces a range of sounds. The synthesizer is also used to add a touch of ambiance to the song. The song is further enhanced by the presence of a drum set, which provides a steady beat that drives the rhythm of the song. The song is characterized by its catchy melody and rhythm, making it an enjoyable listen. The song in question is a melancholic one, with a distinctly sad and mournful tone. It's a slow-paced piece, with a gentle rhythm that's reminiscent of a funeral march. The song is characterized by a distinctive sound, which is created by a combination of a guitar and a flute. The guitar provides a steady, repetitive rhythm, while the flute adds a melancholic melody to the mix. The overall effect is a haunting, emotional sound that evokes a sense of sadness and loss. The song in question has a tempo of 100 beats per minute, which is a moderate tempo. It is a melodic piece that is characterized by a distinctive rhythm, which is created by the combination of a bass drum and a snare. The song is also notable for its use of a synthesizer, which provides a distinctive and prominent melody. The synthesizer is accompanied by a guitar, which adds a rhythmic texture to the song. The song is also notable for its use of a cymbal, which is used to create a rhythmic pattern. The song is a perfect blend of rhythm and melody, making it an ideal choice for a dance track. It is a versatile piece that can be enjoyed by a wide range of audiences, from teenagers to adults.",
#   'This song is categorized as a classical piece, specifically a solo piano piece. The melody is played by a single piano, which is the primary instrument in this composition. The piece is characterized by its slow tempo, which is a hallmark of classical music. The melody is simple, yet elegant, and it is performed with a high degree of skill and precision. The song is not particularly complex, but it is a beautifully crafted piece that showcases the artistry of the pianist. The song is not particularly long, but it is a well-crafted piece that is sure to leave a lasting impression on listeners. The song is a melodic composition that features a piano as the primary instrument. The piano is played in a slow, melodic manner, creating a soothing and calming atmosphere. The melody is simple and repetitive, making it easy to follow and enjoy. The song is not particularly complex, but it is a beautiful and peaceful piece of music that can be enjoyed in its simplicity. The song is not particularly long, but it is a perfect length for a short, relaxing interlude. The melody is not particularly complex, but it is a beautiful and peaceful piece of music that can be enjoyed in its simplicity. The song is not particularly long, but it is a perfect length for a short, relaxing interlude. The melody is not particularly complex, but it is a beautiful and peaceful piece of music that can be enjoyed in its simplicity. The song is not particularly long, but it is a perfect length for a short, relaxing interlude. The melody is not particularly complex, but it is a beautiful and peaceful piece of music that can be enjoyed in its simplicity. The song is not particularly long, but it is a perfect length for a short, relaxing interlude. The melody is not particularly complex, but it is a beautiful and peaceful piece of music that can be enjoyed in its simplicity. The song is not particularly long, but it is a perfect length for a short, relax The song is a melancholic one, evoking a sense of sadness and melancholy. The melody is played on a keyboard, which gives it a distinctive sound. The song is characterized by a slow tempo, which adds to the overall mood of sadness. The melody is simple, yet it has a profound emotional impact, making it a perfect fit for a funeral scene in a movie. The song is a perfect example of how music can evoke emotions and create a specific mood. The song in question is a slow-paced, melodic piece, with a tempo of 60 beats per minute. This tempo is a relatively slow one, which gives the song a soothing and calming feel. The song is characterized by a simple melody, which is played by a single instrument, a flute. The melody is not particularly complex, but it is beautifully executed, adding to the overall charm of the song. The song is not particularly fast-paced, but it is still engaging and enjoyable to listen to. It is a perfect example of a slow-paced, melodic piece that can be enjoyed for its simplicity and beauty.',
#   "This song is a blend of two genres, namely the rock and the alternative genres. The song is characterized by a distinctive guitar riff that sets the tone for the entire piece. The guitar riff is played with a distorted sound, giving it a distinctive edge. The song also features a prominent bass line that adds depth and texture to the overall sound. The drums are played with a steady beat, adding a rhythmic foundation to the song. The vocals are delivered in a monotone style, which gives the song a unique and distinctive feel. The song is a perfect example of the blend of rock and alternative genres, making it a unique and interesting piece of music. The song is a melodic composition that features a male vocalist singing the lead vocals. The instrumental arrangement is quite minimalistic, with only a few instruments contributing to the overall sound. The primary instrument is a bass guitar, which provides a solid foundation for the song. The song also features a rhythm guitar, which provides a steady rhythm to the song. The song also has a drum set, which provides a steady beat to the song. The song also features a synthesizer, which provides a melodic line to the song. The synthesizer is used to create a harmonious melody that complements the lead vocalist's singing. The song also has a tambourine, which provides a shaking rhythm to the song. The tambourine is used to create a rhythmic texture that enhances the overall sound of the song. The song is a simple yet effective composition that showcases the talents of the musicians involved in its creation. It is a melodic piece that is sure to captivate listeners with its minimalistic yet effective instrumentation. The song is a melancholic one, evoking a sense of sadness and melancholy. The melody is characterized by a slow tempo, which is a common feature of many melancholic songs. The song is also characterized by a distinctive guitar riff that adds to the overall melancholic atmosphere. The song is also notable for its use of a distorted bass guitar, which gives it a distinctive edge. The song is a perfect representation of the melancholic mood, which is often associated with the end of a romantic relationship. The song is a perfect representation of the emotions of heartbreak and longing. The song is a slow-paced one, with a tempo of 60 beats per minute. This is a relatively low tempo, which is often associated with a sense of melancholy or sadness. The song's melody is characterized by a simple, repetitive pattern that is played on a keyboard, adding to the overall mood of the song. The song's rhythm is further enhanced by the use of a steady kick drum, which provides a steady, driving beat. The song's overall sound is a blend of a simple, repetitive melody and a driving rhythm, which creates a unique and distinctive atmosphere. It's a perfect fit for a slow-paced, introspective scene in a film or TV show.",
#   "This song is a rock-based composition, with a distinctive blend of elements from the genres of hard rock and heavy metal. The song is characterized by a strong bass line, which is played by an electric bass guitar. The drums are also prominent in the song, with a heavy metal-style beat that is played with a snare drum and a cymbal. The vocals are delivered in a distinctive style, with a deep, guttural growl that is reminiscent of heavy metal. The song is further enhanced by the inclusion of a guitar riff, which is played with a distorted sound, adding a layer of heaviness to the overall sound. The song is also characterized by the use of a synthesizer, which provides a distinctive, futuristic sound. The song is a perfect example of a blend of heavy metal and rock, with a unique and distinctive sound. The song is a melodic composition that features a guitar as the lead instrument. The guitar is played in a rhythmic pattern that is characterized by a steady beat. The melody is a harmonious blend of two different guitar chords, which creates a unique and distinctive sound. The song also features a bass guitar, which provides a solid foundation for the melody. The bass guitar is played in a rhythmic pattern that is synchronized with the guitar. The song is further enhanced by the presence of a drum set, which adds a dynamic element to the composition. The drum set is played in a steady rhythm, which is in sync with the guitar and bass. The song is a unique blend of different instruments, which creates a distinctive and engaging sound. The song is a melancholic one, with a distinctly sad and melancholic tone. It's a slow-paced, low-tempo track, which is characterized by a male vocalist singing in a low, monotone voice. The song is also notable for its use of a synthesizer, which provides a distinctive and prominent sound. The synthesizer is used to create a melancholic atmosphere, which is further enhanced by the male vocalist's monotone delivery. The song is also notable for its use of a drum machine, which provides a steady beat and rhythm to the song. The overall effect of the song is a sense of sadness and melancholy, which is likely to evoke a sense of introspection and reflection. The song in question is a high-tempo piece, with a bpm of 120. This is a relatively fast tempo, which is often associated with high-impact sports, such as football or martial arts. The song is characterized by a strong, energetic rhythm, which is driven by the pounding of the drums. The bass guitar also plays a significant role in the song, providing a solid foundation for the rhythm. The song is further enhanced by the presence of a guitar, which adds a layer of melody to the mix. The song is a perfect fit for a high-impact sports scene, where the audience is looking for an adrenaline-fueled experience.",
#   'This song is a piece of electronic music, specifically a trance-style track. The song is characterized by its hypnotic, pulsing rhythm, which is created by a combination of synthesized sounds. The song is also notable for its use of a distinctive, high-pitched sound that is produced by a synthesizer. This sound is a hallmark of the trance genre, and it is used to create a sense of euphoria and a heightened state of awareness. The song is also notable for its use of a vocal sample, which is a spoken word passage that is repeated throughout the song. This sample is a common feature of trance music, and it serves to add depth and meaning to the song. The song is a unique blend of electronic elements, and it is a testament to the creativity and innovation of the electronic music genre. The song is a melodic composition that features a piano as the primary instrument. The piano is played in a slow, melodic manner, creating a soothing and calming atmosphere. The melody is accompanied by a synthesizer, which provides a harmonious and complementary texture to the piano. The synthesizer is played in a rhythmic pattern, adding a sense of rhythm to the piece. The song is a unique blend of classical and electronic music, making it a unique and distinctive composition. This song is a melancholic piece, evoking a sense of sadness and melancholy. The song is characterized by a slow tempo, which is a hallmark of melancholic music. The melody is played on a piano, which adds to the emotional depth of the song. The song is also accompanied by a male vocalist, whose voice is low and mournful, adding to the overall melancholic atmosphere. The song is a perfect representation of the emotions of sadness and melancholy, making it a suitable choice for a funeral or a memorial service. 120 beats per minute. This song is characterized by a rhythmic pattern that is quite distinctive, with a tempo that is quite fast. The song is a mix of different elements, including a synthesized bassline, a drum loop, and a melody that is played on a keyboard. The melody is quite simple, consisting of a single line that is repeated over and over again. The song is a perfect example of a fast-paced, high-energy track that is designed to get people moving and grooving. It is a perfect fit for a dance club, where the audience is likely to be swept up in the rhythm and energy of the music.',
#   "This song is a melodic piece that can be classified as a type of ambient music. Ambient music is a genre that is characterized by its calming and soothing nature. It is often used as background music, providing a subtle and gentle sonic texture that creates a peaceful atmosphere. This song is a perfect example of ambient music, with its calming melody and gentle rhythm. The song is also notable for its use of a synthesizer, which adds a futuristic and technological touch to the overall sound. The synthesizer creates a unique and distinctive sound that sets it apart from other ambient music pieces. The song is also notable for its use of a simple and repetitive melody, which creates a hypnotic effect, drawing the listener into its sonic world. The song is a perfect example of how ambient music can create a peaceful and calming atmosphere, making it an ideal choice for relaxation and meditation. The song is characterized by a distinctive sound that is created by a combination of instruments. The main instrument is a synthesizer, which provides the melody and the rhythm of the song. The synthesizer is accompanied by a bass guitar, which provides a solid foundation for the melody. The bass guitar is played with a distorted sound, giving the song a unique and distinctive character. Additionally, there is a drum set, which provides the rhythm and the beat of the song. The drum set is played with a simple and straightforward approach, adding a sense of energy to the overall sound. The song is a perfect example of how a combination of different instruments can create a unique and captivating sound. This song is a melancholic piece, evoking a sense of sadness and melancholy. The song is characterized by a slow tempo, which is a hallmark of melancholic music. The melody itself is a simple one, consisting of a single line that is repeated over and over. This repetition creates a sense of monotony, which is a common characteristic of melancholic music. The song is also characterized by a lack of rhythm, which further adds to the melancholic mood. The overall effect of this song is a sense of sadness and longing, which is a common theme in melancholic music. 120 bpm. The song is a fast-paced, high-energy piece that is likely to be used in a high-impact, action-packed scene. The tempo of the song is quick, with a rapid beat that is likely to get the listener's heart racing. The song is characterized by a driving, pulsating rhythm that is sure to create a sense of urgency and excitement. The song is likely to be used in a film or video game to create a sense of tension and excitement, or to set a fast-paced, high-energy tone.",
#   "This song is a blend of two genres, namely pop and rock. The song is characterized by a distinctive guitar riff that is played throughout the song, which gives it a distinctive and recognizable sound. The song also features a prominent bass line that adds depth and rhythm to the overall sound. The vocals are delivered in a pop style, which gives the song a catchy and melodic quality. The song is also notable for its use of percussion, which is played in a rock style, adding a dynamic and energetic element to the overall sound. The song is a perfect blend of pop and rock, making it a unique and enjoyable listening experience. The song is a melodic composition that features a male vocalist singing in a melodic and rhythmic manner. The song is characterized by a distinctive bass line that is played on a bass guitar. The bass line is accompanied by a rhythmic drum beat that is played on a snare drum. The song also features a guitar riff that is played on an electric guitar. The riff is a repetitive pattern that is played in a rhythmic manner, adding to the overall rhythm of the song. The song is further enhanced by the presence of a synthesizer that provides a melodic and harmonic texture to the composition. The synthesizer is played in a rhythmic manner, adding to the overall rhythm of the song. The song is a melodic and rhythmic composition that is characterized by the bass line, drum beat, guitar riff, and synthesizer. It is a unique and distinctive piece of music that is sure to captivate the listener's attention. The song is a melancholic one, evoking a sense of sadness and melancholy. The melody is characterized by a slow tempo, which is a common feature of many sad songs. The song is also notable for its use of a guitar, which is played in a minor key, adding to the overall melancholic atmosphere. The song is also notable for its use of a drum set, which provides a steady beat, adding to the overall rhythm of the song. The song is a perfect representation of the emotions of sadness and melancholy, making it a great choice for a mood-setting background music. The song in question is a high-energy, fast-paced piece of music, with a tempo of 120 beats per minute (BPM). This is a relatively high tempo, making it a great choice for a high-impact, energetic performance. The song is characterized by a distinctive sound, which is a combination of a male vocalist singing in a high-pitched tone, and a synthesizer playing a melody in the background. The synthesizer is a key element of the song, providing a driving force that propels the music forward. The overall sound is energetic, dynamic, and engaging, making it a great choice for a high-impact performance.",
#   "This song is a melodic piece that can be classified as a ballad. It is characterized by a slow tempo, a gentle melody, and a soothing harmony. The song is a solo performance, with a single vocalist singing the lyrics. The lyrics themselves are poignant, expressing a sense of longing and yearning, which is a common theme in ballads. The song is a heartfelt expression of emotions, and its gentle melody and soothing harmony make it a perfect choice for a romantic setting. It is a song that can evoke a sense of nostalgia and longing, making it a fitting choice for a romantic setting. The song in question is a melodic composition that features a prominent acoustic guitar. The guitar is played in a rhythmic pattern that is synchronized with the beat of the song. The melody is further enhanced by the addition of a synthesizer, which provides a harmonious and rich texture to the overall sound. The synthesizer is used to create a distinctive and distinctive sound that is particularly prominent in the song's chorus. The song also features a bass guitar, which provides a solid foundation for the melody and rhythm. The bass guitar is played in a low, pulsating pattern that is synchronized with the beat of the song. The song is further enhanced by the use of a drum kit, which provides a steady beat and rhythm to the song. The drum kit is played with a high degree of precision and skill, adding a dynamic and energetic element to the overall sound. The song is a melodic composition that is characterized by its rhythmic patterns, rich textures, and dynamic beats. It is a perfect example of a song that is both engaging and enjoyable to listen to. The song in question is a melancholic piece, evoking a sense of sadness and melancholy. It is a slow-paced, low-tempo song, with a distinctive and haunting melody that is both captivating and emotional. The song is characterized by a deep, resonant bass line that adds depth and richness to the overall sound. The melody is further enhanced by the use of a cello, which lends a sense of sorrow and pathos to the piece. The song is a perfect representation of the emotional depth and complexity that can be achieved through the use of a cello. It is a piece that is both beautiful and evocative, capable of stirring the emotions of the listener. The song in question is a slow-paced, melodic piece that is characterized by a moderate tempo of 100 beats per minute (BPM). This tempo is a medium-fast pace, which is suitable for a relaxing, contemplative atmosphere. The song is a perfect example of a peaceful, calming melody that is designed to soothe the soul and create a sense of tranquility. It is a beautiful composition that is ideal for use in a variety of settings, including meditation, yoga, and other relaxation-oriented activities.",
#   "This song is a melodic piece that can be classified as a pop song. It is characterized by its catchy melody, which is a blend of various musical elements. The song features a male vocalist who sings in a melodic and rhythmic manner, adding a unique touch to the overall sound. The song also incorporates a range of instruments, including a guitar, which provides a solid foundation for the melody. The song is also notable for its use of a synthesizer, which adds a futuristic and electronic touch to the overall sound. The song is a perfect example of a pop song that is both melodic and rhythmic, making it an enjoyable listen for music lovers. The song in question is a melodic composition that features a prominent bass guitar. The bass guitar is the primary instrument that drives the song's rhythm and melody. It is played with a distorted effect, which gives it a unique and distinctive sound. The song also features a synthesizer, which provides a harmonious and complementary melody to the bass guitar. The synthesizer is played with a chord progression that is reminiscent of a minor chord progression. The song also features a drum set, which provides a steady beat and rhythm to the composition. The drum set is played with a simple and straightforward rhythm, which is in line with the song's overall tempo. The song is characterized by its melodic bass guitar and synthesizer, which creates a unique and distinctive sound. It is a great example of a song that is driven by the bass guitar, and the synthesizer's harmonious melody. The song in question is a melancholic one, with a distinctly sad and mournful tone. It's a slow-paced piece, with a tempo that's quite low, which adds to the overall mournful atmosphere. The song is characterized by a distinctive sound, which is a result of the use of a synthesizer. The synthesizer creates a haunting, eerie sound that's both dark and brooding. This sound is further enhanced by the use of a distortion effect, which gives the synthesizer a harsher, more aggressive edge. The song is also notable for its use of a drum machine, which provides a steady, rhythmic beat that's both pounding and relentless. The overall effect of this song is one of a deep, profound sadness, which is likely to evoke a sense of melancholy in the listener. 120 bpm. The song is a melodic composition that is characterized by a distinctive rhythm. It is a slow-paced, mellow piece that is perfect for a relaxing atmosphere. The song is a blend of various musical elements, including a synthesized bass line, a melodic synthesizer, and a rhythmic drum beat. The overall sound is a harmonious blend of these elements, creating a soothing and calming ambiance. The song is a perfect example of the power of music to create a mood, and it is sure to leave a lasting impression on listeners.",
#   "This song is a pop-infused dance track, with a distinctive and catchy melody that is sure to get people moving. The song features a female vocalist who sings the lyrics with a high-pitched, upbeat tone. The melody is characterized by a prominent bass line, which is played by a synthesizer. The song also features a prominent drum beat, which is played by a drum machine. The song is a perfect blend of pop and dance music, making it an enjoyable and entertaining listen. It is a perfect addition to any dance playlist, and is sure to get people moving on the dance floor. The song in question is a melodic composition that features a prominent bass guitar. The bass guitar is the primary instrument in the song, providing the foundation for the melody. It is played with a distorted effect, giving it a unique and distinctive sound. The song also features a rhythm section, which is comprised of a drum set and a bass drum. The drum set is played with a steady beat, while the bass drum provides a thumping, driving rhythm. The song also features a synthesizer, which provides a melodic line that complements the bass guitar. The synthesizer is played with a high-pitched, treble-heavy sound, adding a layer of depth to the overall sound. The song is characterized by its melodic bass guitar and rhythmic drumming, making it a great choice for a dance track. This song is a melodic piece that evokes a sense of nostalgia and longing. It is characterized by a distinctive melody that is played on a keyboard, which is accompanied by a rhythmic beat that is generated by a drum machine. The overall effect of this combination creates a sense of nostalgia, which is further enhanced by the use of a synthesizer to create a nostalgic atmosphere. The song is also notable for its use of a vocal sample, which is a snippet of a song that was popular in the 90s. This sample adds a unique touch to the song, making it stand out from other similar pieces. The song is a perfect representation of the 90s era, which is characterized by its nostalgic and melodic sound. The song in question is a high-energy, upbeat track with a tempo of 120 beats per minute. It is a male-dominated composition, with a male vocalist delivering the lyrics in a confident, assertive tone. The song is characterized by a distinctive synthesizer melody that is played in a repetitive pattern, adding to the overall rhythm of the song. The melody is accompanied by a driving bassline, which provides a solid foundation for the song's rhythm. The song also features a prominent drum beat, which is played with a steady, energetic rhythm. The overall sound of the song is energetic, upbeat, and lively, making it a perfect fit for a high-energy dance performance.",
#   "This song is a melodic piece that can be classified as a pop song. It is characterized by a catchy melody that is played on a keyboard, which is a common instrument used in pop music. The song also features a male vocalist who sings the lyrics of the song, which are about a man's desire to be with a woman. The lyrics are sung in a slow tempo, giving the song a romantic feel. The song is also notable for its use of a drum machine, which provides a steady beat to the song. The drum machine is a common element in pop music, and it helps to give the song a rhythmic structure that is easy to follow. The song is also characterized by its use of a synthesizer, which provides a melodic texture to the song. The synthesizer is a versatile instrument that can be used to create a wide range of sounds, and it is often used in pop music to add depth and complexity to the music. Overall, this song is a pop piece that is characterized by its catchy melody, romantic lyrics, and the use of a drum machine and synthesizer. The song in question is a melodic piece that features a prominent bass line, which is played on a synthesizer. The bass line is the primary melody of the song, and it is accompanied by a simple drum beat. The drums are played on a snare drum, which is a percussion instrument that produces a sharp, distinct sound. The drum beat is relatively simple, consisting of a steady rhythm that is repeated throughout the song. The song also features a synthesized melody, which is played on a keyboard. This melody is a harmonious blend of different tones, creating a pleasant and soothing sound. The synthesized melody is a key element of the song, adding depth and richness to the overall sound. The song is characterized by its simple yet effective combination of a bass line, a drum beat, and a synthesized melody, which creates a harmonious and engaging sound. The song is a melancholic one, evoking a sense of sadness and melancholy. The melody is characterized by a slow tempo, which is a hallmark of many sad songs. The song is also notable for its use of a piano, which adds a sense of depth and emotional weight to the overall sound. The piano is accompanied by a string section, which further enhances the melancholic mood. The song is also notable for its use of a cello, which provides a sense of depth and emotional resonance. The combination of these elements creates a rich and evocative atmosphere, one that is perfect for a melancholic setting. The song in question is a slow-paced, low-tempo piece, with a tempo of 60 beats per minute (BPM). This tempo is a relatively sedate and relaxed one, making it ideal for a range of settings, including meditation, yoga, or simply unwinding after a long day. The song is characterized by a distinctive, mellow sound, which is likely to be produced by a combination of instruments, including a guitar, a bass, and a drum machine. The overall effect is a soothing, calming sound that is perfect for creating a tranquil atmosphere.",
#   "This song is a dance-pop track, which is a sub-genre of pop music that is characterized by its upbeat tempo and catchy melodies. The song is also classified as a remix, which suggests that it is a reinterpretation of an existing song. The remix is a common form of music production, where a song is reworked and re-arranged to create a new and unique sound. The song is also classified as a trance track, which is a genre of electronic dance music characterized by its hypnotic and repetitive beats. The song's trance-like elements are likely to be created by the use of synthesizers and other electronic instruments, which are common in this genre. The song's catchy melody and upbeat tempo make it a perfect fit for a dance-pop track, and its trance-like elements add a unique twist to the song. The song is primarily instrumental, with a prominent bassline that drives the rhythm. The bassline is played on a synthesizer, which is a digital instrument that can produce a wide range of sounds. The synthesizer is accompanied by a drum machine, which provides a steady beat to the song. The drum machine is programmed to produce a simple, repetitive rhythm that is perfect for dance floors. The song also features a synthesized melody that is played on a keyboard, which adds a touch of melody to the overall sound. The melody is a simple sequence of notes that are repeated throughout the song, creating a memorable and catchy tune. The song is characterized by its upbeat tempo and energetic rhythm, making it perfect for dance floors and nightclubs. It is a perfect example of a high-energy electronic dance music track. The song is a lively, upbeat, and energetic piece that evokes a sense of excitement and fun. It is characterized by a lively rhythm, a catchy melody, and a lively vocal performance. The song is a perfect fit for a dance party or a nightclub setting, where people can let loose and enjoy themselves. The song's lively and upbeat nature is sure to get people moving and grooving to its rhythm. It is a song that is meant to be enjoyed in a social setting, where people can come together and have a good time. The song's lively and energetic nature is sure to create a fun and lively atmosphere, making it a perfect choice for a night out. The song in question is a high-energy, fast-paced electronic dance music track, with a tempo of 120 beats per minute (BPM). This tempo is a perfect fit for the energetic and upbeat nature of the song, which is characterized by a driving bassline and a catchy, repetitive vocal hook. The song also features a prominent synthesizer melody that adds depth and texture to the overall sound. The song's rhythm is further enhanced by the inclusion of a drum loop, which provides a steady beat and a driving force to the song. The song's energy and catchy melody make it a perfect fit for a dance floor, and its high-energy nature is sure to get any crowd moving.",
#   "This song is categorized as a classical piece, specifically a solo piano piece. The melody is played by a single piano, which is the primary instrument in this composition. The piece is characterized by its gentle, soothing melody, which is a hallmark of classical music. The song is not particularly fast-paced, and its tempo is relatively slow, which adds to its calming and peaceful nature. The melody is simple, yet elegant, and it is performed with a great deal of skill and finesse, which is a hallmark of classical music. The song is not particularly complex, but it is a beautiful and well-crafted piece that showcases the artistry of the pianist. The song is a melodic piece that features a piano as the primary instrument. The piano is played in a slow, melodic manner, creating a soothing and calming atmosphere. The melody is simple and repetitive, making it easy to follow and enjoy. The song is not particularly complex, but it is a beautiful and peaceful piece of music that can be enjoyed in a variety of settings. It is a perfect background music for a relaxing evening, a peaceful walk, or a meditation session. The song is not particularly fast-paced, and its simplicity makes it an ideal choice for those who want to unwind and enjoy a calming atmosphere. The song is a melancholic one, evoking a sense of sadness and melancholy. It is a slow-paced piece, with a gentle melody that is played on a flute. The melody is simple, yet it has a profound emotional impact, evoking feelings of sadness and longing. The song is a perfect representation of the emotional state of a person who is lost in thought, pondering over something that has caused them pain or sorrow. The melody is soothing, yet it has a haunting quality that adds to the overall mood of the song. The song is a perfect representation of the emotional state of a person who is lost in thought, pondering over something that has caused them pain or sorrow. It is a perfect representation of the emotional state of a person who is lost in thought, pondering over something that has caused them pain or sorrow. It is a perfect representation of the emotional state of a person who is lost in thought, pondering over something that has caused them pain or sorrow. It is a perfect representation of the emotional state of a person who is lost in thought, pondering over something that has caused them pain or sorrow. It is a perfect representation of the emotional state of a person who is lost in thought, pondering over something that has caused them pain or sorrow. It is a perfect representation of the emotional The song is a slow-paced, melodic piece, with a tempo of 60 beats per minute. This tempo is a medium-fast pace, which is suitable for a relaxing, contemplative atmosphere. The song's melody is characterized by a gentle, soothing melody that is played on a flute. This instrument's soft, smooth sound creates a calming and peaceful ambiance, which is perfect for a relaxing atmosphere. The song is a perfect example of how music can be used to create a tranquil and calming atmosphere, which can be particularly beneficial for people who are looking to unwind and relax.",
#   "This song is a blend of two genres, namely funk and jazz. The funk genre is characterized by its groovy rhythm, which is created by a bass line and a drum beat. The jazz genre, on the other hand, is known for its improvisational nature, where musicians play with different rhythms and melodies. This song is a perfect blend of both genres, with a funky bass line and a jazz-inspired melody. The song is also notable for its use of a saxophone, which adds a unique touch to the overall sound. The song is a perfect example of how two genres can be combined to create a unique and interesting sound. The song is a melodic composition that features a male vocalist singing in a low tone. The melody is characterized by a distinctive rhythm that is created by a snare drum, which is played with a hard hit. The snare drum is accompanied by a bass drum, which is played with a steady beat. The rhythm is further enhanced by a hi-hat cymbal, which is played with a short, quick pattern. The song also features a guitar, which is played with a distorted sound. The guitar is used to create a distinctive riff that is played throughout the song. The song is further enhanced by a synthesizer, which provides a melodic background. The synthesizer is played with a simple, repetitive pattern that creates a hypnotic effect. The song is characterized by a slow tempo, which is perfect for a relaxing atmosphere. It's a great addition to a chill-out playlist, or a background music for a movie scene that requires a mellow, laid-back atmosphere. The song is a melodic piece that evokes a sense of nostalgia. It's a melancholic tune that's characterized by a male vocalist singing in a low, mellow tone. The song is also accompanied by a guitar that plays a simple melody, adding a touch of melancholy to the overall sound. The song is also enriched by a bass guitar that provides a solid foundation to the rhythm. The song is a slow-paced, mellow tune that's perfect for a relaxing atmosphere. It's a song that's ideal for a lazy afternoon, where one can sit back, relax, and enjoy the melody. The song is a perfect representation of the laid-back, relaxed vibe of the 70s. The song is a medium-tempo piece, with a bpm of 100. It's a male-dominated piece, with a male vocalist singing the lyrics. The song is characterized by a distinctive rhythm, which is created by the use of a snare drum and a hi-hat cymbal. The hi-hat cymbal is played in a steady, rhythmic pattern, while the snare drum is played with a slightly more dynamic rhythm. The song is also notable for its use of a bass guitar, which provides a solid foundation for the rhythm section. The song is a blend of rock and funk, with a funky groove that is driven by the rhythm section. The overall sound is characterized by a rich, full-bodied sound, which is enhanced by the use of a distorted electric guitar. The song is a great example of a male-led rock-funk fusion, with a distinctive rhythm that is sure to get people moving.",
# ...
#    'genre': "['metal', 'alternative', 'rock']",
#    'instrument': "['guitar']",
#    'key': 'E minor',
#    'mood/theme': "['sad', 'space']"},
#   {'bpm': 100.012939453,
#    'genre': "['postrock', 'ambient']",
#    'instrument': "['synthesizer']",
#    'key': 'G major',
#    'mood/theme': "['hopeful']"},
#   {'bpm': 98.8434524536,
#    'genre': "['electronic']",
#    'instrument': "['piano']",
#    'key': 'G minor',
#    'mood/theme': "['film']"},
#   {'bpm': 172.265777588,
#    'genre': "['experimental', 'ambient']",
#    'instrument': "['computer']",
#    'key': 'C# major',
#    'mood/theme': "['dark']"},
#   {'bpm': 161.498977661,
#    'genre': "['chillout', 'easylistening']",
#    'instrument': "['acousticguitar', 'drums', 'piano', 'electricguitar', 'synthesizer']",
#    'key': 'C major',
#    'mood/theme': "['dream']"},
#   {'bpm': 99.9706420898,
#    'genre': "['chillout', 'acidjazz', 'funk']",
#    'instrument': "['piano', 'horn', 'rhodes']",
#    'key': 'F major',
#    'mood/theme': "['groovy', 'cool']"},
#   {'bpm': 129.975204468,
#    'genre': "['soundtrack']",
#    'instrument': "['piano']",
#    'key': 'A minor',
#    'mood/theme': "['dark']"},
#   {'bpm': 72.0010604858,
#    'genre': "['pop']",
#    'instrument': "['guitar']",
#    'key': 'C major',
#    'mood/theme': "['love', 'happy']"},
#   {'bpm': 120.013366699,
#    'genre': "['easylistening', 'swing']",
#    'instrument': "['orchestra']",
#    'key': 'C# major',
#    'mood/theme': "['fun']"},
#   {'bpm': 99.9439239502,
#    'genre': "['soundtrack']",
#    'instrument': "['piano', 'acousticbassguitar', 'classicalguitar', 'guitar']",
#    'key': 'F major',
#    'mood/theme': "['melancholic']"},
#   {'bpm': 149.862136841,
#    'genre': "['classical', 'easylistening']",
#    'instrument': "['piano']",
#    'key': 'C# minor',
#    'mood/theme': "['background']"},
#   {'bpm': 123.86164093,
#    'genre': "['chillout', 'easylistening', 'soundtrack']",
#    'instrument': "['keyboard', 'strings', 'flute']",
#    'key': 'F major',
#    'mood/theme': "['soft', 'melodic']"},
#   {'bpm': 94.9320602417,
#    'genre': "['newage', 'ambient', 'easylistening', 'fusion', 'experimental', 'electronic']",
#    'instrument': "['bass', 'synthesizer', 'drums']",
#    'key': 'A minor',
#    'mood/theme': "['documentary', 'drama']"},
#   {'bpm': 102.940666199,
#    'genre': "['instrumentalpop', 'blues', 'pop']",
#    'instrument': "['guitar']",
#    'key': 'E minor',
#    'mood/theme': "['calm']"},
#   {'bpm': 128.035400391,
#    'genre': "['chillout', 'ambient', 'easylistening', 'soundtrack']",
#    'instrument': "['acousticguitar', 'classicalguitar', 'electricpiano', 'keyboard', 'piano', 'electricguitar']",
#    'key': 'F major',
#    'mood/theme': "['advertising', 'motivational']"},
#   {'bpm': 133.372970581,
#    'genre': "['world', 'ambient', 'soundtrack']",
#    'instrument': "['strings']",
#    'key': 'G major',
#    'mood/theme': "['epic', 'trailer']"},
#   {'bpm': 139.930252075,
#    'genre': "['popfolk', 'singersongwriter', 'pop']",
#    'instrument': "['piano']",
#    'key': 'C minor',
#    'mood/theme': "['sad', 'emotional']"},
#   {'bpm': 119.96762085,
#    'genre': "['classical', 'orchestral', 'soundtrack']",
#    'instrument': "['doublebass', 'horn', 'harp', 'classicalguitar', 'violin', 'cello', 'trumpet', 'flute', 'oboe', 'trombone']",
#    'key': 'F minor',
#    'mood/theme': "['film']"},
#   {'bpm': 122.056167603,
#    'genre': "['chillout', 'dance']",
#    'instrument': "['keyboard', 'percussion', 'bass', 'drums', 'synthesizer']",
#    'key': 'A# major',
#    'mood/theme': "['summer', 'deep', 'happy']"},
#   {'bpm': 144.776428223,
#    'genre': "['ambient', 'easylistening']",
#    'instrument': "['piano', 'strings']",
#    'key': 'C# major',
#    'mood/theme': "['relaxing']"},
#   {'bpm': 162.160110474,
#    'genre': "['popfolk', 'folk']",
#    'instrument': "['acousticguitar', 'guitar']",
#    'key': 'E major',
#    'mood/theme': "['holiday', 'christmas']"},
#   {'bpm': 119.940948486,
#    'genre': "['downtempo', 'pop', 'easylistening', 'choir', 'orchestral', 'soundtrack', 'electronic']",
#    'instrument': "['drums', 'sampler', 'bass', 'cello', 'computer', 'strings', 'drummachine', 'keyboard']",
#    'key': 'A minor',
#    'mood/theme': "['drama']"},
#   {'bpm': 124.933891296,
#    'genre': "['soundtrack']",
#    'instrument': "['strings', 'guitar']",
#    'key': 'B minor',
#    'mood/theme': "['adventure', 'documentary', 'film', 'advertising']"},
#   {'bpm': 92.3565673828,
#    'genre': "['classical']",
#    'instrument': "['piano']",
#    'key': 'C major',
#    'mood/theme': "['soft', 'relaxing', 'dream']"},
#   {'bpm': 136.522293091,
#    'genre': "['classical']",
#    'instrument': "['clarinet', 'cello', 'violin']",
#    'key': 'F minor',
#    'mood/theme': "['trailer', 'movie', 'love', 'romantic']"},
#   {'bpm': 135.077362061,
#    'genre': "['orchestral', 'easylistening']",
#    'instrument': "['electricguitar', 'strings', 'synthesizer', 'percussion']",
#    'key': 'D major',
#    'mood/theme': "['soft', 'calm']"},
#   {'bpm': 99.7636642456,
#    'genre': "['hardrock', 'rock', 'alternative']",
#    'instrument': "['synthesizer', 'guitar', 'drums']",
#    'key': 'C# major',
#    'mood/theme': "['dark']"},
#   {'bpm': 152.657073975,
#    'genre': "['classical']",
#    'instrument': "['piano']",
#    'key': 'E minor',
#    'mood/theme': "['love', 'nature', 'adventure', 'melodic', 'dream']"},
#   {'bpm': 99.8442840576,
#    'genre': "['popfolk', 'easylistening', 'pop']",
#    'instrument': "['flute', 'ukulele']",
#    'key': 'C major',
#    'mood/theme': "['upbeat', 'positive', 'children', 'happy']"},
#   {'bpm': 137.687927246,
#    'genre': "['classical', 'orchestral', 'soundtrack']",
#    'instrument': "['piano', 'percussion']",
#    'key': 'G# major',
#    'mood/theme': "['funny']"},
#   {'bpm': 79.9763946533,
#    'genre': "['world', 'folk', 'soundtrack']",
#    'instrument': "['ukulele']",
#    'key': 'E minor',
#    'mood/theme': "['upbeat', 'energetic', 'corporate', 'happy']"},
#   {'bpm': 136.953536987,
#    'genre': "['classical']",
#    'instrument': "['piano']",
#    'key': 'A minor',
#    'mood/theme': "['emotional', 'calm', 'melancholic']"},
#   {'bpm': 79.9841766357,
#    'genre': "['ambient', 'classical', 'soundtrack']",
#    'instrument': "['trumpet', 'violin', 'piano', 'trombone', 'cello']",
#    'key': 'A minor',
#    'mood/theme': "['epic', 'film', 'emotional']"},
#   {'bpm': 89.9383850098,
#    'genre': "['chillout', 'pop', '80s', 'electronic']",
#    'instrument': "['synthesizer']",
#    'key': 'C# minor',
#    'mood/theme': "['retro']"},
#   {'bpm': 119.987449646,
#    'genre': "['classical']",
#    'instrument': "['piano']",
#    'key': 'D major',
#    'mood/theme': "['sad']"},
#   {'bpm': 130.019882202,
#    'genre': "['classical', 'orchestral']",
#    'instrument': "['trumpet', 'drums', 'drummachine', 'electricguitar', 'trombone', 'synthesizer', 'violin']",
#    'key': 'D minor',
#    'mood/theme': "['trailer']"},
#   {'bpm': 129.879150391,
#    'genre': "['singersongwriter', 'folk', 'pop']",
#    'instrument': "['ukulele']",
#    'key': 'F major',
#    'mood/theme': "['love']"},
#   {'bpm': 79.946182251,
#    'genre': "['atmospheric', 'ambient', 'soundtrack']",
#    'instrument': "['piano', 'strings']",
#    'key': 'E minor',
#    'mood/theme': "['movie']"},
#   {'bpm': 122.073120117,
#    'genre': "['electronic']",
#    'instrument': "['piano']",
#    'key': 'E major',
#    'mood/theme': "['film']"},
#   {'bpm': 88.3791656494,
#    'genre': "['ambient']",
#    'instrument': "['bell', 'synthesizer']",
#    'key': 'C major',
#    'mood/theme': "['dream']"},
#   {'bpm': 105.008560181,
#    'genre': "['lounge', 'reggae', 'house']",
#    'instrument': "['keyboard', 'percussion', 'bass', 'drums', 'synthesizer']",
#    'key': 'D# major',
#    'mood/theme': "['deep']"},
#   {'bpm': 110.004760742,
#    'genre': "['classical', 'orchestral', 'soundtrack']",
#    'instrument': "['strings', 'brass']",
#    'key': 'E minor',
#    'mood/theme': "['fun']"},
#   {'bpm': 115.866889954,
#    'genre': "['chillout', 'newage', 'ambient']",
#    'instrument': "['synthesizer']",
#    'key': 'C major',
#    'mood/theme': "['corporate']"},
#   {'bpm': 99.8000259399,
#    'genre': "['synthpop', 'triphop', 'pop']",
#    'instrument': "['violin']",
#    'key': 'A major',
#    'mood/theme': "['commercial', 'advertising', 'motivational']"},
#   {'bpm': 120.068626404,
#    'genre': "['atmospheric', 'classical', 'easylistening']",
#    'instrument': "['guitar']",
#    'key': 'A minor',
#    'mood/theme': "['nature']"},
#   {'bpm': 122.992225647,
#    'genre': "['ambient', 'classical', 'electronic']",
#    'instrument': "['computer', 'synthesizer', 'keyboard']",
#    'key': 'E major',
#    'mood/theme': "['meditative', 'relaxing']"},
#   {'bpm': 142.977752686,
#    'genre': "['90s', 'dance', 'eurodance', 'electronic']",
#    'instrument': "['sampler', 'synthesizer']",
#    'key': 'A# major',
#    'mood/theme': "['melodic']"},
#   {'bpm': 140.015197754,
#    'genre': "['ambient', 'electronic']",
#    'instrument': "['piano']",
#    'key': 'F major',
#    'mood/theme': "['sad', 'dramatic']"},
#   {'bpm': 161.754302979,
#    'genre': "['chillout', 'rnb', 'pop']",
#    'instrument': "['synthesizer', 'drums']",
#    'key': 'F major',
#    'mood/theme': "['love']"},
#   {'bpm': 161.565658569,
#    'genre': "['downtempo', 'hiphop', 'electronic']",
#    'instrument': "['beat', 'electricguitar', 'guitar']",
#    'key': 'E minor',
#    'mood/theme': "['relaxing']"},
#   {'bpm': 178.205871582,
#    'genre': "['folk', 'country', 'soundtrack']",
#    'instrument': "['acousticguitar']",
#    'key': 'C major',
#    'mood/theme': "['soft']"},
#   {'bpm': 91.263710022,
#    'genre': "['classical']",
#    'instrument': "['piano']",
#    'key': 'F minor',
#    'mood/theme': "['meditative', 'relaxing']"},
#   {'bpm': 166.614822388,
#    'genre': "['easylistening', 'pop']",
#    'instrument': "['trumpet']",
#    'key': 'C major',
#    'mood/theme': "['sad', 'romantic']"},
#   {'bpm': 109.977622986,
#    'genre': "['symphonic', 'classical', 'orchestral', 'soundtrack']",
#    'instrument': "['piano']",
#    'key': 'D minor',
#    'mood/theme': "['sad', 'love', 'dream']"},
#   {'bpm': 172.265289307,
#    'genre': "['folk', 'ethno', 'latin']",
#    'instrument': "['harp']",
#    'key': 'D minor',
#    'mood/theme': "['positive', 'children', 'relaxing']"},
#   {'bpm': 83.6870803833,
#    'genre': "['chillout', 'dance', 'world', 'electronic', 'soundtrack']",
#    'instrument': "['acousticbassguitar', 'electricpiano', 'drums', 'violin', 'accordion']",
#    'key': 'D# minor',
#    'mood/theme': "['movie']"},
#   {'bpm': 139.531311035,
#    'genre': "['experimental', 'alternative', 'ambient', 'electronic']",
#    'instrument': "['piano']",
#    'key': 'D# major',
#    'mood/theme': "['meditative']"},
#   {'bpm': 105.108047485,
#    'genre': "['rock', 'pop']",
#    'instrument': "['ukulele']",
#    'key': 'G major',
#    'mood/theme': "['corporate', 'happy']"},
#   {'bpm': 97.9883956909,
#    'genre': "['indie', 'electronic']",
#    'instrument': "['bass', 'synthesizer', 'drums']",
#    'key': 'A major',
#    'mood/theme': "['advertising']"},
#   {'bpm': 128.508056641,
#    'genre': "['easylistening']",
#    'instrument': "['piano', 'synthesizer']",
#    'key': 'C minor',
#    'mood/theme': "['meditative', 'movie']"},
#   {'bpm': 106.632850647,
#    'genre': "['rock', 'poprock']",
#    'instrument': "['guitar']",
#    'key': 'A# major',
#    'mood/theme': "['happy']"},
#   {'bpm': 129.940948486,
#    'genre': "['easylistening', 'pop']",
#    'instrument': "['beat', 'strings', 'piano', 'drums']",
#    'key': 'D# minor',
#    'mood/theme': "['happy']"},
#   {'bpm': 121.997840881,
#    'genre': "['chillout', 'house', 'dance', 'easylistening', 'club']",
#    'instrument': "['keyboard', 'percussion', 'bass', 'drums', 'synthesizer']",
#    'key': 'G major',
#    'mood/theme': "['deep', 'happy']"},
#   {'bpm': 114.333808899,
#    'genre': "['classical', 'soundtrack']",
#    'instrument': "['doublebass', 'strings', 'viola', 'piano', 'cello']",
#    'key': 'D# major',
#    'mood/theme': "['emotional']"},
#   {'bpm': 106.608634949,
#    'genre': "['electronic']",
#    'instrument': "['drummachine', 'synthesizer', 'sampler']",
#    'key': 'G major',
#    'mood/theme': "['retro', 'energetic', 'fun', 'happy']"},
#   {'bpm': 184.570343018,
#    'genre': "['classical', 'easylistening']",
#    'instrument': "['piano']",
#    'key': 'G minor',
#    'mood/theme': "['relaxing', 'background']"},
#   {'bpm': 108.997642517,
#    'genre': "['chillout', 'poprock', 'easylistening']",
#    'instrument': "['acousticguitar']",
#    'key': 'A major',
#    'mood/theme': "['calm', 'background']"},
#   {'bpm': 134.776016235,
#    'genre': "['indie', 'dance', 'techno']",
#    'instrument': "['synthesizer']",
#    'key': 'F minor',
#    'mood/theme': "['party']"},
#   {'bpm': 148.03944397,
#    'genre': "['triphop', 'experimental', 'hiphop']",
#    'instrument': "['violin', 'cello', 'trumpet', 'flute', 'voice', 'piano', 'drummachine', 'electricguitar', 'harp', 'drums', 'brass', 'clarinet', 'bass', 'synthesizer', 'computer', 'strings', 'electricpiano', 'keyboard', 'bongo', 'trombone']",
#    'key': 'G# major',
#    'mood/theme': "['dark']"},
#   {'bpm': 140.20993042,
#    'genre': "['newage', 'soundtrack']",
#    'instrument': "['piano']",
#    'key': 'C major',
#    'mood/theme': "['documentary', 'children', 'dream']"},
#   {'bpm': 118.223922729,
#    'genre': "['classical', 'soundtrack']",
#    'instrument': "['doublebass', 'harp', 'clarinet', 'violin', 'cello', 'flute', 'viola', 'piano']",
#    'key': 'D major',
#    'mood/theme': "['romantic']"},
#   {'bpm': 134.005447388,
#    'genre': "['easylistening', 'pop']",
#    'instrument': "['synthesizer']",
#    'key': 'C major',
#    'mood/theme': "['children', 'advertising']"},
#   {'bpm': 178.205566406,
#    'genre': "['fusion', 'experimental', 'electronic']",
#    'instrument': "['computer', 'drums', 'sampler', 'bass', 'synthesizer']",
#    'key': 'A# major',
#    'mood/theme': "['emotional']"},
#   {'bpm': 131.977218628,
#    'genre': "['electronic']",
#    'instrument': "['piano']",
#    'key': 'C minor',
#    'mood/theme': "['film']"},
#   {'bpm': 140.386245728,
#    'genre': "['choir', 'classical', 'soundtrack']",
#    'instrument': "['doublebass', 'voice', 'violin', 'piano', 'bass', 'cello']",
#    'key': 'A minor',
#    'mood/theme': "['dark']"},
#   {'bpm': 119.975143433,
#    'genre': "['rock', 'punkrock']",
#    'instrument': "['electricguitar']",
#    'key': 'D major',
#    'mood/theme': "['adventure', 'energetic', 'sport']"},
#   {'bpm': 113.267623901,
#    'genre': "['bossanova', 'dance', 'easylistening']",
#    'instrument': "['acousticguitar', 'flute', 'electricpiano']",
#    'key': 'F major',
#    'mood/theme': "['melodic', 'background']"},
#   {'bpm': 112.874359131,
#    'genre': "['world', 'poprock']",
#    'instrument': "['acousticguitar', 'keyboard']",
#    'key': 'A major',
#    'mood/theme': "['melodic']"},
#   {'bpm': 139.918426514,
#    'genre': "['electropop', 'synthpop', 'newwave']",
#    'instrument': "['synthesizer']",
#    'key': 'F major',
#    'mood/theme': "['game']"},
#   {'bpm': 107.905860901,
#    'genre': "['rock', 'poprock', 'pop']",
#    'instrument': "['electricguitar', 'bass', 'drums']",
#    'key': 'B minor',
#    'mood/theme': "['energetic', 'sport']"},
#   {'bpm': 119.821510315,
#    'genre': "['classical', 'soundtrack']",
#    'instrument': "['piano', 'orchestra']",
#    'key': 'D major',
#    'mood/theme': "['movie']"},
#   {'bpm': 98.9765777588,
#    'genre': "['ambient', 'electronic']",
#    'instrument': "['viola', 'violin', 'drummachine', 'cello', 'synthesizer']",
#    'key': 'C major',
#    'mood/theme': "['uplifting']"},
#   {'bpm': 105.142189026,
#    'genre': "['orchestral', 'soundtrack']",
#    'instrument': "['trumpet', 'violin', 'piano', 'trombone', 'cello']",
#    'key': 'A# major',
#    'mood/theme': "['film']"},
#   {'bpm': 99.9905700684,
#    'genre': "['lounge', 'newage', 'ethno']",
#    'instrument': "['piano', 'classicalguitar']",
#    'key': 'D minor',
#    'mood/theme': "['meditative']"},
#   {'bpm': 120.123466492,
#    'genre': "['classical', 'medieval', 'soundtrack', 'orchestral']",
#    'instrument': "['doublebass', 'horn', 'flute', 'violin', 'piano', 'cello']",
#    'key': 'C major',
#    'mood/theme': "['epic', 'trailer', 'film']"},
#   {'bpm': 125.808837891,
#    'genre': "['downtempo', 'atmospheric', 'soundtrack']",
#    'instrument': "['bass', 'pad']",
#    'key': 'E minor',
#    'mood/theme': "['melodic', 'space']"}],
#  'included': [<IncludeEnum.documents: 'documents'>,
#   <IncludeEnum.metadatas: 'metadatas'>]}

# %%
import pandas as pd

# %%
song_csv.at[1088000,'genre']
# Out:
# "['alternative', 'soundtrack', 'pop']"

# %%
#song_csv=pd.read_csv(r'C:\Users\Opalina\Desktop\Meng\jamendo\musi_long120_parsed_results.csv',index_col=1)
song_csv=pd.read_csv(r'/home/opalinav/musi_long120_parsed_results.csv',index_col=1)
song_csv['description']=song_csv['Predicted_genre']+ ' '+song_csv['Predicted_instrument'] +  ' ' + song_csv['Predicted_mood/theme'] +' '+ song_csv['Predicted_bpm']
song_csv
# Out:
#           Unnamed: 0                                         instrument  \
# Track_ID
# 1088000            0                                    ['synthesizer']
# 759300             1                       ['strings', 'bass', 'drums']
# 1066500            2     ['accordion', 'ukulele', 'pipeorgan', 'drums']
# 1416200            3                           ['piano', 'synthesizer']
# 1189900            4                                ['guitar', 'drums']
# ...              ...                                                ...
# 1110500          115  ['viola', 'violin', 'drummachine', 'cello', 's...
# 794600           116  ['trumpet', 'violin', 'piano', 'trombone', 'ce...
# 1101300          117                       ['piano', 'classicalguitar']
# 798200           118  ['doublebass', 'horn', 'flute', 'violin', 'pia...
# 1314300          119                                    ['bass', 'pad']
#
#                                              gpt_instrument  \
# Track_ID
# 1088000   ['synthesizer', 'bass', 'drummachine', 'keyboa...
# 759300      ['synthesizer', 'bass', 'drummachine', 'voice']
# 1066500   ['electricguitar', 'bass', 'synthesizer', 'dru...
# 1416200                                           ['piano']
# 1189900          ['bass', 'guitar', 'drums', 'synthesizer']
# ...                                                     ...
# 1110500                                          ['guitar']
# 794600                                 ['piano', 'strings']
# 1101300        ['synthesizer', 'bass', 'drums', 'keyboard']
# 798200                                   ['piano', 'cello']
# 1314300   ['synthesizer', 'bass', 'drummachine', 'keyboa...
#
#                                        Predicted_instrument  \
# Track_ID
# 1088000   The song is a melodic composition that feature...
# 759300    The song is a melodic composition that feature...
# 1066500   The song is a melodic composition that feature...
# 1416200   The song is a melodic composition that feature...
# 1189900   The song is a melodic composition that feature...
# ...                                                     ...
# 1110500   The song is a melodic piece that features a gu...
# 794600    The song is a melodic composition that feature...
# 1101300   The song is a melodic composition that feature...
# 798200    The song is a melodic composition that feature...
# 1314300   The song is a melodic composition that feature...
#
#                                                       genre  \
# Track_ID
# 1088000                ['alternative', 'soundtrack', 'pop']
# 759300                                       ['soundtrack']
# 1066500                                             ['pop']
# 1416200            ['ambient', 'electronica', 'soundtrack']
# 1189900                       ['indie', 'rock', 'punkrock']
# ...                                                     ...
# 1110500                           ['ambient', 'electronic']
# 794600                         ['orchestral', 'soundtrack']
# 1101300                       ['lounge', 'newage', 'ethno']
# 798200    ['classical', 'medieval', 'soundtrack', 'orche...
# 1314300          ['downtempo', 'atmospheric', 'soundtrack']
#
#                                             gpt_genre  \
# Track_ID
# 1088000                      ['electronic', 'techno']
# 759300                                     ['hiphop']
# 1066500                           ['pop', 'synthpop']
# 1416200                                 ['classical']
# 1189900                       ['rock', 'alternative']
# ...                                               ...
# 1110500           ['electronic', 'techno', 'minimal']
# 794600    ['electronic', 'techno', 'trance', 'house']
# 1101300      ['pop', 'electronic', 'synthpop', '80s']
# 798200                                        ['pop']
# 1314300                               ['pop', 'rock']
#
#                                             Predicted_genre  \
# Track_ID
# 1088000   This song is a melodic techno piece, which is ...
# 759300    This song is a hip-hop track, characterized by...
# 1066500   This song is a melodic piece that belongs to t...
# 1416200   This song is categorized as a classical piece,...
# 1189900   This song is a blend of two genres, namely the...
# ...                                                     ...
# 1110500   This song is categorized as a genre of electro...
# 794600    This song is a melodic piece that belongs to t...
# 1101300   This song is categorized as a pop song. Pop mu...
# 798200    This song is a melodic piece that can be class...
# 1314300   This song is a melodic piece of music that bel...
#
#                                                  mood/theme  \
# Track_ID
# 1088000                                           ['sport']
# 759300                                             ['game']
# 1066500   ['positive', 'uplifting', 'advertising', 'happy']
# 1416200                                 ['sad', 'romantic']
# 1189900                                   ['retro', 'cool']
# ...                                                     ...
# 1110500                                       ['uplifting']
# 794600                                             ['film']
# 1101300                                      ['meditative']
# 798200                          ['epic', 'trailer', 'film']
# 1314300                                ['melodic', 'space']
#
#                                              gpt_mood/theme  \
# Track_ID
# 1088000   ['melancholic', 'sad', 'slow', 'emotional', 'd...
# 759300    ['melodic', 'mellow', 'slow', 'relaxing', 'nos...
# 1066500         ['melancholic', 'sad', 'slow', 'emotional']
# 1416200   ['melancholic', 'sad', 'emotional', 'slow', 'd...
# 1189900   ['melancholic', 'sad', 'slow', 'emotional', 'r...
# ...                                                     ...
# 1110500                ['melancholic', 'slow', 'emotional']
# 794600    ['melancholic', 'slow', 'emotional', 'drama', ...
# 1101300   ['melodic', 'slow', 'mellow', 'soft', 'romanti...
# 798200    ['melancholic', 'sad', 'slow', 'emotional', 'd...
# 1314300          ['fun', 'uplifting', 'energetic', 'party']
#
#                                        Predicted_mood/theme         bpm  \
# Track_ID
# 1088000   The song is a melancholic one, evoking a sense...  119.910202
# 759300    The song is a melodic piece that evokes a sens...   99.987396
# 1066500   The song in question is a melancholic one, wit...   95.076775
# 1416200   The song is a melancholic one, evoking a sense...  101.623245
# 1189900   The song is a melancholic one, evoking a sense...  154.786545
# ...                                                     ...         ...
# 1110500   The song in question is a melodic piece that e...   98.976578
# 794600    This song is a melancholic piece, evoking a se...  105.142189
# 1101300   The song is a melodic piece that evokes a sens...   99.990570
# 798200    This song is a melancholic piece, evoking a se...  120.123466
# 1314300   The song is a melodic piece that evokes a sens...  125.808838
#
#           gpt_bpm                                      Predicted_bpm  \
# Track_ID
# 1088000       120  The song is a high-tempo, energetic piece of m...
# 759300        100  The song in question is a mid-tempo piece, wit...
# 1066500       100  The song in question has a tempo of 100 beats ...
# 1416200        60  The song in question is a slow-paced, melodic ...
# 1189900        60  The song is a slow-paced one, with a tempo of ...
# ...           ...                                                ...
# 1110500        60  The song in question is a slow-paced, mellow p...
# 794600        120  120. The song is a slow-paced, melodic piece t...
# 1101300       100  The song is a medium-tempo piece, with a tempo...
# 798200        100  The song in question is a slow-paced, melodic ...
# 1314300        60  The song in question is a slow-paced, melodic ...
#
#                key       gpt_key  \
# Track_ID
# 1088000    D minor       B minor
# 759300     A minor  B flat minor
# 1066500    G major       C minor
# 1416200   D# major       C minor
# 1189900    F major       C minor
# ...            ...           ...
# 1110500    C major       C minor
# 794600    A# major       C minor
# 1101300    D minor       C minor
# 798200     C major       C minor
# 1314300    E minor       B minor
#
#                                               Predicted_key  \
# Track_ID
# 1088000   This song is in the key of B minor. The song i...
# 759300    The song is in the key of B flat. This is a mi...
# 1066500   The song is in the key of C minor. This is a m...
# 1416200   This song is in the key of C minor. The reason...
# 1189900   It's a song in the key of C minor. The song is...
# ...                                                     ...
# 1110500   The song is in the key of C minor. This is a m...
# 794600    This song is in the key of C minor. The melody...
# 1101300   The song is in the key of C minor. This is a m...
# 798200    The song is in the key of C minor. This is a m...
# 1314300   The song is in the key of B minor. This is a m...
#
#                                                 description
# Track_ID
# 1088000   This song is a melodic techno piece, which is ...
# 759300    This song is a hip-hop track, characterized by...
# 1066500   This song is a melodic piece that belongs to t...
# 1416200   This song is categorized as a classical piece,...
# 1189900   This song is a blend of two genres, namely the...
# ...                                                     ...
# 1110500   This song is categorized as a genre of electro...
# 794600    This song is a melodic piece that belongs to t...
# 1101300   This song is categorized as a pop song. Pop mu...
# 798200    This song is a melodic piece that can be class...
# 1314300   This song is a melodic piece of music that bel...
#
# [120 rows x 17 columns]

# %%
metadata=song_csv[['instrument','genre','mood/theme','bpm','key']]
metadata
# Out:
#                                                  instrument  \
# Track_ID
# 1088000                                     ['synthesizer']
# 759300                         ['strings', 'bass', 'drums']
# 1066500      ['accordion', 'ukulele', 'pipeorgan', 'drums']
# 1416200                            ['piano', 'synthesizer']
# 1189900                                 ['guitar', 'drums']
# ...                                                     ...
# 1110500   ['viola', 'violin', 'drummachine', 'cello', 's...
# 794600    ['trumpet', 'violin', 'piano', 'trombone', 'ce...
# 1101300                        ['piano', 'classicalguitar']
# 798200    ['doublebass', 'horn', 'flute', 'violin', 'pia...
# 1314300                                     ['bass', 'pad']
#
#                                                       genre  \
# Track_ID
# 1088000                ['alternative', 'soundtrack', 'pop']
# 759300                                       ['soundtrack']
# 1066500                                             ['pop']
# 1416200            ['ambient', 'electronica', 'soundtrack']
# 1189900                       ['indie', 'rock', 'punkrock']
# ...                                                     ...
# 1110500                           ['ambient', 'electronic']
# 794600                         ['orchestral', 'soundtrack']
# 1101300                       ['lounge', 'newage', 'ethno']
# 798200    ['classical', 'medieval', 'soundtrack', 'orche...
# 1314300          ['downtempo', 'atmospheric', 'soundtrack']
#
#                                                  mood/theme         bpm  \
# Track_ID
# 1088000                                           ['sport']  119.910202
# 759300                                             ['game']   99.987396
# 1066500   ['positive', 'uplifting', 'advertising', 'happy']   95.076775
# 1416200                                 ['sad', 'romantic']  101.623245
# 1189900                                   ['retro', 'cool']  154.786545
# ...                                                     ...         ...
# 1110500                                       ['uplifting']   98.976578
# 794600                                             ['film']  105.142189
# 1101300                                      ['meditative']   99.990570
# 798200                          ['epic', 'trailer', 'film']  120.123466
# 1314300                                ['melodic', 'space']  125.808838
#
#                key
# Track_ID
# 1088000    D minor
# 759300     A minor
# 1066500    G major
# 1416200   D# major
# 1189900    F major
# ...            ...
# 1110500    C major
# 794600    A# major
# 1101300    D minor
# 798200     C major
# 1314300    E minor
#
# [120 rows x 5 columns]

# %%
metadata=metadata.to_dict('index')
metadata
# Out:
# {1088000: {'instrument': "['synthesizer']",
#   'genre': "['alternative', 'soundtrack', 'pop']",
#   'mood/theme': "['sport']",
#   'bpm': 119.910202026,
#   'key': 'D minor'},
#  759300: {'instrument': "['strings', 'bass', 'drums']",
#   'genre': "['soundtrack']",
#   'mood/theme': "['game']",
#   'bpm': 99.9873962402,
#   'key': 'A minor'},
#  1066500: {'instrument': "['accordion', 'ukulele', 'pipeorgan', 'drums']",
#   'genre': "['pop']",
#   'mood/theme': "['positive', 'uplifting', 'advertising', 'happy']",
#   'bpm': 95.0767745972,
#   'key': 'G major'},
#  1416200: {'instrument': "['piano', 'synthesizer']",
#   'genre': "['ambient', 'electronica', 'soundtrack']",
#   'mood/theme': "['sad', 'romantic']",
#   'bpm': 101.623245239,
#   'key': 'D# major'},
#  1189900: {'instrument': "['guitar', 'drums']",
#   'genre': "['indie', 'rock', 'punkrock']",
#   'mood/theme': "['retro', 'cool']",
#   'bpm': 154.7865448,
#   'key': 'F major'},
#  1317900: {'instrument': "['guitar']",
#   'genre': "['rock', 'alternative', 'punkrock']",
#   'mood/theme': "['fun']",
#   'bpm': 143.721221924,
#   'key': 'E major'},
#  1300500: {'instrument': "['piano']",
#   'genre': "['darkambient', 'experimental']",
#   'mood/theme': "['sad']",
#   'bpm': 63.0484466553,
#   'key': 'A# minor'},
#  1125400: {'instrument': "['electricguitar', 'computer']",
#   'genre': "['experimental', 'ambient', 'electronic']",
#   'mood/theme': "['nature']",
#   'bpm': 98.9011077881,
#   'key': 'A# major'},
#  604700: {'instrument': "['acousticguitar', 'drums', 'electricguitar', 'keyboard', 'bass', 'synthesizer']",
#   'genre': "['poprock', 'pop']",
#   'mood/theme': "['soft', 'romantic', 'emotional']",
#   'bpm': 172.26550293,
#   'key': 'D minor'},
#  702500: {'instrument': "['orchestra']",
#   'genre': "['symphonic', 'world', 'soundtrack']",
#   'mood/theme': "['drama', 'dramatic', 'film', 'melancholic']",
#   'bpm': 120.015769958,
#   'key': 'C major'},
#  1073700: {'instrument': "['synthesizer']",
#   'genre': "['atmospheric', 'ambient', 'soundtrack', 'electronic']",
#   'mood/theme': "['soundscape']",
#   'bpm': 104.767745972,
#   'key': 'D minor'},
#  1372200: {'instrument': "['guitar']",
#   'genre': "['electropop', 'indie', 'electronica', 'poprock']",
#   'mood/theme': "['upbeat']",
#   'bpm': 126.032211304,
#   'key': 'A# major'},
#  1337900: {'instrument': "['guitar']",
#   'genre': "['chillout', 'trance', 'easylistening']",
#   'mood/theme': "['meditative']",
#   'bpm': 135.886322021,
#   'key': 'C# major'},
#  945200: {'instrument': "['synthesizer']",
#   'genre': "['house', 'dance', 'pop']",
#   'mood/theme': "['summer', 'happy']",
#   'bpm': 128.268371582,
#   'key': 'D# minor'},
#  501300: {'instrument': "['piano']",
#   'genre': "['classical']",
#   'mood/theme': "['romantic']",
#   'bpm': 139.105636597,
#   'key': 'G minor'},
#  1115700: {'instrument': "['electricguitar', 'bass', 'electricpiano', 'drums']",
#   'genre': "['instrumentalpop', 'indie', 'pop']",
#   'mood/theme': "['melodic']",
#   'bpm': 129.639434814,
#   'key': 'A major'},
#  1388600: {'instrument': "['synthesizer']",
#   'genre': "['experimental']",
#   'mood/theme': "['slow', 'dark']",
#   'bpm': 100.000473022,
#   'key': 'C minor'},
#  1158200: {'instrument': "['piano', 'synthesizer']",
#   'genre': "['ambient', 'soundtrack']",
#   'mood/theme': "['energetic']",
#   'bpm': 109.878768921,
#   'key': 'C major'},
#  872000: {'instrument': "['synthesizer']",
#   'genre': "['contemporary', 'atmospheric', 'dubstep', 'electronic']",
#   'mood/theme': "['uplifting']",
#   'bpm': 135.031051636,
#   'key': 'A major'},
#  1320000: {'instrument': "['piano', 'bass', 'guitar', 'drums']",
#   'genre': "['downtempo', 'triphop', 'hiphop']",
#   'mood/theme': "['upbeat', 'dark']",
#   'bpm': 83.0498428345,
#   'key': 'F# minor'},
#  1080900: {'instrument': "['electricguitar']",
#   'genre': "['classical', 'hiphop', 'soundtrack']",
#   'mood/theme': "['film']",
#   'bpm': 161.512939453,
#   'key': 'F major'},
#  816200: {'instrument': "['piano']",
#   'genre': "['newage', 'soundtrack']",
#   'mood/theme': "['soft', 'love', 'documentary', 'children', 'emotional']",
#   'bpm': 162.334091187,
#   'key': 'C major'},
#  1037900: {'instrument': "['piano', 'harp']",
#   'genre': "['lounge', 'newage', 'ambient']",
#   'mood/theme': "['ambiental', 'background']",
#   'bpm': 119.950935364,
#   'key': 'C minor'},
#  1327700: {'instrument': "['flute', 'guitar']",
#   'genre': "['chillout', 'ambient', 'psychedelic']",
#   'mood/theme': "['soundscape', 'relaxing']",
#   'bpm': 120.175621033,
#   'key': 'G major'},
#  1353300: {'instrument': "['keyboard', 'percussion', 'bass', 'drums', 'synthesizer']",
#   'genre': "['chillout', 'house']",
#   'mood/theme': "['summer', 'deep', 'happy']",
#   'bpm': 114.856483459,
#   'key': 'F minor'},
#  1357400: {'instrument': "['piano']",
#   'genre': "['classical', 'easylistening']",
#   'mood/theme': "['romantic', 'emotional']",
#   'bpm': 120.02028656,
#   'key': 'C major'},
#  1041500: {'instrument': "['piano']",
#   'genre': "['minimal', 'easylistening', 'soundtrack']",
#   'mood/theme': "['melodic']",
#   'bpm': 136.866104126,
#   'key': 'A minor'},
#  1374300: {'instrument': "['piano']",
#   'genre': "['minimal', 'classical', 'easylistening']",
#   'mood/theme': "['calm']",
#   'bpm': 110.900253296,
#   'key': 'E minor'},
#  1096800: {'instrument': "['electricguitar', 'voice', 'synthesizer']",
#   'genre': "['experimental', 'alternative', 'gothic', 'electronic']",
#   'mood/theme': "['sad']",
#   'bpm': 99.9737625122,
#   'key': 'E major'},
#  1062500: {'instrument': "['synthesizer']",
#   'genre': "['ambient']",
#   'mood/theme': "['relaxing', 'holiday', 'christmas', 'calm']",
#   'bpm': 103.501441956,
#   'key': 'G major'},
#  682600: {'instrument': "['guitar', 'pad']",
#   'genre': "['newage', 'ambient', 'easylistening', 'soundtrack']",
#   'mood/theme': "['meditative']",
#   'bpm': 161.499649048,
#   'key': 'F major'},
#  80500: {'instrument': "['guitar']",
#   'genre': "['pop']",
#   'mood/theme': "['mellow']",
#   'bpm': 133.489547729,
#   'key': 'A major'},
#  1121400: {'instrument': "['drummachine', 'synthesizer', 'violin']",
#   'genre': "['reggae', 'dance', 'pop']",
#   'mood/theme': "['energetic', 'party']",
#   'bpm': 120.002471924,
#   'key': 'D# major'},
#  1087100: {'instrument': "['acousticguitar', 'piano', 'electricguitar', 'cello', 'synthesizer']",
#   'genre': "['instrumentalpop', 'easylistening']",
#   'mood/theme': "['motivational', 'positive', 'inspiring', 'happy']",
#   'bpm': 109.935836792,
#   'key': 'A minor'},
#  1014400: {'instrument': "['guitar']",
#   'genre': "['metal', 'alternative', 'rock']",
#   'mood/theme': "['sad', 'space']",
#   'bpm': 84.8799591064,
#   'key': 'E minor'},
#  1052800: {'instrument': "['synthesizer']",
#   'genre': "['postrock', 'ambient']",
#   'mood/theme': "['hopeful']",
#   'bpm': 100.012939453,
#   'key': 'G major'},
#  399500: {'instrument': "['piano']",
#   'genre': "['electronic']",
#   'mood/theme': "['film']",
#   'bpm': 98.8434524536,
#   'key': 'G minor'},
#  1090700: {'instrument': "['computer']",
#   'genre': "['experimental', 'ambient']",
#   'mood/theme': "['dark']",
#   'bpm': 172.265777588,
#   'key': 'C# major'},
#  1056400: {'instrument': "['acousticguitar', 'drums', 'piano', 'electricguitar', 'synthesizer']",
#   'genre': "['chillout', 'easylistening']",
#   'mood/theme': "['dream']",
#   'bpm': 161.498977661,
#   'key': 'C major'},
#  1371800: {'instrument': "['piano', 'horn', 'rhodes']",
#   'genre': "['chillout', 'acidjazz', 'funk']",
#   'mood/theme': "['groovy', 'cool']",
#   'bpm': 99.9706420898,
#   'key': 'F major'},
#  95400: {'instrument': "['piano']",
#   'genre': "['soundtrack']",
#   'mood/theme': "['dark']",
#   'bpm': 129.975204468,
#   'key': 'A minor'},
#  1081000: {'instrument': "['guitar']",
#   'genre': "['pop']",
#   'mood/theme': "['love', 'happy']",
#   'bpm': 72.0010604858,
#   'key': 'C major'},
#  1132200: {'instrument': "['orchestra']",
#   'genre': "['easylistening', 'swing']",
#   'mood/theme': "['fun']",
#   'bpm': 120.013366699,
#   'key': 'C# major'},
#  1170600: {'instrument': "['piano', 'acousticbassguitar', 'classicalguitar', 'guitar']",
#   'genre': "['soundtrack']",
#   'mood/theme': "['melancholic']",
#   'bpm': 99.9439239502,
#   'key': 'F major'},
#  752300: {'instrument': "['piano']",
#   'genre': "['classical', 'easylistening']",
#   'mood/theme': "['background']",
#   'bpm': 149.862136841,
#   'key': 'C# minor'},
#  1366700: {'instrument': "['keyboard', 'strings', 'flute']",
#   'genre': "['chillout', 'easylistening', 'soundtrack']",
#   'mood/theme': "['soft', 'melodic']",
#   'bpm': 123.86164093,
#   'key': 'F major'},
#  206000: {'instrument': "['bass', 'synthesizer', 'drums']",
#   'genre': "['newage', 'ambient', 'easylistening', 'fusion', 'experimental', 'electronic']",
#   'mood/theme': "['documentary', 'drama']",
#   'bpm': 94.9320602417,
#   'key': 'A minor'},
#  86200: {'instrument': "['guitar']",
#   'genre': "['instrumentalpop', 'blues', 'pop']",
#   'mood/theme': "['calm']",
#   'bpm': 102.940666199,
#   'key': 'E minor'},
#  1062600: {'instrument': "['acousticguitar', 'classicalguitar', 'electricpiano', 'keyboard', 'piano', 'electricguitar']",
#   'genre': "['chillout', 'ambient', 'easylistening', 'soundtrack']",
#   'mood/theme': "['advertising', 'motivational']",
#   'bpm': 128.035400391,
#   'key': 'F major'},
#  1284300: {'instrument': "['strings']",
#   'genre': "['world', 'ambient', 'soundtrack']",
#   'mood/theme': "['epic', 'trailer']",
#   'bpm': 133.372970581,
#   'key': 'G major'},
#  1211600: {'instrument': "['piano']",
#   'genre': "['popfolk', 'singersongwriter', 'pop']",
#   'mood/theme': "['sad', 'emotional']",
#   'bpm': 139.930252075,
#   'key': 'C minor'},
#  729300: {'instrument': "['doublebass', 'horn', 'harp', 'classicalguitar', 'violin', 'cello', 'trumpet', 'flute', 'oboe', 'trombone']",
#   'genre': "['classical', 'orchestral', 'soundtrack']",
#   'mood/theme': "['film']",
#   'bpm': 119.96762085,
#   'key': 'F minor'},
#  1420500: {'instrument': "['keyboard', 'percussion', 'bass', 'drums', 'synthesizer']",
#   'genre': "['chillout', 'dance']",
#   'mood/theme': "['summer', 'deep', 'happy']",
#   'bpm': 122.056167603,
#   'key': 'A# major'},
#  1066200: {'instrument': "['piano', 'strings']",
#   'genre': "['ambient', 'easylistening']",
#   'mood/theme': "['relaxing']",
#   'bpm': 144.776428223,
#   'key': 'C# major'},
#  1398500: {'instrument': "['acousticguitar', 'guitar']",
#   'genre': "['popfolk', 'folk']",
#   'mood/theme': "['holiday', 'christmas']",
#   'bpm': 162.160110474,
#   'key': 'E major'},
#  7400: {'instrument': "['drums', 'sampler', 'bass', 'cello', 'computer', 'strings', 'drummachine', 'keyboard']",
#   'genre': "['downtempo', 'pop', 'easylistening', 'choir', 'orchestral', 'soundtrack', 'electronic']",
#   'mood/theme': "['drama']",
#   'bpm': 119.940948486,
#   'key': 'A minor'},
#  1227500: {'instrument': "['strings', 'guitar']",
#   'genre': "['soundtrack']",
#   'mood/theme': "['adventure', 'documentary', 'film', 'advertising']",
#   'bpm': 124.933891296,
#   'key': 'B minor'},
#  1116400: {'instrument': "['piano']",
#   'genre': "['classical']",
#   'mood/theme': "['soft', 'relaxing', 'dream']",
#   'bpm': 92.3565673828,
#   'key': 'C major'},
#  1082100: {'instrument': "['clarinet', 'cello', 'violin']",
#   'genre': "['classical']",
#   'mood/theme': "['trailer', 'movie', 'love', 'romantic']",
#   'bpm': 136.522293091,
#   'key': 'F minor'},
#  1163000: {'instrument': "['electricguitar', 'strings', 'synthesizer', 'percussion']",
#   'genre': "['orchestral', 'easylistening']",
#   'mood/theme': "['soft', 'calm']",
#   'bpm': 135.077362061,
#   'key': 'D major'},
#  1393400: {'instrument': "['synthesizer', 'guitar', 'drums']",
#   'genre': "['hardrock', 'rock', 'alternative']",
#   'mood/theme': "['dark']",
#   'bpm': 99.7636642456,
#   'key': 'C# major'},
#  757500: {'instrument': "['piano']",
#   'genre': "['classical']",
#   'mood/theme': "['love', 'nature', 'adventure', 'melodic', 'dream']",
#   'bpm': 152.657073975,
#   'key': 'E minor'},
#  1282300: {'instrument': "['flute', 'ukulele']",
#   'genre': "['popfolk', 'easylistening', 'pop']",
#   'mood/theme': "['upbeat', 'positive', 'children', 'happy']",
#   'bpm': 99.8442840576,
#   'key': 'C major'},
#  1277700: {'instrument': "['piano', 'percussion']",
#   'genre': "['classical', 'orchestral', 'soundtrack']",
#   'mood/theme': "['funny']",
#   'bpm': 137.687927246,
#   'key': 'G# major'},
#  1166100: {'instrument': "['ukulele']",
#   'genre': "['world', 'folk', 'soundtrack']",
#   'mood/theme': "['upbeat', 'energetic', 'corporate', 'happy']",
#   'bpm': 79.9763946533,
#   'key': 'E minor'},
#  1396500: {'instrument': "['piano']",
#   'genre': "['classical']",
#   'mood/theme': "['emotional', 'calm', 'melancholic']",
#   'bpm': 136.953536987,
#   'key': 'A minor'},
#  1012000: {'instrument': "['trumpet', 'violin', 'piano', 'trombone', 'cello']",
#   'genre': "['ambient', 'classical', 'soundtrack']",
#   'mood/theme': "['epic', 'film', 'emotional']",
#   'bpm': 79.9841766357,
#   'key': 'A minor'},
#  913700: {'instrument': "['synthesizer']",
#   'genre': "['chillout', 'pop', '80s', 'electronic']",
#   'mood/theme': "['retro']",
#   'bpm': 89.9383850098,
#   'key': 'C# minor'},
#  1028900: {'instrument': "['piano']",
#   'genre': "['classical']",
#   'mood/theme': "['sad']",
#   'bpm': 119.987449646,
#   'key': 'D major'},
#  1084200: {'instrument': "['trumpet', 'drums', 'drummachine', 'electricguitar', 'trombone', 'synthesizer', 'violin']",
#   'genre': "['classical', 'orchestral']",
#   'mood/theme': "['trailer']",
#   'bpm': 130.019882202,
#   'key': 'D minor'},
#  1395500: {'instrument': "['ukulele']",
#   'genre': "['singersongwriter', 'folk', 'pop']",
#   'mood/theme': "['love']",
#   'bpm': 129.879150391,
#   'key': 'F major'},
#  1173500: {'instrument': "['piano', 'strings']",
#   'genre': "['atmospheric', 'ambient', 'soundtrack']",
#   'mood/theme': "['movie']",
#   'bpm': 79.946182251,
#   'key': 'E minor'},
#  661300: {'instrument': "['piano']",
#   'genre': "['electronic']",
#   'mood/theme': "['film']",
#   'bpm': 122.073120117,
#   'key': 'E major'},
#  1339700: {'instrument': "['bell', 'synthesizer']",
#   'genre': "['ambient']",
#   'mood/theme': "['dream']",
#   'bpm': 88.3791656494,
#   'key': 'C major'},
#  1420600: {'instrument': "['keyboard', 'percussion', 'bass', 'drums', 'synthesizer']",
#   'genre': "['lounge', 'reggae', 'house']",
#   'mood/theme': "['deep']",
#   'bpm': 105.008560181,
#   'key': 'D# major'},
#  1155900: {'instrument': "['strings', 'brass']",
#   'genre': "['classical', 'orchestral', 'soundtrack']",
#   'mood/theme': "['fun']",
#   'bpm': 110.004760742,
#   'key': 'E minor'},
#  1416000: {'instrument': "['synthesizer']",
#   'genre': "['chillout', 'newage', 'ambient']",
#   'mood/theme': "['corporate']",
#   'bpm': 115.866889954,
#   'key': 'C major'},
#  1266500: {'instrument': "['violin']",
#   'genre': "['synthpop', 'triphop', 'pop']",
#   'mood/theme': "['commercial', 'advertising', 'motivational']",
#   'bpm': 99.8000259399,
#   'key': 'A major'},
#  1330500: {'instrument': "['guitar']",
#   'genre': "['atmospheric', 'classical', 'easylistening']",
#   'mood/theme': "['nature']",
#   'bpm': 120.068626404,
#   'key': 'A minor'},
#  1129800: {'instrument': "['computer', 'synthesizer', 'keyboard']",
#   'genre': "['ambient', 'classical', 'electronic']",
#   'mood/theme': "['meditative', 'relaxing']",
#   'bpm': 122.992225647,
#   'key': 'E major'},
#  950100: {'instrument': "['sampler', 'synthesizer']",
#   'genre': "['90s', 'dance', 'eurodance', 'electronic']",
#   'mood/theme': "['melodic']",
#   'bpm': 142.977752686,
#   'key': 'A# major'},
#  1385300: {'instrument': "['piano']",
#   'genre': "['ambient', 'electronic']",
#   'mood/theme': "['sad', 'dramatic']",
#   'bpm': 140.015197754,
#   'key': 'F major'},
#  1398100: {'instrument': "['synthesizer', 'drums']",
#   'genre': "['chillout', 'rnb', 'pop']",
#   'mood/theme': "['love']",
#   'bpm': 161.754302979,
#   'key': 'F major'},
#  1248600: {'instrument': "['beat', 'electricguitar', 'guitar']",
#   'genre': "['downtempo', 'hiphop', 'electronic']",
#   'mood/theme': "['relaxing']",
#   'bpm': 161.565658569,
#   'key': 'E minor'},
#  1086300: {'instrument': "['acousticguitar']",
#   'genre': "['folk', 'country', 'soundtrack']",
#   'mood/theme': "['soft']",
#   'bpm': 178.205871582,
#   'key': 'C major'},
#  847200: {'instrument': "['piano']",
#   'genre': "['classical']",
#   'mood/theme': "['meditative', 'relaxing']",
#   'bpm': 91.263710022,
#   'key': 'F minor'},
#  1324900: {'instrument': "['trumpet']",
#   'genre': "['easylistening', 'pop']",
#   'mood/theme': "['sad', 'romantic']",
#   'bpm': 166.614822388,
#   'key': 'C major'},
#  633200: {'instrument': "['piano']",
#   'genre': "['symphonic', 'classical', 'orchestral', 'soundtrack']",
#   'mood/theme': "['sad', 'love', 'dream']",
#   'bpm': 109.977622986,
#   'key': 'D minor'},
#  1222000: {'instrument': "['harp']",
#   'genre': "['folk', 'ethno', 'latin']",
#   'mood/theme': "['positive', 'children', 'relaxing']",
#   'bpm': 172.265289307,
#   'key': 'D minor'},
#  1076600: {'instrument': "['acousticbassguitar', 'electricpiano', 'drums', 'violin', 'accordion']",
#   'genre': "['chillout', 'dance', 'world', 'electronic', 'soundtrack']",
#   'mood/theme': "['movie']",
#   'bpm': 83.6870803833,
#   'key': 'D# minor'},
#  116600: {'instrument': "['piano']",
#   'genre': "['experimental', 'alternative', 'ambient', 'electronic']",
#   'mood/theme': "['meditative']",
#   'bpm': 139.531311035,
#   'key': 'D# major'},
#  1195900: {'instrument': "['ukulele']",
#   'genre': "['rock', 'pop']",
#   'mood/theme': "['corporate', 'happy']",
#   'bpm': 105.108047485,
#   'key': 'G major'},
#  1109900: {'instrument': "['bass', 'synthesizer', 'drums']",
#   'genre': "['indie', 'electronic']",
#   'mood/theme': "['advertising']",
#   'bpm': 97.9883956909,
#   'key': 'A major'},
#  1105300: {'instrument': "['piano', 'synthesizer']",
#   'genre': "['easylistening']",
#   'mood/theme': "['meditative', 'movie']",
#   'bpm': 128.508056641,
#   'key': 'C minor'},
#  840600: {'instrument': "['guitar']",
#   'genre': "['rock', 'poprock']",
#   'mood/theme': "['happy']",
#   'bpm': 106.632850647,
#   'key': 'A# major'},
#  1250200: {'instrument': "['beat', 'strings', 'piano', 'drums']",
#   'genre': "['easylistening', 'pop']",
#   'mood/theme': "['happy']",
#   'bpm': 129.940948486,
#   'key': 'D# minor'},
#  1420700: {'instrument': "['keyboard', 'percussion', 'bass', 'drums', 'synthesizer']",
#   'genre': "['chillout', 'house', 'dance', 'easylistening', 'club']",
#   'mood/theme': "['deep', 'happy']",
#   'bpm': 121.997840881,
#   'key': 'G major'},
#  635300: {'instrument': "['doublebass', 'strings', 'viola', 'piano', 'cello']",
#   'genre': "['classical', 'soundtrack']",
#   'mood/theme': "['emotional']",
#   'bpm': 114.333808899,
#   'key': 'D# major'},
#  1164200: {'instrument': "['drummachine', 'synthesizer', 'sampler']",
#   'genre': "['electronic']",
#   'mood/theme': "['retro', 'energetic', 'fun', 'happy']",
#   'bpm': 106.608634949,
#   'key': 'G major'},
#  903600: {'instrument': "['piano']",
#   'genre': "['classical', 'easylistening']",
#   'mood/theme': "['relaxing', 'background']",
#   'bpm': 184.570343018,
#   'key': 'G minor'},
#  1202100: {'instrument': "['acousticguitar']",
#   'genre': "['chillout', 'poprock', 'easylistening']",
#   'mood/theme': "['calm', 'background']",
#   'bpm': 108.997642517,
#   'key': 'A major'},
#  1155000: {'instrument': "['synthesizer']",
#   'genre': "['indie', 'dance', 'techno']",
#   'mood/theme': "['party']",
#   'bpm': 134.776016235,
#   'key': 'F minor'},
#  659900: {'instrument': "['violin', 'cello', 'trumpet', 'flute', 'voice', 'piano', 'drummachine', 'electricguitar', 'harp', 'drums', 'brass', 'clarinet', 'bass', 'synthesizer', 'computer', 'strings', 'electricpiano', 'keyboard', 'bongo', 'trombone']",
#   'genre': "['triphop', 'experimental', 'hiphop']",
#   'mood/theme': "['dark']",
#   'bpm': 148.03944397,
#   'key': 'G# major'},
#  920000: {'instrument': "['piano']",
#   'genre': "['newage', 'soundtrack']",
#   'mood/theme': "['documentary', 'children', 'dream']",
#   'bpm': 140.20993042,
#   'key': 'C major'},
#  1009600: {'instrument': "['doublebass', 'harp', 'clarinet', 'violin', 'cello', 'flute', 'viola', 'piano']",
#   'genre': "['classical', 'soundtrack']",
#   'mood/theme': "['romantic']",
#   'bpm': 118.223922729,
#   'key': 'D major'},
#  1162700: {'instrument': "['synthesizer']",
#   'genre': "['easylistening', 'pop']",
#   'mood/theme': "['children', 'advertising']",
#   'bpm': 134.005447388,
#   'key': 'C major'},
#  501200: {'instrument': "['computer', 'drums', 'sampler', 'bass', 'synthesizer']",
#   'genre': "['fusion', 'experimental', 'electronic']",
#   'mood/theme': "['emotional']",
#   'bpm': 178.205566406,
#   'key': 'A# major'},
#  202200: {'instrument': "['piano']",
#   'genre': "['electronic']",
#   'mood/theme': "['film']",
#   'bpm': 131.977218628,
#   'key': 'C minor'},
#  893400: {'instrument': "['doublebass', 'voice', 'violin', 'piano', 'bass', 'cello']",
#   'genre': "['choir', 'classical', 'soundtrack']",
#   'mood/theme': "['dark']",
#   'bpm': 140.386245728,
#   'key': 'A minor'},
#  1303000: {'instrument': "['electricguitar']",
#   'genre': "['rock', 'punkrock']",
#   'mood/theme': "['adventure', 'energetic', 'sport']",
#   'bpm': 119.975143433,
#   'key': 'D major'},
#  718300: {'instrument': "['acousticguitar', 'flute', 'electricpiano']",
#   'genre': "['bossanova', 'dance', 'easylistening']",
#   'mood/theme': "['melodic', 'background']",
#   'bpm': 113.267623901,
#   'key': 'F major'},
#  1102300: {'instrument': "['acousticguitar', 'keyboard']",
#   'genre': "['world', 'poprock']",
#   'mood/theme': "['melodic']",
#   'bpm': 112.874359131,
#   'key': 'A major'},
#  1383900: {'instrument': "['synthesizer']",
#   'genre': "['electropop', 'synthpop', 'newwave']",
#   'mood/theme': "['game']",
#   'bpm': 139.918426514,
#   'key': 'F major'},
#  133600: {'instrument': "['electricguitar', 'bass', 'drums']",
#   'genre': "['rock', 'poprock', 'pop']",
#   'mood/theme': "['energetic', 'sport']",
#   'bpm': 107.905860901,
#   'key': 'B minor'},
#  1170400: {'instrument': "['piano', 'orchestra']",
#   'genre': "['classical', 'soundtrack']",
#   'mood/theme': "['movie']",
#   'bpm': 119.821510315,
#   'key': 'D major'},
#  1110500: {'instrument': "['viola', 'violin', 'drummachine', 'cello', 'synthesizer']",
#   'genre': "['ambient', 'electronic']",
#   'mood/theme': "['uplifting']",
#   'bpm': 98.9765777588,
#   'key': 'C major'},
#  794600: {'instrument': "['trumpet', 'violin', 'piano', 'trombone', 'cello']",
#   'genre': "['orchestral', 'soundtrack']",
#   'mood/theme': "['film']",
#   'bpm': 105.142189026,
#   'key': 'A# major'},
#  1101300: {'instrument': "['piano', 'classicalguitar']",
#   'genre': "['lounge', 'newage', 'ethno']",
#   'mood/theme': "['meditative']",
#   'bpm': 99.9905700684,
#   'key': 'D minor'},
#  798200: {'instrument': "['doublebass', 'horn', 'flute', 'violin', 'piano', 'cello']",
#   'genre': "['classical', 'medieval', 'soundtrack', 'orchestral']",
#   'mood/theme': "['epic', 'trailer', 'film']",
#   'bpm': 120.123466492,
#   'key': 'C major'},
#  1314300: {'instrument': "['bass', 'pad']",
#   'genre': "['downtempo', 'atmospheric', 'soundtrack']",
#   'mood/theme': "['melodic', 'space']",
#   'bpm': 125.808837891,
#   'key': 'E minor'}}

# %%
ids=list([str(idx) for idx in song_csv.index])
descriptions=list(song_csv['description'])
metadatas=[metadata[int(idx)] for idx in ids]

# %%
client = chromadb.PersistentClient(path=r'/home/opalinav/chroma120_v3')
collection = client.get_or_create_collection(name="Songs120_v3",embedding_function=openai_ef)

# %%
collection.add(ids=ids,documents=descriptions,metadatas=metadatas)
