# %%
# Note: include in the tests folder a .env file that contains the API keys for the services used in the tests    
import os
import pandas as pd  # type: ignore
import palimpzest as pz

if not os.environ.get('OPENAI_API_KEY'):
    with open('.env') as f:
        for line in f:
            key, value = line.strip().split('=')
            os.environ[key] = value

# %% [markdown]
# ### Columns definition
# In the following cell we target schema of the case study we are interested in. Note how we are not specifying target attributes with fine grained metadata but rather with natural language, possibly ambiguous, specifications.

# %%
case_data_cols = [
    {"name": "case_submitter_id", "type": str, "desc": "The ID of the case"},
    {"name": "age_at_diagnosis", "type": int | float, "desc": "The age of the patient at the time of diagnosis"},
    {"name": "race", "type": str, "desc": "An arbitrary classification of a taxonomic group that is a division of a species."},
    {"name": "ethnicity", "type": str, "desc": "Whether an individual describes themselves as Hispanic or Latino or not."},
    {"name": "gender", "type": str, "desc": "Text designations that identify gender."},
    {"name": "vital_status", "type": str, "desc": "The vital status of the patient"},
    {"name": "ajcc_pathologic_t", "type": str, "desc": "Code of pathological T (primary tumor) to define the size or contiguous extension of the primary tumor (T), using staging criteria from the American Joint Committee on Cancer (AJCC)."},
    {"name": "ajcc_pathologic_n", "type": str, "desc": "The codes that represent the stage of cancer based on the nodes present (N stage) according to criteria based on multiple editions of the AJCC's Cancer Staging Manual."},
    {"name": "ajcc_pathologic_stage", "type": str, "desc": "The extent of a cancer, especially whether the disease has spread from the original site to other parts of the body based on AJCC staging criteria."},
    {"name": "tumor_grade", "type": int | float, "desc": "Numeric value to express the degree of abnormality of cancer cells, a measure of differentiation and aggressiveness."},
    {"name": "tumor_focality", "type": str, "desc": "The text term used to describe whether the patient's disease originated in a single location or multiple locations."},
    {"name": "tumor_largest_dimension_diameter", "type": int | float, "desc": "The tumor largest dimension diameter."},
    {"name": "primary_diagnosis", "type": str, "desc": "Text term used to describe the patient's histologic diagnosis, as described by the World Health Organization's (WHO) International Classification of Diseases for Oncology (ICD-O)."},
    {"name": "morphology", "type": str, "desc": "The Morphological code of the tumor, as described by the World Health Organization's (WHO) International Classification of Diseases for Oncology (ICD-O)."},
    {"name": "tissue_or_organ_of_origin", "type": str, "desc": "The text term used to describe the anatomic site of origin, of the patient's malignant disease, as described by the World Health Organization's (WHO) International Classification of Diseases for Oncology (ICD-O)."},
    {"name": "study", "type": str, "desc": "The last name of the author of the study, from the table name"}
]

file_cols = [
    {"name": "filename", "type": str, "desc": "The name of the file"},
    {"name": "contents", "type": bytes, "desc": "The contents of the file"}
]

xls_cols = file_cols + [
    {"name": "number_sheets", "type": int, "desc": "The number of sheets in the Excel file"},
    {"name": "sheet_names", "type": list[str], "desc": "The names of the sheets in the Excel file"},
]

table_cols = [
    {"name": "rows", "type": list[str], "desc": "The rows of the table"},
    {"name": "header", "type": list[str], "desc": "The header of the table"},
    {"name": "name", "type": str, "desc": "The name of the table"},
    {"name": "filename", "type": str, "desc": "The name of the file the table was extracted from"}
]


print("Case Data columns:")
for col in case_data_cols[:5]:
    print(col)
# Out:
# Case Data columns:
# {'name': 'case_submitter_id', 'type': <class 'str'>, 'desc': 'The ID of the case'}
# {'name': 'age_at_diagnosis', 'type': int | float, 'desc': 'The age of the patient at the time of diagnosis'}
# {'name': 'race', 'type': <class 'str'>, 'desc': 'An arbitrary classification of a taxonomic group that is a division of a species.'}
# {'name': 'ethnicity', 'type': <class 'str'>, 'desc': 'Whether an individual describes themselves as Hispanic or Latino or not.'}
# {'name': 'gender', 'type': <class 'str'>, 'desc': 'Text designations that identify gender.'}

# %%
from palimpzest.core.elements.records import DataRecord

def print_result(records):
    df = DataRecord.to_df(records)
    cols = records[0].schema.field_names()
    display(df[cols])

def print_stats(stats):
    print("Chosen plan")
    print(result.executed_plans[0])
    print("Total execution time:", stats.total_execution_time,"seconds")
    print("Total execution cost:", stats.total_execution_cost, "USD")
    # print("Total time optimizing pipeline:", stats.total_optimization_time, "seconds")

# %% [markdown]
# ## Printing base dataset
# In the following cell we print the base dataset we are interested in. Note how we are not specifying target attributes with fine grained metadata but rather with natural language, possibly ambiguous, specifications.

# %%
papers_html = pz.Dataset("../testdata/biofabric-html")
output = papers_html

policy = pz.MinCost()
config = pz.QueryProcessorConfig(
    policy=policy,
    nocache=True,
    processing_strategy="no_sentinel",
)
result = output.run(config)

print_result(result.data_records)
# print_stats(result.execution_stats)
# Out:
# VBox(children=(IntProgress(value=0, bar_style='info', description='Processing:', max=11), HTML(value='<pre>Ini…
#          filename                                               html  \
# 0         cao.htm  <!DOCTYPE html> <html lang="en" class="pb-page...
# 1       clark.htm  <!DOCTYPE html> <html lang="en" class="pb-page...
# 2         dou.htm  <!DOCTYPE html> <html lang="en" class="pb-page...
# 3     gilette.htm  <!DOCTYPE html> <html lang="en" class="pb-page...
# 4       huang.htm  <!DOCTYPE html> <html lang="en" class="pb-page...
# 5        krug.htm  <!DOCTYPE html> <html lang="en" class="pb-page...
# 6          li.htm  <!DOCTYPE html> <html lang="en" class="pb-page...
# 7   mcdermott.htm  <!DOCTYPE html> <html lang="en" class="pb-page...
# 8    satpathy.htm  <!DOCTYPE html> <html lang="en" class="pb-page...
# 9    vasaikar.htm  <!DOCTYPE html> <html lang="en" class="pb-page...
# 10       wang.htm  <!DOCTYPE html> <html lang="en" class="pb-page...
#
#                                                  text     timestamp
# 0   Proteogenomic characterization of pancreatic d...  1.724867e+09
# 1   Integrated Proteogenomic Characterization of C...  1.724867e+09
# 2   Proteogenomic Characterization of Endometrial ...  1.724867e+09
# 3   Proteogenomic Characterization Reveals Therape...  1.724867e+09
# 4   Proteogenomic insights into the biology and tr...  1.724867e+09
# 5   Proteogenomic Landscape of Breast Cancer Tumor...  1.724867e+09
# 6   Proteogenomic data and resources for pan-cance...  1.724867e+09
# 7   Proteogenomic Characterization of Ovarian HGSC...  1.724867e+09
# 8   A proteogenomic portrait of lung squamous cell...  1.724867e+09
# 9   Proteogenomic Analysis of Human Colon Cancer R...  1.724867e+09
# 10  Proteogenomic and metabolomic characterization...  1.724867e+09

# %% [markdown]
# ### Downloading relevant tables from the papers

# %%
from palimpzest.utils import udfs

papers_html = pz.Dataset("../testdata/biofabric-html-tiny")
table_urls = papers_html.sem_add_columns(
    [{"name": "url", "type": str, "desc": "The URLs of the XLS tables from the page"}],
    cardinality=pz.Cardinality.ONE_TO_MANY)
files = table_urls.download()
output = files

policy = pz.MinCost()
config = pz.QueryProcessorConfig(policy=policy, nocache=True)
result = output.run(config)

print_result(result.data_records)
# Out:
# VBox(children=(IntProgress(value=0, bar_style='info', description='Processing:', max=3), HTML(value='<pre>Init…
#                                              contents filename  \
# 0                                                 b''  cao.htm
# 1   b'<!DOCTYPE html><html lang="en-US"><head><tit...  cao.htm
# 2   b'<!DOCTYPE html><html lang="en-US"><head><tit...  cao.htm
# 3   b'<!DOCTYPE html><html lang="en-US"><head><tit...  cao.htm
# 4   b'<!DOCTYPE html><html lang="en-US"><head><tit...  cao.htm
# 5   b'<!DOCTYPE html><html lang="en-US"><head><tit...  cao.htm
# 6   b'<!DOCTYPE html><html lang="en-US"><head><tit...  cao.htm
# 7   b'<!DOCTYPE html><html lang="en-US"><head><tit...  cao.htm
# 8                                                 b''  cao.htm
# 9   b'<!DOCTYPE html><html lang="en-US"><head><tit...  cao.htm
# 10  b'<!DOCTYPE html><html lang="en-US"><head><tit...  cao.htm
# 11  b'<!DOCTYPE html><html lang="en-US"><head><tit...  cao.htm
# 12  b'<!DOCTYPE html><html lang="en-US"><head><tit...  cao.htm
# 13  b'<!DOCTYPE html><html lang="en-US"><head><tit...  cao.htm
# 14  b'<!DOCTYPE html><html lang="en-US"><head><tit...  cao.htm
# 15  b'<!DOCTYPE html><html lang="en-US"><head><tit...  cao.htm
#
#                                                  html  \
# 0   <!DOCTYPE html> <html lang="en" class="pb-page...
# 1   <!DOCTYPE html> <html lang="en" class="pb-page...
# 2   <!DOCTYPE html> <html lang="en" class="pb-page...
# 3   <!DOCTYPE html> <html lang="en" class="pb-page...
# 4   <!DOCTYPE html> <html lang="en" class="pb-page...
# 5   <!DOCTYPE html> <html lang="en" class="pb-page...
# 6   <!DOCTYPE html> <html lang="en" class="pb-page...
# 7   <!DOCTYPE html> <html lang="en" class="pb-page...
# 8   <!DOCTYPE html> <html lang="en" class="pb-page...
# 9   <!DOCTYPE html> <html lang="en" class="pb-page...
# 10  <!DOCTYPE html> <html lang="en" class="pb-page...
# 11  <!DOCTYPE html> <html lang="en" class="pb-page...
# 12  <!DOCTYPE html> <html lang="en" class="pb-page...
# 13  <!DOCTYPE html> <html lang="en" class="pb-page...
# 14  <!DOCTYPE html> <html lang="en" class="pb-page...
# 15  <!DOCTYPE html> <html lang="en" class="pb-page...
#
#                                                  text     timestamp  \
# 0   Proteogenomic characterization of pancreatic d...  1.742491e+09
# 1   Proteogenomic characterization of pancreatic d...  1.742491e+09
# 2   Proteogenomic characterization of pancreatic d...  1.742491e+09
# 3   Proteogenomic characterization of pancreatic d...  1.742491e+09
# 4   Proteogenomic characterization of pancreatic d...  1.742491e+09
# 5   Proteogenomic characterization of pancreatic d...  1.742491e+09
# 6   Proteogenomic characterization of pancreatic d...  1.742491e+09
# 7   Proteogenomic characterization of pancreatic d...  1.742491e+09
# 8   Proteogenomic characterization of pancreatic d...  1.742491e+09
# 9   Proteogenomic characterization of pancreatic d...  1.742491e+09
# 10  Proteogenomic characterization of pancreatic d...  1.742491e+09
# 11  Proteogenomic characterization of pancreatic d...  1.742491e+09
# 12  Proteogenomic characterization of pancreatic d...  1.742491e+09
# 13  Proteogenomic characterization of pancreatic d...  1.742491e+09
# 14  Proteogenomic characterization of pancreatic d...  1.742491e+09
# 15  Proteogenomic characterization of pancreatic d...  1.742491e+09
#
#                                                   url
# 0                                                  []
# 1   /cms/10.1016/j.cell.2021.08.023/attachment/d1c...
# 2   /cms/10.1016/j.cell.2021.08.023/attachment/0f1...
# 3   /cms/10.1016/j.cell.2021.08.023/attachment/40d...
# 4   /cms/10.1016/j.cell.2021.08.023/attachment/01c...
# 5   /cms/10.1016/j.cell.2021.08.023/attachment/9be...
# 6   /cms/10.1016/j.cell.2021.08.023/attachment/a1c...
# 7   /cms/10.1016/j.cell.2021.08.023/attachment/39e...
# 8                                                  []
# 9   /cms/10.1016/j.cell.2021.08.023/attachment/d1c...
# 10  /cms/10.1016/j.cell.2021.08.023/attachment/0f1...
# 11  /cms/10.1016/j.cell.2021.08.023/attachment/40d...
# 12  /cms/10.1016/j.cell.2021.08.023/attachment/01c...
# 13  /cms/10.1016/j.cell.2021.08.023/attachment/9be...
# 14  /cms/10.1016/j.cell.2021.08.023/attachment/a1c...
# 15  /cms/10.1016/j.cell.2021.08.023/attachment/39e...

# %% [markdown]
# ### Filtering stage
# In the following cell we define the first part of the workload, that comprises a filtering stage responsible for selecting the tables from all the spreadsheets that contain relevant biometric information about the patient.

# %%
from palimpzest.utils import udfs
xls = pz.Dataset("../testdata/biofabric-tiny")
patient_tables = xls.add_columns(udf=udfs.xls_to_tables, cols=table_cols, cardinality=pz.Cardinality.ONE_TO_MANY)
patient_tables = patient_tables.sem_filter("The table contains biometric information about the patient")

output = patient_tables

policy = pz.MinCost()
config = pz.QueryProcessorConfig(policy=policy,nocache=True)
result = patient_tables.run(config)

print_result(result.data_records)
print_stats(result.execution_stats)
# Out:
# VBox(children=(IntProgress(value=0, bar_style='info', description='Processing:', max=9), HTML(value='<pre>Init…
#                                             contents            filename  \
# 0  b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...       dou_mmc1.xlsx
# 1  b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...  vasaikar_mmc1.xlsx
# 2  b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...  vasaikar_mmc1.xlsx
# 3  b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...      wang_mmc2.xlsx
# 4  b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...      wang_mmc2.xlsx
# 5  b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...      wang_mmc2.xlsx
#
#                                               header  \
# 0  [idx, Proteomics_Participant_ID, Case_excluded...
# 1  [Column name, Column definition, Unnamed: 2, U...
# 2  [SampleID, Clinical, Mutation, CNV, miRNA-seq,...
# 3  [case_id, age, gender, height, weight, bmi, co...
# 4  [case, sample_type, multiomic, nmf_consensus, ...
# 5  [aliquot_id, sample_id, original_aliquot_id, b...
#
#                                         name  number_sheets  \
# 0  dou_mmc1.xlsx_UCEC_CPTAC3_meta_table_V2.1              1
# 1            vasaikar_mmc1.xlsx_A-Annotation              3
# 2          vasaikar_mmc1.xlsx_B-ClinicalData              3
# 3               wang_mmc2.xlsx_clinical_data              5
# 4      wang_mmc2.xlsx_additional_annotations              5
# 5           wang_mmc2.xlsx_cbttc_sample_info              5
#
#                                                 rows  \
# 0  [[S001, C3L-00006, No, 2, 5, 128N, C3L-00006-0...
# 1  [[SampleID, ID of the prospective participant,...
# 2  [[Type, BIN, BIN, BIN, BIN, BIN, BIN, BIN, BIN...
# 3  [[C3L-00104, 58, Male, 188.0, 115.0, 32.54, Un...
# 4  [[C3L-00104, tumor, nmf1, nmf1, 0.743, Proneur...
# 5  [[7316-288-TISS [894482], 7316-288, 7316-288-T...
#
#                                          sheet_names
# 0                      [UCEC_CPTAC3_meta_table_V2.1]
# 1        [Description, A-Annotation, B-ClinicalData]
# 2        [Description, A-Annotation, B-ClinicalData]
# 3  [README, clinical_data, additional_annotations...
# 4  [README, clinical_data, additional_annotations...
# 5  [README, clinical_data, additional_annotations...
# Chosen plan
#  0. MarshalAndScanDataOp -> XLSFile
#
#  1. XLSFile -> NonLLMConvert -> Schema[['contents', 'filename', 'filename', 'header', 'name', 'number_sheets', 'rows', 'sheet_names']]
#     (contents, filename, number_she) -> (contents, filename, header, na)
#     UDF: <function xls_to_tables at 0x7fcdc4214720>
#
#  2. Schema[['contents', 'filename', 'filename', 'header', 'name', 'number_sheets', 'rows', 'sheet_names']] -> LLMFilter -> Schema[['contents', 'filename', 'filename', 'header', 'name', 'number_sheets', 'rows', 'sheet_names']]
#     (contents, filename, header, na) -> (contents, filename, header, na)
#     Model: Model.GPT_4o_MINI
#     Filter: The table contains biometric information about the patient
#
#
# Total execution time: 15.247003078460693 seconds
# Total execution cost: 0.0029549999999999993 USD

# %%
policy = pz.MaxQuality()

config = pz.QueryProcessorConfig(policy=policy, nocache=True)
result = patient_tables.run(config)
print_result(result.data_records)
print_stats(result.execution_stats)
# Out:
# VBox(children=(IntProgress(value=0, bar_style='info', description='Processing:', max=9), HTML(value='<pre>Init…
#                                             contents            filename  \
# 0  b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...       dou_mmc1.xlsx
# 1  b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...  vasaikar_mmc1.xlsx
# 2  b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...      wang_mmc2.xlsx
# 3  b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...      wang_mmc2.xlsx
#
#                                               header  \
# 0  [idx, Proteomics_Participant_ID, Case_excluded...
# 1  [SampleID, Clinical, Mutation, CNV, miRNA-seq,...
# 2      [README for Table S1, Unnamed: 1, Unnamed: 2]
# 3  [case_id, age, gender, height, weight, bmi, co...
#
#                                         name  number_sheets  \
# 0  dou_mmc1.xlsx_UCEC_CPTAC3_meta_table_V2.1              1
# 1          vasaikar_mmc1.xlsx_B-ClinicalData              3
# 2                      wang_mmc2.xlsx_README              5
# 3               wang_mmc2.xlsx_clinical_data              5
#
#                                                 rows  \
# 0  [[S001, C3L-00006, No, 2, 5, 128N, C3L-00006-0...
# 1  [[Type, BIN, BIN, BIN, BIN, BIN, BIN, BIN, BIN...
# 2  [[nan, nan, nan], [Tab1, clinical_data, Clinic...
# 3  [[C3L-00104, 58, Male, 188.0, 115.0, 32.54, Un...
#
#                                          sheet_names
# 0                      [UCEC_CPTAC3_meta_table_V2.1]
# 1        [Description, A-Annotation, B-ClinicalData]
# 2  [README, clinical_data, additional_annotations...
# 3  [README, clinical_data, additional_annotations...
# Chosen plan
#  0. MarshalAndScanDataOp -> XLSFile
#
#  1. XLSFile -> NonLLMConvert -> Schema[['contents', 'filename', 'filename', 'header', 'name', 'number_sheets', 'rows', 'sheet_names']]
#     (contents, filename, number_she) -> (contents, filename, header, na)
#     UDF: <function xls_to_tables at 0x7fcdc4214720>
#
#  2. Schema[['contents', 'filename', 'filename', 'header', 'name', 'number_sheets', 'rows', 'sheet_names']] -> LLMFilter -> Schema[['contents', 'filename', 'filename', 'header', 'name', 'number_sheets', 'rows', 'sheet_names']]
#     (contents, filename, header, na) -> (contents, filename, header, na)
#     Model: Model.GPT_4o
#     Filter: The table contains biometric information about the patient
#
#
# Total execution time: 20.54369831085205 seconds
# Total execution cost: 0.05419000000000001 USD

# %% [markdown]
# ## Matching stage
# Once filtered, we can define the second part of the workload, that matches the patient records in the different tables and merging the information into a single table.

# %% [markdown]
# Minimum cost: GPT 3.5

# %%
from palimpzest.utils import udfs   
input_dataset = pz.Dataset("../testdata/biofabric-tiny-filtered")
patient_tables = input_dataset.add_columns(udf=udfs.xls_to_tables, cols=table_cols, cardinality=pz.Cardinality.ONE_TO_MANY)
patient_tables = patient_tables.sem_filter("The table contains biometric information about the patient")
case_data = patient_tables.sem_add_columns(case_data_cols, cardinality=pz.Cardinality.ONE_TO_MANY)

policy = pz.MinCost()
config = pz.QueryProcessorConfig(
    policy=policy,
    nocache=True,
    allow_code_synth=False,
    processing_strategy="no_sentinel",
)
data_record_collection = case_data.run(config) 

print_result(data_record_collection.data_records)
print_stats(data_record_collection.execution_stats)
# Out:
# VBox(children=(IntProgress(value=0, bar_style='info', description='Processing:', max=12), HTML(value='<pre>Ini…
#     age_at_diagnosis ajcc_pathologic_n ajcc_pathologic_stage  \
# 0              38.88               pN0               Stage I
# 1              39.76               pNX              Stage IV
# 2              51.19               pN0               Stage I
# 3                NaN              None                  None
# 4              32.69               pNX               Stage I
# 5                NaN              None                  None
# 6             729.00               N2b             Stage III
# 7             838.00                N0              Stage II
# 8             904.00               N2b             Stage III
# 9             652.00                N0              Stage II
# 10             58.00               nan                   nan
#
#    ajcc_pathologic_t case_submitter_id  \
# 0     pT1a (FIGO IA)         C3L-00006
# 1     pT1a (FIGO IA)         C3L-00008
# 2     pT1a (FIGO IA)         C3L-00032
# 3               None         C3L-00084
# 4     pT1a (FIGO IA)         C3L-00090
# 5               None              None
# 6                T4a           01CO001
# 7                 T3           01CO005
# 8                T4a           01CO006
# 9                 T3           01CO008
# 10               nan         C3L-00104
#
#                                              contents               ethnicity  \
# 0   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...  Not-Hispanic or Latino
# 1   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...  Not-Hispanic or Latino
# 2   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...  Not-Hispanic or Latino
# 3   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...                      No
# 4   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...  Not-Hispanic or Latino
# 5   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...                    None
# 6   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...                    None
# 7   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...                    None
# 8   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...                    None
# 9   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...                    None
# 10  b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...  Not-Hispanic or Latino
#
#               filename  gender  \
# 0        dou_mmc1.xlsx  Female
# 1        dou_mmc1.xlsx  Female
# 2        dou_mmc1.xlsx  Female
# 3        dou_mmc1.xlsx  Female
# 4        dou_mmc1.xlsx  Female
# 5   vasaikar_mmc1.xlsx    None
# 6   vasaikar_mmc1.xlsx    Male
# 7   vasaikar_mmc1.xlsx  Female
# 8   vasaikar_mmc1.xlsx  Female
# 9   vasaikar_mmc1.xlsx  Female
# 10      wang_mmc2.xlsx    Male
#
#                                                header  ... primary_diagnosis  \
# 0   [idx, Proteomics_Participant_ID, Case_excluded...  ...      Endometrioid
# 1   [idx, Proteomics_Participant_ID, Case_excluded...  ...      Endometrioid
# 2   [idx, Proteomics_Participant_ID, Case_excluded...  ...      Endometrioid
# 3   [idx, Proteomics_Participant_ID, Case_excluded...  ...    Carcinosarcoma
# 4   [idx, Proteomics_Participant_ID, Case_excluded...  ...      Endometrioid
# 5                                [Sheet, Description]  ...              None
# 6   [SampleID, Clinical, Mutation, CNV, miRNA-seq,...  ...              None
# 7   [SampleID, Clinical, Mutation, CNV, miRNA-seq,...  ...              None
# 8   [SampleID, Clinical, Mutation, CNV, miRNA-seq,...  ...              None
# 9   [SampleID, Clinical, Mutation, CNV, miRNA-seq,...  ...              None
# 10  [case_id, age, gender, height, weight, bmi, co...  ...               GBM
#
#      race                                               rows  \
# 0   White  [[S001, C3L-00006, No, 2, 5, 128N, C3L-00006-0...
# 1   White  [[S001, C3L-00006, No, 2, 5, 128N, C3L-00006-0...
# 2   White  [[S001, C3L-00006, No, 2, 5, 128N, C3L-00006-0...
# 3    None  [[S001, C3L-00006, No, 2, 5, 128N, C3L-00006-0...
# 4   White  [[S001, C3L-00006, No, 2, 5, 128N, C3L-00006-0...
# 5    None  [[A-Annotation, Column annotations], [B-Clinic...
# 6    None  [[Type, BIN, BIN, BIN, BIN, BIN, BIN, BIN, BIN...
# 7    None  [[Type, BIN, BIN, BIN, BIN, BIN, BIN, BIN, BIN...
# 8    None  [[Type, BIN, BIN, BIN, BIN, BIN, BIN, BIN, BIN...
# 9    None  [[Type, BIN, BIN, BIN, BIN, BIN, BIN, BIN, BIN...
# 10  White  [[C3L-00104, 58, Male, 188.0, 115.0, 32.54, Un...
#
#                       sheet_names     study  \
# 0   [UCEC_CPTAC3_meta_table_V2.1]       dou
# 1   [UCEC_CPTAC3_meta_table_V2.1]       dou
# 2   [UCEC_CPTAC3_meta_table_V2.1]       dou
# 3   [UCEC_CPTAC3_meta_table_V2.1]       dou
# 4   [UCEC_CPTAC3_meta_table_V2.1]       dou
# 5   [Description, B-ClinicalData]      None
# 6   [Description, B-ClinicalData]  Vasaikar
# 7   [Description, B-ClinicalData]  Vasaikar
# 8   [Description, B-ClinicalData]  Vasaikar
# 9   [Description, B-ClinicalData]  Vasaikar
# 10                [clinical_data]      Wang
#
#              tissue_or_organ_of_origin tumor_focality   tumor_grade  \
# 0                 Anterior endometrium       Unifocal  FIGO grade 1
# 1                Posterior endometrium       Unifocal  FIGO grade 1
# 2   Anterior and Posterior endometrium       Unifocal  FIGO grade 2
# 3                                 None           None          None
# 4   Anterior and Posterior endometrium       Unifocal  FIGO grade 2
# 5                                 None           None          None
# 6                        Sigmoid Colon           None          None
# 7                        Sigmoid Colon           None          None
# 8                      Ascending Colon           None          None
# 9                     Descending Colon           None          None
# 10                        Frontal Lobe            nan           nan
#
#    tumor_largest_dimension_diameter vital_status
# 0                               2.9           No
# 1                               3.5           No
# 2                               4.5           No
# 3                              None          Yes
# 4                               3.5           No
# 5                              None         None
# 6                              None       Living
# 7                              None     Deceased
# 8                              None       Living
# 9                              None       Living
# 10                              nan     Deceased
#
# [11 rows x 23 columns]
# Chosen plan
#  0. MarshalAndScanDataOp -> XLSFile
#
#  1. XLSFile -> NonLLMConvert -> Schema[['contents', 'filename', 'filename', 'header', 'name', 'number_sheets', 'rows', 'sheet_names']]
#     (contents, filename, number_she) -> (contents, filename, header, na)
#     UDF: <function xls_to_tables at 0x7faeec21bba0>
#
#  2. Schema[['contents', 'filename', 'filename', 'header', 'name', 'number_sheets', 'rows', 'sheet_names']] -> LLMFilter -> Schema[['contents', 'filename', 'filename', 'header', 'name', 'number_sheets', 'rows', 'sheet_names']]
#     (contents, filename, header, na) -> (contents, filename, header, na)
#     Model: Model.GPT_4o_MINI
#     Filter: The table contains biometric information about the patient
#
#
# Total execution time: 50.044567823410034 seconds
# Total execution cost: 0.0061902 USD

# %% [markdown]
# ## End to end

# %% [markdown]
# Minimum cost : GPT 3.5

# %%
papers_html = pz.Dataset("../testdata/biofabric-html-tiny")
table_urls = papers_html.sem_add_columns(
    [{"name": "url", "type": str, "desc": "The URLs of the XLS tables from the page"}],
    cardinality=pz.Cardinality.ONE_TO_MANY)
files = table_urls.add_columns(udf=udfs.url_to_file, cols=file_cols)
# xls = files.download()
xls = pz.Dataset("../testdata/biofabric-tiny")
tables = xls.add_columns(udf=udfs.xls_to_tables, cols=table_cols, cardinality=pz.Cardinality.ONE_TO_MANY)
patient_tables = tables.sem_filter("The table contains biometric information about the patient")
case_data = patient_tables.sem_add_columns(case_data_cols, cardinality=pz.Cardinality.ONE_TO_MANY)

policy = pz.MinCost()
config = pz.QueryProcessorConfig(policy=policy, nocache=True)
result = case_data.run(config)

print_result(result.data_records)
print_stats(result.execution_stats)
# Out:
# VBox(children=(IntProgress(value=0, bar_style='info', description='Processing:', max=12), HTML(value='<pre>Ini…
# Error parsing answers: Extra data: line 1 column 266 (char 265)
#     age_at_diagnosis ajcc_pathologic_n ajcc_pathologic_stage  \
# 0              38.88               pN0               Stage I
# 1              39.76               pNX              Stage IV
# 2              51.19               pN0               Stage I
# 3                NaN              None                  None
# 4              32.69               pNX               Stage I
# 5                NaN              None                  None
# 6             729.00               N2b             Stage III
# 7             838.00                N0              Stage II
# 8             904.00               N2b             Stage III
# 9             652.00                N0              Stage II
# 10               NaN              None                  None
# 11             58.00
# 12             59.00              None                  None
# 13             45.00              None                  None
# 14             69.00              None                  None
# 15             77.00              None                  None
# 16               NaN              None                  None
# 17               NaN              None                  None
#
#    ajcc_pathologic_t case_submitter_id  \
# 0     pT1a (FIGO IA)         C3L-00006
# 1     pT1a (FIGO IA)         C3L-00008
# 2     pT1a (FIGO IA)         C3L-00032
# 3               None         C3L-00084
# 4     pT1a (FIGO IA)         C3L-00090
# 5               None              None
# 6                T4a           01CO001
# 7                 T3           01CO005
# 8                T4a           01CO006
# 9                 T3           01CO008
# 10              None              None
# 11     Not available         C3L-00104
# 12              None              None
# 13              None              None
# 14              None              None
# 15              None              None
# 16              None         C3L-00104
# 17              None              None
#
#                                              contents               ethnicity  \
# 0   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...  Not-Hispanic or Latino
# 1   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...  Not-Hispanic or Latino
# 2   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...  Not-Hispanic or Latino
# 3   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...                      No
# 4   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...  Not-Hispanic or Latino
# 5   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...                    None
# 6   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...                    None
# 7   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...                    None
# 8   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...                    None
# 9   b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...                    None
# 10  b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...                    None
# 11  b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...  Not-Hispanic or Latino
# 12  b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...                    None
# 13  b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...                    None
# 14  b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...                    None
# 15  b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...                    None
# 16  b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...                    None
# 17  b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\...                    None
#
#               filename  gender  \
# 0        dou_mmc1.xlsx  Female
# 1        dou_mmc1.xlsx  Female
# 2        dou_mmc1.xlsx  Female
# 3        dou_mmc1.xlsx    None
# 4        dou_mmc1.xlsx  Female
# 5   vasaikar_mmc1.xlsx    None
# 6   vasaikar_mmc1.xlsx    Male
# 7   vasaikar_mmc1.xlsx  Female
# 8   vasaikar_mmc1.xlsx  Female
# 9   vasaikar_mmc1.xlsx  Female
# 10      wang_mmc2.xlsx    None
# 11      wang_mmc2.xlsx    Male
# 12      wang_mmc2.xlsx  Female
# 13      wang_mmc2.xlsx    None
# 14      wang_mmc2.xlsx    None
# 15      wang_mmc2.xlsx    None
# 16      wang_mmc2.xlsx    None
# 17      wang_mmc2.xlsx    None
#
#                                                header  ... primary_diagnosis  \
# 0   [idx, Proteomics_Participant_ID, Case_excluded...  ...      Endometrioid
# 1   [idx, Proteomics_Participant_ID, Case_excluded...  ...      Endometrioid
# 2   [idx, Proteomics_Participant_ID, Case_excluded...  ...      Endometrioid
# 3   [idx, Proteomics_Participant_ID, Case_excluded...  ...    Carcinosarcoma
# 4   [idx, Proteomics_Participant_ID, Case_excluded...  ...      Endometrioid
# 5   [Column name, Column definition, Unnamed: 2, U...  ...              None
# 6   [SampleID, Clinical, Mutation, CNV, miRNA-seq,...  ...              None
# 7   [SampleID, Clinical, Mutation, CNV, miRNA-seq,...  ...              None
# 8   [SampleID, Clinical, Mutation, CNV, miRNA-seq,...  ...              None
# 9   [SampleID, Clinical, Mutation, CNV, miRNA-seq,...  ...              None
# 10      [README for Table S1, Unnamed: 1, Unnamed: 2]  ...              None
# 11  [case_id, age, gender, height, weight, bmi, co...  ...               GBM
# 12  [case_id, age, gender, height, weight, bmi, co...  ...              None
# 13  [case_id, age, gender, height, weight, bmi, co...  ...              None
# 14  [case_id, age, gender, height, weight, bmi, co...  ...              None
# 15  [case_id, age, gender, height, weight, bmi, co...  ...              None
# 16  [case, sample_type, multiomic, nmf_consensus, ...  ...       GBM, RTK II
# 17  [aliquot_id, sample_id, original_aliquot_id, b...  ...              None
#
#          race                                               rows  \
# 0       White  [[S001, C3L-00006, No, 2, 5, 128N, C3L-00006-0...
# 1       White  [[S001, C3L-00006, No, 2, 5, 128N, C3L-00006-0...
# 2       White  [[S001, C3L-00006, No, 2, 5, 128N, C3L-00006-0...
# 3        None  [[S001, C3L-00006, No, 2, 5, 128N, C3L-00006-0...
# 4       White  [[S001, C3L-00006, No, 2, 5, 128N, C3L-00006-0...
# 5        None  [[SampleID, ID of the prospective participant,...
# 6        None  [[Type, BIN, BIN, BIN, BIN, BIN, BIN, BIN, BIN...
# 7        None  [[Type, BIN, BIN, BIN, BIN, BIN, BIN, BIN, BIN...
# 8        None  [[Type, BIN, BIN, BIN, BIN, BIN, BIN, BIN, BIN...
# 9        None  [[Type, BIN, BIN, BIN, BIN, BIN, BIN, BIN, BIN...
# 10       None  [[nan, nan, nan], [Tab1, clinical_data, Clinic...
# 11  Caucasian  [[C3L-00104, 58, Male, 188.0, 115.0, 32.54, Un...
# 12       None  [[C3L-00104, 58, Male, 188.0, 115.0, 32.54, Un...
# 13       None  [[C3L-00104, 58, Male, 188.0, 115.0, 32.54, Un...
# 14       None  [[C3L-00104, 58, Male, 188.0, 115.0, 32.54, Un...
# 15       None  [[C3L-00104, 58, Male, 188.0, 115.0, 32.54, Un...
# 16       None  [[C3L-00104, tumor, nmf1, nmf1, 0.743, Proneur...
# 17       None  [[7316-288-TISS [894482], 7316-288, 7316-288-T...
#
#                                           sheet_names     study  \
# 0                       [UCEC_CPTAC3_meta_table_V2.1]  dou_mmc1
# 1                       [UCEC_CPTAC3_meta_table_V2.1]  dou_mmc1
# 2                       [UCEC_CPTAC3_meta_table_V2.1]  dou_mmc1
# 3                       [UCEC_CPTAC3_meta_table_V2.1]  dou_mmc1
# 4                       [UCEC_CPTAC3_meta_table_V2.1]  dou_mmc1
# 5         [Description, A-Annotation, B-ClinicalData]      None
# 6         [Description, A-Annotation, B-ClinicalData]  Vasaikar
# 7         [Description, A-Annotation, B-ClinicalData]  Vasaikar
# 8         [Description, A-Annotation, B-ClinicalData]  Vasaikar
# 9         [Description, A-Annotation, B-ClinicalData]  Vasaikar
# 10  [README, clinical_data, additional_annotations...      None
# 11  [README, clinical_data, additional_annotations...      Wang
# 12  [README, clinical_data, additional_annotations...      None
# 13  [README, clinical_data, additional_annotations...      None
# 14  [README, clinical_data, additional_annotations...      None
# 15  [README, clinical_data, additional_annotations...      None
# 16  [README, clinical_data, additional_annotations...      Wang
# 17  [README, clinical_data, additional_annotations...      Wang
#
#              tissue_or_organ_of_origin tumor_focality   tumor_grade  \
# 0                 Anterior endometrium       Unifocal  FIGO grade 1
# 1                Posterior endometrium       Unifocal  FIGO grade 1
# 2   Anterior and Posterior endometrium       Unifocal  FIGO grade 2
# 3                                 None           None          None
# 4   Anterior and Posterior endometrium       Unifocal  FIGO grade 2
# 5                                 None           None          None
# 6                        Sigmoid Colon           None          None
# 7                        Sigmoid Colon           None          None
# 8                      Ascending Colon           None          None
# 9                     Descending Colon           None          None
# 10                                None           None          None
# 11                        Frontal Lobe     unilateral             4
# 12                                None           None          None
# 13                                None           None          None
# 14                                None           None          None
# 15                                None           None          None
# 16                                None           None          None
# 17                                None           None          None
#
#    tumor_largest_dimension_diameter vital_status
# 0                               2.9           No
# 1                               3.5           No
# 2                               4.5           No
# 3                              None          Yes
# 4                               3.5           No
# 5                              None         None
# 6                              None       Living
# 7                              None     Deceased
# 8                              None       Living
# 9                              None       Living
# 10                             None         None
# 11                            608.0     Deceased
# 12                             None     Deceased
# 13                             None     Deceased
# 14                             None     Deceased
# 15                             None       Living
# 16                           2632.0         None
# 17                             None        Alive
#
# [18 rows x 23 columns]
# Chosen plan
#  0. MarshalAndScanDataOp -> XLSFile
#
#  1. XLSFile -> NonLLMConvert -> Schema[['contents', 'filename', 'filename', 'header', 'name', 'number_sheets', 'rows', 'sheet_names']]
#     (contents, filename, number_she) -> (contents, filename, header, na)
#     UDF: <function xls_to_tables at 0x7fcdc4214720>
#
#  2. Schema[['contents', 'filename', 'filename', 'header', 'name', 'number_sheets', 'rows', 'sheet_names']] -> LLMFilter -> Schema[['contents', 'filename', 'filename', 'header', 'name', 'number_sheets', 'rows', 'sheet_names']]
#     (contents, filename, header, na) -> (contents, filename, header, na)
#     Model: Model.GPT_4o_MINI
#     Filter: The table contains biometric information about the patient
#
#  3. Schema[['contents', 'filename', 'filename', 'header', 'name', 'number_sheets', 'rows', 'sheet_names']] -> LLMConvertBonded -> Schema[['age_at_diagnosis', 'ajcc_pathologic_n', 'ajcc_pathologic_stage', 'ajcc_pathologic_t', 'case_submitter_id', 'contents', 'ethnicity', 'filename', 'gender', 'header', 'morphology', 'name', 'number_sheets', 'primary_diagnosis', 'race', 'rows', 'sheet_names', 'study', 'tissue_or_organ_of_origin', 'tumor_focality', 'tumor_grade', 'tumor_largest_dimension_diameter', 'vital_status']]
#     (contents, filename, header, na) -> (age_at_diagnosis, ajcc_patholo)
#     Model: Model.GPT_4o_MINI
#     Prompt Strategy: PromptStrategy.COT_QA
#
#
# Total execution time: 100.12398648262024 seconds
# Total execution cost: 0.014461200000000002 USD

# %%
output_table.__dict__.keys()

# %% [markdown]
# Maximum Cost: GPT 4

# %%
xls = pz.Dataset("testdata/biofabric-tiny")
patient_tables = xls.sem_add_columns(table_cols, cardinality=pz.Cardinality.ONE_TO_MANY)
patient_tables = patient_tables.sem_filter("The table contains biometric information about the patient")
case_data = patient_tables.sem_add_columns(case_data_cols, cardinality=pz.Cardinality.ONE_TO_MANY)

policy = pz.MaxQuality()
config = pz.QueryProcessorConfig(
    policy=policy,
    nocache=True,
    allow_token_reduction=False,
    allow_code_synth=False,
    processing_strategy="streaming",
    execution_strategy="sequential",
)
iterable = case_data.run(config)

output_rows = []
for data_record_collection in iterable:  # noqa: B007
    for output_table in data_record_collection:
        print(output_table.to_dict().keys())
        output_rows.append(output_table.to_dict()) 

output_df = pd.DataFrame(output_rows)
display(output_df)
# Out:
# LOGICAL PLANS: 1
# INITIAL PLANS: 27
# DEDUP PLANS: 27
# PARETO PLANS: 17
# ----------
# Policy is: Maximum Quality
# Chosen plan: Time est: 411.647 -- Cost est: 0.973 -- Quality est: 0.486
#  0. MarshalAndScanDataOp -> File
#
#  1. File -> InduceFromCandidateOp -> XLSFile
#     Using Model.GPT_3_5
#     (contents,filena...) -> (contents,filena...)
#
#  2. XLSFile -> InduceFromCandidateOp -> Table
#     Using Model.GPT_4
#     (contents,filena...) -> (filename,header...)
#
#  3. Table -> FilterCandidateOp -> Table
#     Using Model.GPT_4
#     Filter: "The table contains biometric information about the patient"
#     (filename,header...) -> (filename,header...)
#
#  4. Table -> InduceFromCandidateOp -> CaseData
#     Using Model.GPT_4
#     (filename,header...) -> (age_at_diagnosi...)
#
# Bonded query processing error: No output objects were generated with bonded query - trying with conventional query...
# BondedQuery Error: No output objects were generated with bonded query - trying with conventional query...
# Falling back to conventional query
# Could not find any items in the JSON response
# Could not find any items in the JSON response
# Bonded query processing error: No output objects were generated with bonded query - trying with conventional query...
# BondedQuery Error: No output objects were generated with bonded query - trying with conventional query...
# Falling back to conventional query
# Could not find any items in the JSON response
# Could not find any items in the JSON response
# Could not find any items in the JSON response
# Could not find any items in the JSON response
# Could not find any items in the JSON response
#     age_at_diagnosis ajcc_pathologic_n ajcc_pathologic_stage  \
# 0               64.0               pN0               Stage I
# 1               58.0               pNX              Stage IV
# 2               50.0               pN0               Stage I
# 3                NaN              None                  None
# 4               75.0               pNX               Stage I
# 5              729.0               N2b             Stage III
# 6              838.0                N0              Stage II
# 7              904.0               N2b             Stage III
# 8              652.0                N0              Stage II
# 9               58.0              None                  None
# 10              59.0              None                  None
# 11              45.0              None                  None
# 12              69.0              None                  None
# 13              77.0              None                  None
#
#    ajcc_pathologic_t case_submitter_id               ethnicity  gender  \
# 0     pT1a (FIGO IA)         C3L-00006  Not-Hispanic or Latino  Female
# 1     pT1a (FIGO IA)         C3L-00008  Not-Hispanic or Latino  Female
# 2     pT1a (FIGO IA)         C3L-00032  Not-Hispanic or Latino  Female
# 3               None         C3L-00084                    None    None
# 4     pT1a (FIGO IA)         C3L-00090  Not-Hispanic or Latino  Female
# 5                T4a           01CO001                    None    Male
# 6                 T3           01CO005                    None  Female
# 7                T4a           01CO006                    None  Female
# 8                 T3           01CO008                    None  Female
# 9               None         C3L-00104  Not-Hispanic or Latino    Male
# 10              None         C3L-00365  Not-Hispanic or Latino  Female
# 11              None         C3L-00674  Not-Hispanic or Latino    Male
# 12              None         C3L-00677  Not-Hispanic or Latino  Female
# 13              None         C3L-01040                     nan    Male
#
#         morphology primary_diagnosis   race        study  \
# 0     Endometrioid      FIGO grade 1  White  UCEC_CPTAC3
# 1     Endometrioid      FIGO grade 1  White  UCEC_CPTAC3
# 2     Endometrioid      FIGO grade 2  White  UCEC_CPTAC3
# 3   Carcinosarcoma              None   None  UCEC_CPTAC3
# 4     Endometrioid      FIGO grade 2  White  UCEC_CPTAC3
# 5         Mucinous              None   None     Vasaikar
# 6     Not Mucinous              None   None     Vasaikar
# 7         Mucinous              None   None     Vasaikar
# 8         Mucinous              None   None     Vasaikar
# 9             None              None  White         wang
# 10            None              None  White         wang
# 11            None              None  White         wang
# 12            None              None  White         wang
# 13            None              None    nan         wang
#
#    tissue_or_organ_of_origin tumor_focality           tumor_grade  \
# 0       Anterior endometrium       Unifocal  Cannot be determined
# 1      Posterior endometrium       Unifocal  Cannot be determined
# 2             Other, specify       Unifocal  Cannot be determined
# 3                       None           None                  None
# 4             Other, specify       Unifocal  Cannot be determined
# 5              Sigmoid Colon           None                  None
# 6              Sigmoid Colon           None                  None
# 7            Ascending Colon           None                  None
# 8           Descending Colon           None                  None
# 9               Frontal Lobe           None                  None
# 10             Parietal Lobe           None                  None
# 11              Frontal Lobe           None                  None
# 12              Frontal Lobe           None                  None
# 13              Frontal Lobe           None                  None
#
#     tumor_largest_dimension_diameter vital_status
# 0                                2.9           No
# 1                                3.5           No
# 2                                4.5          Yes
# 3                                NaN         None
# 4                                3.5           No
# 5                                NaN       Living
# 6                                NaN     Deceased
# 7                                NaN       Living
# 8                                NaN       Living
# 9                                NaN     Deceased
# 10                               NaN     Deceased
# 11                               NaN     Deceased
# 12                               NaN     Deceased
# 13                               NaN       Living
